# %% [markdown]
# ## Creating a sub-network of assembled interactions from a list of entities for Boolean network modeling

# %% [markdown]
# ### Getting identifiers for a list of entities

# %% [markdown]
# In the spreadsheet provided below, informal names are given for several genes, proteins, and phenotypes. Unless database identifiers are readily available for these, we need to "ground" them automatically. The Gilda package (see http://grounding.indra.bio/, https://github.com/indralab/gilda, https://www.biorxiv.org/content/10.1101/2021.09.10.459803v1) can correctly ground most entities in the provided spreadsheet but some use non-standard naming like underscores so these we assign identifiers manually

# %%
fname = 'test_INDRA_BN_seed_genes_apoptosis.xlsx'

# %%
import gilda
import pandas

mappings = {
    'SARS_3a': ('UP', 'P59632'),
    'SARS_E7a': ('UP', 'P59637'),
    'SARS_M': ('UP', 'P59596'),
    'Procasp9': ('UP', 'P55211'),
    'Apoptosis_phenotype': ('GO', 'GO:0006915'),
    'Cytochrome_C': ('HGNC', '19986')
}


df = pandas.read_excel(fname, engine='openpyxl', header=None)
entities = sorted(set(df[0]))
groundings = {}
for entity in entities:
    mapped_grounding = mappings.get(entity)
    if mapped_grounding:
        groundings[entity] = mapped_grounding
    else:
        matches = gilda.ground(entity)
        if not matches:
            groundings[entity] = None
        else:
            groundings[entity] = matches[0].term.db, matches[0].term.id

# %% [markdown]
# At this point we have a dict called `groundings` that contains each entity's name as a key and its database namespace and identifier as value.

# %%
groundings
# Out:
# {'AKT': ('FPLX', 'AKT'),
#  'Apoptosis_phenotype': ('GO', 'GO:0006915'),
#  'Apoptosome': ('GO', 'GO:0043293'),
#  'BAD': ('HGNC', '936'),
#  'BAX': ('HGNC', '959'),
#  'BCL2': ('HGNC', '990'),
#  'BCLXL': ('HGNC', '992'),
#  'BID': ('HGNC', '1050'),
#  'BIM': ('HGNC', '994'),
#  'CASP3': ('HGNC', '1504'),
#  'CASP7': ('HGNC', '1508'),
#  'CASP8': ('HGNC', '1509'),
#  'CASP9': ('HGNC', '1511'),
#  'Cytochrome_C': ('HGNC', '19986'),
#  'FADD': ('HGNC', '3573'),
#  'FAS': ('HGNC', '11920'),
#  'FASL': ('HGNC', '11936'),
#  'MAPK14': ('HGNC', '6876'),
#  'MCL1': ('HGNC', '6943'),
#  'PUMA': ('HGNC', '17868'),
#  'Procasp9': ('UP', 'P55211'),
#  'SARS_3a': ('UP', 'P59632'),
#  'SARS_E7a': ('UP', 'P59637'),
#  'SARS_M': ('UP', 'P59596'),
#  'TNFA': ('HGNC', '11892'),
#  'TNFR1': ('HGNC', '11916'),
#  'TRADD': ('HGNC', '12030')}

# %% [markdown]
# ### Obtaining the sub-network of relations from INDRA Discovery

# %% [markdown]
# With these in hand, we can now start constructing the subnetwork. To do this, we turn to the INDRA Discovery service (https://discovery.indra.bio) whose REST API is documented at https://discovery.indra.bio/apidocs. We call the `indra_subnetwork_relations` endpoint which takes a list of up to 300 database namespace/identifier pairs as input and returns all relations (each relation representing an INDRA Statement (see https://indra.readthedocs.io/en/latest/modules/statements.html)) between them. These relations have the following structure:
# - `source_ns`: the source entity's database namespace
# - `source_id`: the source entity's database identifier
# - `source_ns`: the target entity's database namespace
# - `source_id`: the target entity's database identifier
# - `rel_type`: this is always `indra_rel` so not interesting
# - `data`:
#     - `stmt_hash`: the unique identifier of the INDRA Statement, derived from its content
#     - `stmt_json`: the full data structure of the INDRA Statement including at most 1 of its evidences (even if the Statement is supported by many evidences, for efficiency, this endpoint doesn't return all of them. This JSON can be deserialized into INDRA Statement objects using the INDRA package if installed (see https://indra.readthedocs.io/en/latest/modules/statements.html#indra.statements.statements.stmts_from_json). There is also a JSON Schema specification for INDRA Statements here in case it's useful: https://github.com/sorgerlab/indra/blob/master/indra/resources/statements_schema.json
#     - `evidence_count`: the overall number of evidences supporting this Statement
#     - `source_counts`: a more detailed breakdown of the `evidence_count` by the specific source from which the evidence was obtained (representing text mining systems, pathway databases, etc.). Detailed source information is available here: https://github.com/sorgerlab/indra#knowledge-sources
#     - `belief`: a belief score between 0 and 1 assigned to the statement based on the overall support it has from evidences. Generally, a statement with more evidences from more different sources, and more reliable sources have higher belief. This score can be used for thresholding to retain higher-quality statements.
#
# Let's now make the request to the INDRA Discovery API and look at the relations we got:

# %%
import requests

# %%
res = requests.post('https://discovery.indra.bio/api/indra_subnetwork_relations',
                    json={'nodes': list(groundings.values())})

# %%
subnetwork_relations = res.json()
subnetwork_relations[0]
# Out:
# {'data': {'belief': 0.65,
#   'evidence_count': 1,
#   'source_counts': '{"reach": 1}',
#   'stmt_hash': 19619433452108905,
#   'stmt_json': '{"type": "IncreaseAmount", "subj": {"name": "BBC3", "db_refs": {"UP": "Q96PG8", "HGNC": "17868", "TEXT": "PUMA"}}, "obj": {"name": "BCL2L11", "db_refs": {"UP": "O43521", "MESH": "D000072224", "HGNC": "994", "TEXT": "BIM"}}, "belief": 1, "id": "6ac7f599-6367-4482-a42d-81982bec3e30", "matches_hash": "19619433452108905", "evidence": [{"source_api": "reach", "text": "As mitochondria and ER communicate via membrane tethering and a series of signaling events (i.e., induced expression of BIM and PUMA, XREF_FIG) to induce tUPR, we evaluated the expression of Mfn1 and Mfn2, which are implicated in ER-mitochondrial communication.", "annotations": {"found_by": "transcription_1b", "agents": {"coords": [[128, 132], [120, 123]]}}, "epistemics": {"direct": false, "section_type": null}, "text_refs": {"TRID": "20596041", "PMID": "25482509", "PMCID": "PMC4289414", "DOI": "10.1016/J.MOLCEL.2014.10.028", "PII": "S1097-2765(14)00863-6", "MANUSCRIPT_ID": "NIHMS640629"}, "source_hash": 5997473844318191458, "pmid": "25482509"}]}',
#   'stmt_type': 'IncreaseAmount'},
#  'rel_type': 'indra_rel',
#  'source_id': '17868',
#  'source_ns': 'HGNC',
#  'target_id': '994',
#  'target_ns': 'HGNC'}

# %%
print('The number of relations we got is %d' % len(subnetwork_relations))
# Out:
# The number of relations we got is 3120

# %% [markdown]
# ### Examining and filtering the INDRA Statements constituting the sub-network

# %% [markdown]
# It is almost always the case that we want to filter INDRA Statements based on some criteria to end up with a more appropriate set for our use case. To do this, we will import INDRA and instantiate the Statement JSONs provided in the relations above for more convenient manipulation.

# %%
import json
from indra.statements import stmts_from_json, Complex

stmts = stmts_from_json([json.loads(r['data']['stmt_json']) for r in subnetwork_relations])
stmts
# Out:
# [IncreaseAmount(BBC3(), BCL2L11()),
#  DecreaseAmount(BBC3(), BCL2L11()),
#  Inhibition(BBC3(), BCL2L11()),
#  Activation(BBC3(), BCL2L11()),
#  Complex(BBC3(), BCL2L11()),
#  Complex(BBC3(), BCL2L1(), BH3 domain()),
#  Activation(BBC3(), BCL2L1(muts: (None, None, None))),
#  Activation(BBC3(), BCL2L1()),
#  Complex(BBC3(), BCL2L1(), sapC()),
#  Inhibition(BBC3(bound: [BCL2L1, True]), BCL2L1()),
#  Inhibition(BBC3(), BCL2L1()),
#  Complex(BBC3(), BCL2L1(), BH3 domains()),
#  Complex(BBC3(), BCL2L1(), BCL2L11()),
#  Complex(BBC3(), BCL2L1()),
#  Activation(BBC3(bound: [PMAIP1, True]), BCL2()),
#  IncreaseAmount(BBC3(mods: (modification)), BCL2()),
#  IncreaseAmount(BBC3(), BCL2()),
#  Complex(BBC3(), BCL2(), BH3 domain()),
#  DecreaseAmount(BBC3(), BCL2()),
#  Complex(BBC3(), BCL2(), BCL2L1()),
#  Complex(BBC3(), BCL2(), BCL2L11()),
#  DecreaseAmount(BBC3(mods: (modification)), BCL2()),
#  Inhibition(BBC3(), BCL2()),
#  Activation(BBC3(), BCL2()),
#  Complex(BBC3(), BCL2()),
#  Activation(BBC3(bound: [TP53, True]), BAX()),
#  Activation(BBC3(bound: [BCL2, True]), BAX()),
#  Activation(BBC3(catalytic), BAX(), catalytic),
#  DecreaseAmount(BBC3(), BAX()),
#  Activation(BBC3(bound: [BCL2L1, True]), BAX()),
#  Activation(BBC3(bound: [proteins, True]), BAX()),
#  Activation(BBC3(bound: [PMAIP1, True]), BAX()),
#  Inhibition(BBC3(bound: [BCL2, True]), BAX()),
#  Complex(BBC3(), BAX(), BCL2()),
#  Activation(BBC3(bound: [Bcl-X(L), True]), BAX()),
#  Activation(BBC3(bound: [BCL2L11, True]), BAX()),
#  Complex(BBC3(), BAX(), BH3 domain()),
#  Activation(BBC3(bound: [Bim EL, True]), BAX()),
#  IncreaseAmount(BBC3(), BAX()),
#  Complex(BBC3(), BAX(), BCL2L1()),
#  Inhibition(BBC3(), BAX()),
#  Complex(BBC3(), BAX(), BCL2L11()),
#  Complex(BBC3(), BAX()),
#  Activation(BBC3(), BAX()),
#  Complex(BBC3(), BAD(), BCL2()),
#  Complex(BBC3(), BAD(), carD()),
#  Activation(BBC3(), BAD()),
#  Complex(BBC3(), BAD(), BCL2L11()),
#  Inhibition(BBC3(), BAD()),
#  Complex(BBC3(), BAD(), ARC()),
#  Complex(BBC3(), BAD(), BAX()),
#  Complex(BBC3(), BAD()),
#  IncreaseAmount(BBC3(), MCL1()),
#  Complex(BBC3(), MCL1(), BCL2L1()),
#  Ubiquitination(BBC3(mods: (modification)), MCL1()),
#  Complex(BBC3(), MCL1(), B-H1()),
#  Activation(BBC3(muts: (None, None, None)), MCL1()),
#  Complex(BBC3(), MCL1(), A1()),
#  Ubiquitination(BBC3(), MCL1()),
#  DecreaseAmount(BBC3(), MCL1()),
#  Complex(BBC3(), MCL1(), BH3 domain()),
#  Inhibition(BBC3(), MCL1()),
#  Activation(BBC3(), MCL1()),
#  Complex(BBC3(muts: (None, None, None)), MCL1()),
#  Complex(BBC3(), MCL1(), BCL2()),
#  Complex(BBC3(), MCL1(), BCL2L11()),
#  Complex(BBC3(), MCL1()),
#  Complex(BBC3(), MCL1(), PMAIP1()),
#  Activation(BBC3(), FADD()),
#  Inhibition(BBC3(), FADD()),
#  Activation(BBC3(bound: [BCL2, True]), CYCS()),
#  Complex(BBC3(), CYCS()),
#  Activation(BBC3(bound: [BAX, True]), CYCS()),
#  Activation(BBC3(bound: [BCL2L1, True]), CYCS()),
#  Inhibition(BBC3(), CYCS()),
#  Activation(BBC3(), CYCS()),
#  Inhibition(BBC3(), CASP9()),
#  Activation(BBC3(), CASP9()),
#  Activation(BBC3(), CASP8()),
#  Inhibition(BBC3(), CASP3()),
#  Activation(BBC3(), CASP3()),
#  Inhibition(BBC3(), FAS()),
#  Activation(BBC3(), TNF()),
#  Inhibition(BBC3(), TNF()),
#  Inhibition(BBC3(), BID()),
#  Activation(BBC3(), BID()),
#  Activation(BBC3(bound: [BCL2L1, True]), apoptotic process()),
#  Inhibition(BBC3(mods: (modification)), apoptotic process()),
#  Activation(BBC3(mods: (modification)), apoptotic process()),
#  Activation(BBC3(bound: [BCL2L1, True]), apoptotic process()),
#  Activation(BBC3(muts: (W, 71, A)), apoptotic process()),
#  Activation(BBC3(bound: [BCL2, True]), apoptotic process()),
#  Activation(BBC3(bound: [BAX, True]), apoptotic process()),
#  Inhibition(BBC3(), apoptotic process()),
#  Activation(BBC3(), apoptotic process()),
#  DecreaseAmount(BBC3(), AKT()),
#  Dephosphorylation(BBC3(mods: (modification)), AKT()),
#  Activation(BBC3(), AKT()),
#  Inhibition(BBC3(), AKT()),
#  Inhibition(CYCS(), AKT(mods: (phosphorylation))),
#  IncreaseAmount(CYCS(mods: (modification)), AKT(mods: (phosphorylation))),
#  DecreaseAmount(CYCS(), AKT()),
#  Inhibition(CYCS(), AKT()),
#  Dephosphorylation(CYCS(), AKT()),
#  Activation(CYCS(), AKT()),
#  IncreaseAmount(CYCS(), AKT()),
#  IncreaseAmount(CYCS(), BCL2L11()),
#  Activation(CYCS(), BCL2L11()),
#  Complex(CYCS(), BCL2L11()),
#  DecreaseAmount(CYCS(), BCL2L11()),
#  Inhibition(CYCS(), BCL2L11()),
#  IncreaseAmount(CYCS(), BCL2L1()),
#  Activation(CYCS(), BCL2L1()),
#  Inhibition(CYCS(), BCL2L1()),
#  DecreaseAmount(CYCS(), BCL2L1()),
#  Complex(CYCS(), BCL2L1()),
#  Complex(CYCS(), BCL2(), complex I()),
#  IncreaseAmount(CYCS(), BCL2()),
#  Complex(CYCS(), BCL2(), BCL2L11()),
#  IncreaseAmount(CYCS(mods: (modification)), BCL2()),
#  Complex(CYCS(), BCL2(), BCL2L1()),
#  DecreaseAmount(CYCS(mods: (modification)), BCL2()),
#  Inhibition(CYCS(), BCL2()),
#  Activation(CYCS(), BCL2()),
#  DecreaseAmount(CYCS(), BCL2()),
#  Complex(CYCS(), BCL2()),
#  Complex(CYCS(), BAX(), hbhA()),
#  Complex(CYCS(), BAX(), ion channel()),
#  Complex(CYCS(), BAX(), nicK(), CCP(), transferase()),
#  Complex(CYCS(), BAX(), SYD()),
#  Complex(CYCS(), BAX(), BCL2L11()),
#  Dephosphorylation(CYCS(), BAX()),
#  IncreaseAmount(CYCS(mods: (modification)), BAX()),
#  Complex(CYCS(), BAX(), voltage-dependent anion channel()),
#  Complex(CYCS(), BAX(), BCL2()),
#  IncreaseAmount(CYCS(), BAX()),
#  DecreaseAmount(CYCS(), BAX()),
#  Inhibition(CYCS(), BAX()),
#  Complex(CYCS(), BAX()),
#  Activation(CYCS(), BAX()),
#  Complex(CYCS(), BAD(), BCL2L1()),
#  Inhibition(CYCS(), BAD()),
#  Complex(CYCS(), BAD()),
#  Activation(CYCS(), BAD()),
#  Phosphorylation(CYCS(), BAD()),
#  DecreaseAmount(CYCS(), MCL1()),
#  Complex(CYCS(), MCL1()),
#  Dephosphorylation(CYCS(), MCL1()),
#  Activation(CYCS(), FADD()),
#  IncreaseAmount(CYCS(), FADD()),
#  Activation(CYCS(), BBC3()),
#  Activation(CYCS(bound: [Caspase, True]), CASP9()),
#  Activation(CYCS(bound: [protease activator protein-1, True]), CASP9()),
#  Activation(CYCS(bound: [ATP, True]), CASP9()),
#  Activation(CYCS(bound: [procaspase-9, True]), CASP9()),
#  Activation(CYCS(bound: [apoptosis-activating-factor-1, True]), CASP9()),
#  DecreaseAmount(CYCS(), CASP9()),
#  Activation(CYCS(bound: [cytosolic protein, True]), CASP9()),
#  IncreaseAmount(CYCS(), CASP9()),
#  Activation(CYCS(bound: [peptidase, True]), CASP9()),
#  Inhibition(CYCS(bound: [NGB, True]), CASP9()),
#  Activation(CYCS(bound: [CASP9, True]), CASP9()),
#  Inhibition(CYCS(), CASP9()),
#  Inhibition(CYCS(bound: [tRNA, True]), CASP9()),
#  Activation(CYCS(bound: [APAF1, True]), CASP9()),
#  Activation(CYCS(bound: [Protease, True]), CASP9()),
#  Activation(CYCS(), CASP9()),
#  Inhibition(CYCS(), CASP8()),
#  Activation(CYCS(mods: (modification)), CASP8()),
#  Activation(CYCS(), CASP8()),
#  Activation(CYCS(bound: [APAF1, True]), CASP7()),
#  Activation(CYCS(), CASP7()),
#  Activation(CYCS(bound: [Caspase, True]), CASP3()),
#  IncreaseAmount(CYCS(mods: (modification)), CASP3()),
#  Activation(CYCS(bound: [apoptosis-activating-factor-1, True]), CASP3()),
#  Activation(CYCS(bound: [procaspase-9, True]), CASP3()),
#  Activation(CYCS(bound: [CASP9, True], bound: [APAF1, True]), CASP3()),
#  Activation(CYCS(bound: [Protease, True]), CASP3()),
#  Activation(CYCS(bound: [dATP, True]), CASP3()),
#  Activation(CYCS(mods: (modification)), CASP3()),
#  Activation(CYCS(bound: [CASP9, True]), CASP3()),
#  DecreaseAmount(CYCS(), CASP3()),
#  DecreaseAmount(CYCS(mods: (modification)), CASP3()),
#  Activation(CYCS(bound: [APAF1, True]), CASP3()),
#  Inhibition(CYCS(), CASP3()),
#  IncreaseAmount(CYCS(), CASP3()),
#  Activation(CYCS(), CASP3()),
#  IncreaseAmount(CYCS(), FASLG()),
#  Activation(CYCS(), FASLG()),
#  IncreaseAmount(CYCS(), FAS()),
#  Inhibition(CYCS(), FAS()),
#  Inhibition(CYCS(muts: (None, None, None), bound: [APAF1, True]), FAS()),
#  Activation(CYCS(), FAS()),
#  Activation(CYCS(), TNF()),
#  Activation(CYCS(), BID()),
#  Inhibition(CYCS(), BID()),
#  Inhibition(CYCS(), apoptosome()),
#  Activation(CYCS(), apoptosome()),
#  Activation(CYCS(bound: [CASP3, True]), apoptotic process()),
#  Activation(CYCS(bound: [Caspase, True]), apoptotic process()),
#  Activation(CYCS(muts: (N, 52, I)), apoptotic process()),
#  Inhibition(CYCS(bound: [FA, True]), apoptotic process()),
#  Activation(CYCS(bound: [protein, True]), apoptotic process()),
#  Inhibition(CYCS(bound: [HSPB1, True]), apoptotic process()),
#  Activation(CYCS(bound: [ESR1, True]), apoptotic process()),
#  Activation(CYCS(bound: [IP3R post-burn, True]), apoptotic process()),
#  Activation(CYCS(bound: [acetic acid, True]), apoptotic process()),
#  Activation(CYCS(bound: [CASP9, True]), apoptotic process()),
#  Activation(CYCS(bound: [apoptosis-activating-factor-1, True]), apoptotic process()),
#  Activation(CYCS(bound: [APAF1, True]), apoptotic process()),
#  Activation(CYCS(mods: (modification)), apoptotic process()),
#  Inhibition(CYCS(), apoptotic process()),
#  Activation(CYCS(), apoptotic process()),
#  Inhibition(apoptotic process(), BCL2L11()),
#  Activation(apoptotic process(), BCL2L11()),
#  IncreaseAmount(apoptotic process(), BCL2L11()),
#  IncreaseAmount(apoptotic process(), BCL2L1()),
#  Activation(apoptotic process(), BCL2L1()),
#  Inhibition(apoptotic process(), BCL2L1()),
#  IncreaseAmount(apoptotic process(), BCL2()),
#  Inhibition(apoptotic process(), BCL2()),
#  Activation(apoptotic process(), BCL2()),
#  IncreaseAmount(apoptotic process(), BAX()),
#  Activation(apoptotic process(), BAX()),
#  Inhibition(apoptotic process(), BAX()),
#  Activation(apoptotic process(), BAD()),
#  Inhibition(apoptotic process(), MCL1()),
#  Activation(apoptotic process(), MCL1()),
#  IncreaseAmount(apoptotic process(), MCL1()),
#  Inhibition(apoptotic process(), FADD()),
#  Activation(apoptotic process(), FADD()),
#  Activation(apoptotic process(), CYCS()),
#  Inhibition(apoptotic process(), CYCS()),
#  IncreaseAmount(apoptotic process(), BBC3()),
#  Activation(apoptotic process(), BBC3()),
#  Inhibition(apoptotic process(), BBC3()),
#  Activation(apoptotic process(), CASP9()),
#  Inhibition(apoptotic process(), CASP9()),
#  Inhibition(apoptotic process(), CASP9(muts: (None, None, None))),
#  Inhibition(apoptotic process(), CASP8()),
#  Activation(apoptotic process(), CASP8()),
#  Inhibition(apoptotic process(), CASP7()),
#  Activation(apoptotic process(), CASP7()),
#  Inhibition(apoptotic process(), CASP3()),
#  Activation(apoptotic process(), CASP3()),
#  IncreaseAmount(apoptotic process(), CASP3()),
#  Inhibition(apoptotic process(), TRADD()),
#  IncreaseAmount(apoptotic process(), FASLG()),
#  Inhibition(apoptotic process(), FASLG()),
#  Activation(apoptotic process(), FASLG()),
#  Inhibition(apoptotic process(), FAS()),
#  IncreaseAmount(apoptotic process(), FAS()),
#  Activation(apoptotic process(), FAS()),
#  Inhibition(apoptotic process(), TNFRSF1A()),
#  Activation(apoptotic process(), TNFRSF1A()),
#  IncreaseAmount(apoptotic process(), TNF()),
#  Inhibition(apoptotic process(), TNF()),
#  Activation(apoptotic process(), TNF()),
#  Inhibition(apoptotic process(), BID()),
#  Activation(apoptotic process(), BID()),
#  Inhibition(apoptotic process(), AKT(mods: (phosphorylation))),
#  Activation(apoptotic process(), AKT()),
#  Inhibition(apoptotic process(), AKT()),
#  Complex(FADD(), BCL2L1()),
#  Activation(FADD(), BCL2()),
#  Complex(FADD(), BCL2()),
#  Inhibition(FADD(), BCL2()),
#  Complex(FADD(), BCL2(), BCL2L1()),
#  IncreaseAmount(FADD(), BAX()),
#  Activation(FADD(), BAX()),
#  Inhibition(FADD(), CYCS()),
#  Activation(FADD(), CYCS()),
#  Activation(FADD(), BBC3()),
#  Activation(FADD(), CASP9()),
#  Inhibition(FADD(), CASP9()),
#  IncreaseAmount(FADD(), CASP9()),
#  Inhibition(FADD(muts: (None, None, None)), CASP8()),
#  Activation(FADD(bound: [FAS, True]), CASP8()),
#  Inhibition(FADD(bound: [FCMR, True]), CASP8()),
#  Activation(FADD(bound: [procaspase-8 molecules, True]), CASP8()),
#  Activation(FADD(muts: (None, None, None)), CASP8()),
#  Inhibition(FADD(bound: [MUC1-C, True]), CASP8()),
#  Activation(FADD(bound: [CASP8, True], bound: [RIPK1, True]), CASP8()),
#  Ubiquitination(FADD(), CASP8()),
#  Activation(FADD(catalytic), CASP8(), catalytic),
#  Activation(FADD(), CASP8(), catalytic),
#  Activation(FADD(bound: [TNFRSF1A, True]), CASP8()),
#  Activation(FADD(bound: [death domain, True]), CASP8()),
#  IncreaseAmount(FADD(), CASP8()),
#  Inhibition(FADD(mods: (modification)), CASP8()),
#  IncreaseAmount(FADD(mods: (modification)), CASP8()),
#  Activation(FADD(mods: (modification)), CASP8()),
#  Activation(FADD(bound: [caspase-8/10, True]), CASP8()),
#  Activation(FADD(bound: [CASP8, True]), CASP8()),
#  Activation(FADD(bound: [it, True]), CASP8()),
#  DecreaseAmount(FADD(), CASP8()),
#  Inhibition(FADD(bound: [CFLAR, True]), CASP8()),
#  Inhibition(FADD(), CASP8()),
#  Activation(FADD(bound: [ATG13, True]), CASP8()),
#  Inhibition(FADD(), CASP8(muts: (D, 387, A))),
#  Activation(FADD(), CASP8()),
#  Activation(FADD(bound: [CASP8, True]), CASP7()),
#  Inhibition(FADD(muts: (None, None, None)), CASP3()),
#  Activation(FADD(bound: [CASP8, True]), CASP3()),
#  IncreaseAmount(FADD(), CASP3()),
#  Inhibition(FADD(), CASP3()),
#  Acetylation(FADD(), CASP3()),
#  Activation(FADD(), CASP3()),
#  Activation(FADD(), TRADD()),
#  DecreaseAmount(FADD(), FASLG()),
#  Inhibition(FADD(), FASLG()),
#  Activation(FADD(), FASLG()),
#  Activation(FADD(muts: (S, 191, D)), FAS()),
#  Inhibition(FADD(), FAS()),
#  Inhibition(FADD(muts: (None, None, None)), FAS()),
#  Activation(FADD(), FAS()),
#  IncreaseAmount(FADD(), FAS()),
#  Activation(FADD(bound: [PRKCZ, True]), FAS(), catalytic),
#  Inhibition(FADD(), TNFRSF1A()),
#  Activation(FADD(), TNFRSF1A()),
#  Activation(FADD(bound: [RIP1-caspase 8, True]), TNF()),
#  IncreaseAmount(FADD(), TNF()),
#  Inhibition(FADD(), TNF()),
#  Activation(FADD(), TNF()),
#  Inhibition(FADD(), BID()),
#  Activation(FADD(), BID()),
#  Inhibition(FADD(bound: [S116, True], bound: [PEA15, True]), apoptotic process()),
#  Activation(FADD(muts: (S, 191, D)), apoptotic process()),
#  Inhibition(FADD(bound: [PEA15, True]), apoptotic process()),
#  Activation(FADD(bound: [Death Domain, True]), apoptotic process()),
#  Inhibition(FADD(muts: (None, None, None)), apoptotic process()),
#  Activation(FADD(muts: (S, 191, A)), apoptotic process()),
#  Activation(FADD(muts: (S, 194, E)), apoptotic process()),
#  Activation(FADD(bound: [CASP10, True]), apoptotic process()),
#  Activation(FADD(bound: [it, True]), apoptotic process()),
#  Activation(FADD(bound: [TRADD, True]), apoptotic process()),
#  Activation(FADD(bound: [procaspase 8, True]), apoptotic process()),
#  Inhibition(FADD(mods: (modification)), apoptotic process()),
#  Activation(FADD(bound: [caspase-8 form cytosolic, True]), apoptotic process()),
#  Activation(FADD(bound: [CASP8, True]), apoptotic process()),
#  Activation(FADD(bound: [ATG13, True]), apoptotic process()),
#  Activation(FADD(bound: [MYD88, True]), apoptotic process()),
#  Activation(FADD(bound: [TNFRSF1A, True]), apoptotic process()),
#  Activation(FADD(bound: [death domain, True]), apoptotic process()),
#  Activation(FADD(bound: [Death_receptor, True]), apoptotic process()),
#  Activation(FADD(muts: (None, None, None)), apoptotic process()),
#  Activation(FADD(), apoptotic process()),
#  Inhibition(FADD(), apoptotic process()),
#  Activation(apoptosome(), BAX()),
#  Inhibition(apoptosome(), FADD()),
#  Complex(apoptosome(), CYCS()),
#  Activation(apoptosome(), CYCS()),
#  Activation(apoptosome(activity), CASP9()),
#  Activation(apoptosome(), CASP9()),
#  Complex(apoptosome(), CASP9()),
#  Activation(apoptosome(), CASP7()),
#  Complex(apoptosome(), CASP3()),
#  Activation(apoptosome(), CASP3()),
#  Inhibition(apoptosome(), FAS()),
#  Activation(apoptosome(), apoptotic process()),
#  Phosphorylation(MAPK14(), BCL2L11()),
#  Activation(MAPK14(), BCL2L11()),
#  Activation(MAPK14(), BCL2L1()),
#  Phosphorylation(MAPK14(), BCL2L1()),
#  Inhibition(MAPK14(), BCL2L1()),
#  Complex(MAPK14(), BCL2L1()),
#  Phosphorylation(MAPK14(), BCL2L1(), S, 62),
#  Activation(MAPK14(), BCL2()),
#  Phosphorylation(MAPK14(), BCL2(), S, 87),
#  Phosphorylation(MAPK14(), BCL2(), T, 56),
#  Inhibition(MAPK14(), BCL2()),
#  Complex(MAPK14(), BCL2()),
#  Phosphorylation(MAPK14(), BCL2()),
#  IncreaseAmount(MAPK14(), BAX()),
#  Activation(MAPK14(kinase), BAX(), catalytic),
#  Phosphorylation(MAPK14(), BAX()),
#  Inhibition(MAPK14(), BAX()),
#  Activation(MAPK14(), BAX()),
#  Activation(MAPK14(), MCL1()),
#  IncreaseAmount(MAPK14(), BBC3()),
#  Inhibition(MAPK14(), BBC3()),
#  Phosphorylation(MAPK14(), CASP9()),
#  Inhibition(MAPK14(), CASP9()),
#  Inhibition(MAPK14(), CASP8()),
#  Phosphorylation(MAPK14(kinase), CASP8(), S, 347),
#  DecreaseAmount(MAPK14(), CASP8()),
#  Phosphorylation(MAPK14(), CASP8(), S, 347),
#  Activation(MAPK14(), CASP8()),
#  Phosphorylation(MAPK14(), CASP8()),
#  Activation(MAPK14(kinase), CASP3(), catalytic),
#  Activation(MAPK14(), CASP3()),
#  Phosphorylation(MAPK14(kinase), CASP3(), S, 150),
#  DecreaseAmount(MAPK14(), CASP3()),
#  IncreaseAmount(MAPK14(), CASP3()),
#  Phosphorylation(MAPK14(), CASP3()),
#  Inhibition(MAPK14(), CASP3()),
#  Phosphorylation(MAPK14(), CASP3(), S, 150),
#  DecreaseAmount(MAPK14(), CASP3(muts: (S, 150, A))),
#  Activation(MAPK14(), FASLG()),
#  IncreaseAmount(MAPK14(), FASLG()),
#  Activation(MAPK14(), TNF()),
#  IncreaseAmount(MAPK14(), TNF()),
#  DecreaseAmount(MAPK14(), TNF()),
#  Inhibition(MAPK14(), TNF()),
#  Activation(MAPK14(), apoptotic process()),
#  Inhibition(MAPK14(), apoptotic process()),
#  Activation(MAPK14(), AKT()),
#  Inhibition(MAPK14(), AKT()),
#  Phosphorylation(MAPK14(), AKT()),
#  Complex(MCL1(), BCL2L11(), 2A()),
#  Complex(MCL1(), BCL2L11(), 24h()),
#  IncreaseAmount(MCL1(mods: (modification)), BCL2L11()),
#  Complex(MCL1(), BCL2L11(), runx1()),
#  Complex(MCL1(), BCL2L11(), BI()),
#  Phosphorylation(MCL1(), BCL2L11(), S, 87),
#  Phosphorylation(MCL1(mods: (modification)), BCL2L11()),
#  Complex(MCL1(), BCL2L11(muts: (None, None, None)), 2A()),
#  DecreaseAmount(MCL1(), BCL2L11()),
#  Inhibition(MCL1(bound: [it, True]), BCL2L11()),
#  Dephosphorylation(MCL1(), BCL2L11(), S, 69),
#  Complex(MCL1(), BCL2L11(), glutamine()),
#  IncreaseAmount(MCL1(), BCL2L11()),
#  Complex(MCL1(), BCL2L11(), ABT()),
#  IncreaseAmount(MCL1(bound: [BCL2L11, True]), BCL2L11()),
#  Complex(MCL1(), BCL2L11(), A1()),
#  Activation(MCL1(), BCL2L11()),
#  Complex(MCL1(), BCL2L11()),
#  Inhibition(MCL1(), BCL2L11()),
#  DecreaseAmount(MCL1(), BCL2L1()),
#  Phosphorylation(MCL1(), BCL2L1()),
#  Complex(MCL1(), BCL2L1(), A1()),
#  Complex(MCL1(), BCL2L1(), JY-1-106()),
#  Inhibition(MCL1(mods: (modification)), BCL2L1()),
#  Complex(MCL1(), BCL2L1(), Multiple Myeloma()),
#  Complex(MCL1(), BCL2L1(), BCL2L11(), BCL2-related protein-11()),
#  Complex(MCL1(), BCL2L1(), BCL2L2()),
#  Activation(MCL1(), BCL2L1()),
#  Inhibition(MCL1(), BCL2L1()),
#  Complex(MCL1(), BCL2L1(), BCL2L11()),
#  Complex(MCL1(), BCL2L1()),
#  Dephosphorylation(MCL1(), BCL2()),
#  Activation(MCL1(bound: [BCL2L11, True]), BCL2()),
#  Inhibition(MCL1(mods: (modification)), BCL2()),
#  DecreaseAmount(MCL1(mods: (modification)), BCL2()),
#  Complex(MCL1(), BCL2(), BCL2L1(), Death Domain()),
#  IncreaseAmount(MCL1(mods: (modification)), BCL2()),
#  Complex(MCL1(), BCL2(), Multiple Myeloma()),
#  Complex(MCL1(), BCL2(), BCL2L2()),
#  Activation(MCL1(mods: (modification)), BCL2()),
#  Complex(MCL1(), BCL2(), BCL2L2(), FlaG()),
#  Complex(MCL1(), BCL2(), BCL2A1()),
#  DecreaseAmount(MCL1(), BCL2()),
#  Phosphorylation(MCL1(), BCL2()),
#  Phosphorylation(MCL1(), BCL2(), T, 56),
#  IncreaseAmount(MCL1(), BCL2()),
#  Complex(MCL1(), BCL2(), BCL2L11()),
#  Inhibition(MCL1(), BCL2()),
#  Activation(MCL1(), BCL2()),
#  Complex(MCL1(), BCL2(), BCL2L1()),
#  Complex(MCL1(), BCL2()),
#  Complex(MCL1(), BAX(bound: [BAK1, True])),
#  Complex(MCL1(), BAX(), BCL2L11()),
#  Activation(MCL1(bound: [BCL2L11, True]), BAX()),
#  Inhibition(MCL1(), BAX(bound: [BAK1, True])),
#  Inhibition(MCL1(bound: [BAK1, True]), BAX()),
#  Inhibition(MCL1(catalytic), BAX(), catalytic),
#  DecreaseAmount(MCL1(mods: (modification)), BAX()),
#  IncreaseAmount(MCL1(), BAX()),
#  DecreaseAmount(MCL1(), BAX()),
#  Complex(MCL1(), BAX(), serine()),
#  IncreaseAmount(MCL1(mods: (modification)), BAX()),
#  Activation(MCL1(mods: (modification)), BAX()),
#  Complex(MCL1(), BAX(), BCL2()),
#  Complex(MCL1(), BAX(), BCL2L1()),
#  Activation(MCL1(), BAX()),
#  Complex(MCL1(), BAX()),
#  Inhibition(MCL1(), BAX()),
#  Activation(MCL1(), BAD()),
#  Complex(MCL1(), BAD(), BCL2L1()),
#  Complex(MCL1(), BAD(), BCL2A1()),
#  Complex(MCL1(), BAD(), A1()),
#  Phosphorylation(MCL1(), BAD()),
#  DecreaseAmount(MCL1(), BAD()),
#  Inhibition(MCL1(), BAD()),
#  Complex(MCL1(), BAD()),
#  Inhibition(MCL1(bound: [BAK1, True]), CYCS()),
#  Inhibition(MCL1(), CYCS()),
#  Inhibition(MCL1(mods: (modification)), CYCS()),
#  Activation(MCL1(), CYCS()),
#  IncreaseAmount(MCL1(), BBC3()),
#  Inhibition(MCL1(), BBC3()),
#  Activation(MCL1(), BBC3()),
#  Inhibition(MCL1(mods: (modification)), CASP9()),
#  Activation(MCL1(), CASP9()),
#  Inhibition(MCL1(), CASP9()),
#  Activation(MCL1(), CASP8()),
#  Inhibition(MCL1(), CASP8()),
#  Inhibition(MCL1(), CASP7()),
#  IncreaseAmount(MCL1(), CASP3()),
#  Activation(MCL1(), CASP3()),
#  Inhibition(MCL1(), CASP3()),
#  IncreaseAmount(MCL1(mods: (modification)), FASLG()),
#  Inhibition(MCL1(), FASLG()),
#  Inhibition(MCL1(), FAS()),
#  IncreaseAmount(MCL1(), FAS()),
#  Inhibition(MCL1(), TNF()),
#  Activation(MCL1(), TNF()),
#  DecreaseAmount(MCL1(), BID()),
#  Activation(MCL1(mods: (modification)), BID()),
#  Activation(MCL1(), BID()),
#  Inhibition(MCL1(), BID()),
#  Activation(MCL1(bound: [IP3R, True]), apoptotic process()),
#  Inhibition(MCL1(bound: [BBC3, True]), apoptotic process()),
#  Activation(MCL1(bound: [their, True]), apoptotic process()),
#  Activation(MCL1(bound: [MFF, True]), apoptotic process()),
#  Conversion(MCL1(), [TUMOR-CELLS()], [apoptotic process()]),
#  Activation(MCL1(bound: [BCL2L11, True]), apoptotic process()),
#  Inhibition(MCL1(bound: [BCL2, True]), apoptotic process()),
#  Inhibition(MCL1(bound: [BAK1, True]), apoptotic process()),
#  Inhibition(MCL1(bound: [HSPA8, True]), apoptotic process()),
#  Inhibition(MCL1(bound: [BCL2L11, True]), apoptotic process()),
#  Activation(MCL1(bound: [it, True]), apoptotic process()),
#  Inhibition(MCL1(bound: [BAX, True]), apoptotic process()),
#  Inhibition(MCL1(mods: (modification)), apoptotic process()),
#  Activation(MCL1(bound: [PMAIP1, True]), apoptotic process()),
#  Inhibition(MCL1(muts: (T, 92, A)), apoptotic process()),
#  Inhibition(MCL1(bound: [killer, True]), apoptotic process()),
#  Inhibition(MCL1(), apoptotic process()),
#  Activation(MCL1(), apoptotic process()),
#  Activation(MCL1(), AKT(mods: (phosphorylation))),
#  Inhibition(MCL1(bound: [AKT, True]), AKT()),
#  Phosphorylation(MCL1(), AKT()),
#  Activation(MCL1(bound: [AKT, True]), AKT()),
#  Inhibition(MCL1(), AKT()),
#  Activation(MCL1(), AKT()),
#  DecreaseAmount(BAD(), BCL2L11()),
#  Activation(BAD(), BCL2L11()),
#  Complex(BAD(), BCL2L11()),
#  Inhibition(BAD(), BCL2L11()),
#  Complex(BAD(), BCL2L1(), Ser-112()),
#  Complex(BAD(), BCL2L1(), BCL2-related protein-11()),
#  Inhibition(BAD(bound: [BCL2L1, True]), BCL2L1()),
#  Complex(BAD(), BCL2L1(), BH3 domain()),
#  DecreaseAmount(BAD(mods: (phosphorylation)), BCL2L1()),
#  Inhibition(BAD(mods: (phosphorylation)), BCL2L1()),
#  DecreaseAmount(BAD(mods: (modification)), BCL2L1()),
#  Complex(BAD(), BCL2L1(), Ser-136()),
#  Inhibition(BAD(bound: [p14_3_3, True]), BCL2L1()),
#  IncreaseAmount(BAD(mods: (modification)), BCL2L1()),
#  Complex(BAD(mods: (phosphorylation)), BCL2L1()),
#  Complex(BAD(), BCL2L1(), BCL2L2()),
#  Phosphorylation(BAD(), BCL2L1()),
#  IncreaseAmount(BAD(), BCL2L1()),
#  Activation(BAD(bound: [BCL2L1, True]), BCL2L1()),
#  IncreaseAmount(BAD(mods: (phosphorylation)), BCL2L1()),
#  Complex(BAD(), BCL2L1(), Ser-155()),
#  Complex(BAD(), BCL2L1(), BCL2L11()),
#  Inhibition(BAD(), BCL2L1()),
#  Activation(BAD(), BCL2L1()),
#  Complex(BAD(), BCL2L1()),
#  Complex(BAD(muts: (None, None, None)), BCL2()),
#  Complex(BAD(), BCL2(), serine()),
#  Activation(BAD(mods: (phosphorylation, False)), BCL2()),
#  Inhibition(BAD(bound: [p14_3_3, True]), BCL2()),
#  Complex(BAD(), BCL2(), HBP()),
#  Complex(BAD(), BCL2(), Ser-155()),
#  Complex(BAD(), BCL2(), A375()),
#  Inhibition(BAD(bound: [BCL2, True]), BCL2()),
#  IncreaseAmount(BAD(mods: (modification)), BCL2()),
#  Phosphorylation(BAD(), BCL2()),
#  DecreaseAmount(BAD(mods: (phosphorylation)), BCL2()),
#  DecreaseAmount(BAD(), BCL2()),
#  IncreaseAmount(BAD(mods: (phosphorylation)), BCL2()),
#  IncreaseAmount(BAD(), BCL2()),
#  Inhibition(BAD(bound: [BAX, True]), BCL2()),
#  Complex(BAD(), BCL2(), BH3 domain()),
#  Complex(BAD(), BCL2(), BCL2L11()),
#  Activation(BAD(mods: (phosphorylation)), BCL2()),
#  DecreaseAmount(BAD(mods: (modification)), BCL2()),
#  Inhibition(BAD(), BCL2()),
#  Complex(BAD(mods: (phosphorylation)), BCL2()),
#  Complex(BAD(), BCL2(), BCL2L1()),
#  Activation(BAD(), BCL2()),
#  Complex(BAD(), BCL2()),
#  DecreaseAmount(BAD(mods: (modification)), BAX()),
#  Activation(BAD(catalytic), BAX(), catalytic),
#  Activation(BAD(mods: (phosphorylation, False)), BAX()),
#  Activation(BAD(mods: (phosphorylation)), BAX()),
#  Inhibition(BAD(bound: [BCL2L1, True]), BAX()),
#  DecreaseAmount(BAD(), BAX()),
#  Inhibition(BAD(bound: [BCL2, True]), BAX()),
#  Complex(BAD(), BAX(), BCL2(), bcl-x()),
#  Activation(BAD(bound: [BCL2, True]), BAX()),
#  IncreaseAmount(BAD(), BAX()),
#  Complex(BAD(), BAX(), NP1()),
#  Complex(BAD(), BAX(), NP1(), OGD()),
#  Activation(BAD(bound: [BCL2L1, True]), BAX()),
#  IncreaseAmount(BAD(mods: (modification)), BAX()),
#  Phosphorylation(BAD(), BAX()),
#  Dephosphorylation(BAD(), BAX()),
#  Inhibition(BAD(), BAX()),
#  Activation(BAD(), BAX()),
#  Complex(BAD(), BAX()),
#  Complex(BAD(), BAX(), BCL2L1()),
#  Inhibition(BAD(mods: (phosphorylation)), BAX()),
#  Complex(BAD(), BAX(), BCL2()),
#  Phosphorylation(BAD(), MCL1()),
#  Inhibition(BAD(), MCL1()),
#  Activation(BAD(), MCL1()),
#  DecreaseAmount(BAD(mods: (modification)), CYCS()),
#  Inhibition(BAD(mods: (phosphorylation)), CYCS()),
#  IncreaseAmount(BAD(mods: (modification)), CYCS()),
#  Inhibition(BAD(), CYCS()),
#  Activation(BAD(mods: (phosphorylation, False)), CYCS()),
#  Phosphorylation(BAD(), CYCS()),
#  Activation(BAD(), CYCS()),
#  DecreaseAmount(BAD(mods: (modification)), CASP9()),
#  IncreaseAmount(BAD(), CASP9()),
#  Dephosphorylation(BAD(), CASP9()),
#  Activation(BAD(), CASP9()),
#  Inhibition(BAD(), CASP9()),
#  Activation(BAD(), CASP8()),
#  Inhibition(BAD(), CASP8()),
#  IncreaseAmount(BAD(mods: (modification)), CASP3()),
#  Phosphorylation(BAD(), CASP3()),
#  Activation(BAD(), CASP3()),
#  Inhibition(BAD(), CASP3()),
#  Activation(BAD(), FASLG()),
#  IncreaseAmount(BAD(), FASLG()),
#  Inhibition(BAD(), FAS()),
#  IncreaseAmount(BAD(), FAS()),
#  Activation(BAD(), FAS()),
#  Activation(BAD(), TNF()),
#  Inhibition(BAD(), TNF()),
#  IncreaseAmount(BAD(), BID()),
#  Inhibition(BAD(), BID()),
#  Activation(BAD(), BID()),
#  Activation(BAD(mods: (modification)), apoptotic process()),
#  Activation(BAD(bound: [TP53, True]), apoptotic process()),
#  Inhibition(BAD(bound: [14-3-3beta, True]), apoptotic process()),
#  Activation(BAD(muts: (S, 113, A)), apoptotic process()),
#  Activation(BAD(mods: (phosphorylation)), apoptotic process()),
#  Inhibition(BAD(bound: [BCL2, True]), apoptotic process()),
#  Activation(BAD(mods: (phosphorylation, False)), apoptotic process()),
#  Activation(BAD(bound: [BCL2L1, True]), apoptotic process()),
#  Activation(BAD(muts: (S, 112, A)), apoptotic process()),
#  Activation(BAD(bound: [BCL2, True]), apoptotic process()),
#  Activation(BAD(muts: (None, None, None)), apoptotic process()),
#  Inhibition(BAD(muts: (None, None, None)), apoptotic process()),
#  Inhibition(BAD(mods: (phosphorylation)), apoptotic process()),
#  Inhibition(BAD(), apoptotic process()),
#  Activation(BAD(), apoptotic process()),
#  Phosphorylation(BAD(mods: (phosphorylation, S, 118)), AKT(), S, 99),
#  Phosphorylation(BAD(), AKT(), S, 136),
#  Inhibition(BAD(), AKT()),
#  Phosphorylation(BAD(), AKT(), T, 308),
#  Phosphorylation(BAD(), AKT(), S, 473),
#  Inhibition(BAD(), AKT(mods: (phosphorylation))),
#  Phosphorylation(BAD(mods: (phosphorylation)), AKT()),
#  DecreaseAmount(BAD(), AKT()),
#  DecreaseAmount(BAD(mods: (modification)), AKT()),
#  Phosphorylation(BAD(), AKT()),
#  Activation(BAD(), AKT()),
#  DecreaseAmount(BAD(), AKT(mods: (phosphorylation))),
#  Complex(BAX(), BCL2L11(), BH3 domain()),
#  Complex(BAX(muts: (S, 184, E)), BCL2L11()),
#  Complex(BAX(), BCL2L11(), a6()),
#  Complex(BAX(bound: [BAK1, True]), BCL2L11()),
#  IncreaseAmount(BAX(), BCL2L11()),
#  Complex(BAX(), BCL2L11(mods: (phosphorylation))),
#  Inhibition(BAX(), BCL2L11()),
#  Complex(BAX(), BCL2L11(), BH3()),
#  Activation(BAX(), BCL2L11()),
#  Complex(BAX(), BCL2L11(), CbiD()),
#  Complex(BAX(), BCL2L11()),
#  Complex(BAX(activity: False), BCL2L1()),
#  Complex(BAX(), BCL2L1(), hspX()),
#  Complex(BAX(), BCL2L1(), ABT()),
#  IncreaseAmount(BAX(mods: (modification)), BCL2L1()),
#  Complex(BAX(), BCL2L1(), tos()),
#  IncreaseAmount(BAX(bound: [BBC3, True]), BCL2L1()),
#  Complex(BAX(), BCL2L1(), BH3 domains()),
#  Complex(BAX(), BCL2L1(), BCL2L11()),
#  DecreaseAmount(BAX(), BCL2L1()),
#  DecreaseAmount(BAX(mods: (modification)), BCL2L1()),
#  Complex(BAX(), BCL2L1(), Ser-62()),
#  Complex(BAX(), BCL2L1(), CbiD()),
#  IncreaseAmount(BAX(), BCL2L1()),
#  Activation(BAX(), BCL2L1()),
#  Inhibition(BAX(), BCL2L1()),
#  Complex(BAX(), BCL2L1()),
#  Complex(BAX(), BCL2(), Ku()),
#  Complex(BAX(), BCL2(), B-H1()),
#  Complex(BAX(), BCL2(), H146()),
#  Complex(BAX(), BCL2(), SAHB domains()),
#  Complex(BAX(), BCL2(), mtnN()),
#  Complex(BAX(location: nucleus), BCL2(location: nucleus)),
#  Inhibition(BAX(mods: (modification)), BCL2()),
#  Complex(BAX(), BCL2(), virulence factor()),
#  Complex(BAX(), BCL2(), BIM1()),
#  Complex(BAX(), BCL2(), aspartate()),
#  Activation(BAX(muts: (V, 177, C)), BCL2()),
#  Complex(BAX(), BCL2(), BH4 domain()),
#  Methylation(BAX(), BCL2()),
#  Complex(BAX(), BCL2(), rnh()),
#  Complex(BAX(), BCL2(), BH4()),
#  Complex(BAX(), BCL2(mods: (phosphorylation))),
#  Phosphorylation(BAX(), BCL2()),
#  Complex(BAX(), BCL2(), Oestrogen receptor()),
#  Inhibition(BAX(bound: [ABT-737, True]), BCL2()),
#  Complex(BAX(), BCL2(), Ptpn2()),
#  Complex(BAX(), BCL2(), RAD9()),
#  Complex(BAX(), BCL2(), BCL2L1(), TM()),
#  Activation(BAX(mods: (modification)), BCL2()),
#  Complex(BAX(), BCL2(), Reperfusion Injury()),
#  Complex(BAX(), BCL2(), A1()),
#  Complex(BAX(), BCL2(), bcl-x()),
#  Complex(BAX(), BCL2(), ANT()),
#  Complex(BAX(), BCL2(), eg()),
#  Complex(BAX(), BCL2(), ami(), HF()),
#  Complex(BAX(), BCL2(), BCL2L1(), ion channel()),
#  Inhibition(BAX(bound: [BCL2, True]), BCL2()),
#  Complex(BAX(), BCL2(), BCL2L2()),
#  Complex(BAX(bound: [BAK1, True]), BCL2()),
#  Complex(BAX(), BCL2(), divIC()),
#  Complex(BAX(), BCL2(), DRG()),
#  Complex(BAX(), BCL2(), BCL2L11()),
#  Complex(BAX(), BCL2(), PTP()),
#  Complex(BAX(), BCL2(), scrib()),
#  Complex(BAX(), BCL2(), MOM1()),
#  Complex(BAX(activity), BCL2()),
#  Complex(BAX(), BCL2(), kaiso()),
#  Complex(BAX(), BCL2(), E1B 19K()),
#  IncreaseAmount(BAX(mods: (modification)), BCL2()),
#  Complex(BAX(), BCL2(), ion channel()),
#  Complex(BAX(), BCL2(), BH3 domain()),
#  DecreaseAmount(BAX(), BCL2()),
#  Complex(BAX(), BCL2(), BCL2L1(), \\u03b1B-crystallin()),
#  DecreaseAmount(BAX(mods: (modification)), BCL2()),
#  Activation(BAX(), BCL2()),
#  Complex(BAX(), BCL2(), BCL2L1()),
#  Inhibition(BAX(), BCL2()),
#  IncreaseAmount(BAX(), BCL2()),
#  Complex(BAX(), BCL2()),
#  IncreaseAmount(BAX(), BAD()),
#  Phosphorylation(BAX(), BAD()),
#  Inhibition(BAX(), BAD()),
#  Activation(BAX(), BAD()),
#  DecreaseAmount(BAX(), MCL1()),
#  DecreaseAmount(BAX(mods: (modification)), MCL1()),
#  IncreaseAmount(BAX(mods: (modification)), MCL1()),
#  Activation(BAX(bound: [BAK1, True]), MCL1()),
#  IncreaseAmount(BAX(), MCL1()),
#  Inhibition(BAX(), MCL1()),
#  Activation(BAX(), MCL1()),
#  Activation(BAX(bound: [MCL1, True]), MCL1()),
#  Activation(BAX(), MAPK14()),
#  DecreaseAmount(BAX(), FADD()),
#  Inhibition(BAX(bound: [MUC1, True]), FADD()),
#  Activation(BAX(bound: [voltage-dependent anion channel, True]), CYCS()),
#  Activation(BAX(mods: (modification)), CYCS()),
#  Inhibition(BAX(bound: [It, True]), CYCS()),
#  Activation(BAX(muts: (P, 168, G)), CYCS()),
#  Activation(BAX(mods: (phosphorylation)), CYCS()),
#  Inhibition(BAX(bound: [HSPA, True]), CYCS()),
#  Activation(BAX(bound: [BCL2, True]), CYCS()),
#  Inhibition(BAX(bound: [BCL2, True]), CYCS()),
#  Activation(BAX(bound: [it, True]), CYCS()),
#  IncreaseAmount(BAX(mods: (modification)), CYCS()),
#  Inhibition(BAX(mods: (modification)), CYCS()),
#  DecreaseAmount(BAX(), CYCS()),
#  Activation(BAX(bound: [BCL2L11, True]), CYCS()),
#  Activation(BAX(bound: [BAK1, True]), CYCS()),
#  Activation(BAX(bound: [VDAC1, True]), CYCS()),
#  Inhibition(BAX(bound: [BCL2L1, True]), CYCS()),
#  IncreaseAmount(BAX(), CYCS()),
#  DecreaseAmount(BAX(mods: (modification)), CYCS()),
#  Inhibition(BAX(), CYCS()),
#  Activation(BAX(), CYCS()),
#  IncreaseAmount(BAX(), BBC3()),
#  Inhibition(BAX(), BBC3()),
#  DecreaseAmount(BAX(), BBC3()),
#  Activation(BAX(), BBC3()),
#  Inhibition(BAX(mods: (modification)), CASP9()),
#  Ubiquitination(BAX(), CASP9()),
#  DecreaseAmount(BAX(mods: (modification)), CASP9()),
#  IncreaseAmount(BAX(mods: (modification)), CASP9()),
#  DecreaseAmount(BAX(), CASP9()),
#  IncreaseAmount(BAX(), CASP9()),
#  Inhibition(BAX(), CASP9()),
#  Activation(BAX(), CASP9()),
#  IncreaseAmount(BAX(), CASP8()),
#  DecreaseAmount(BAX(), CASP8()),
#  Activation(BAX(), CASP8()),
#  Inhibition(BAX(), CASP8()),
#  Inhibition(BAX(), CASP7()),
#  Activation(BAX(), CASP7()),
#  DecreaseAmount(BAX(), CASP7()),
#  Activation(BAX(bound: [BCL2, True]), CASP3()),
#  Inhibition(BAX(bound: [BCL2L1, True]), CASP3()),
#  DecreaseAmount(BAX(), CASP3()),
#  Inhibition(BAX(mods: (modification)), CASP3()),
#  DecreaseAmount(BAX(mods: (modification)), CASP3()),
#  IncreaseAmount(BAX(mods: (modification)), CASP3()),
#  Activation(BAX(bound: [SH3GLB1, True]), CASP3()),
#  Inhibition(BAX(), CASP3()),
#  Activation(BAX(), CASP3()),
#  IncreaseAmount(BAX(), CASP3()),
#  DecreaseAmount(BAX(), TRADD()),
#  Activation(BAX(), FASLG()),
#  DecreaseAmount(BAX(), FASLG()),
#  Inhibition(BAX(), FAS()),
#  DecreaseAmount(BAX(), FAS()),
#  IncreaseAmount(BAX(), FAS()),
#  Activation(BAX(), FAS()),
#  Activation(BAX(), TNFRSF1A()),
#  DecreaseAmount(BAX(), TNF()),
#  Activation(BAX(), TNF()),
#  IncreaseAmount(BAX(), TNF()),
#  Inhibition(BAX(), TNF()),
#  Inhibition(BAX(), BID()),
#  IncreaseAmount(BAX(), BID()),
#  Activation(BAX(), BID()),
#  Inhibition(BAX(), apoptosome()),
#  Activation(BAX(), apoptosome()),
#  Activation(BAX(bound: [ERN1, True]), apoptotic process()),
#  Inhibition(BAX(bound: [BCL2L10, True]), apoptotic process()),
#  Inhibition(BAX(bound: [VDAC1, True]), apoptotic process()),
#  Activation(BAX(muts: (E, 69, A)), apoptotic process()),
#  IncreaseAmount(BAX(), apoptotic process()),
#  Inhibition(BAX(mods: (modification)), apoptotic process()),
#  Activation(BAX(muts: (D, 68, A)), apoptotic process()),
#  Activation(BAX(bound: [TP73, True]), apoptotic process()),
#  Activation(BAX(bound: [It, True]), apoptotic process()),
#  Activation(BAX(bound: [proteins, True]), apoptotic process()),
#  Conversion(BAX(), [CELL()], [apoptotic process()]),
#  Activation(BAX(bound: [SMBA(s), True]), apoptotic process()),
#  Activation(BAX(bound: [PRPF6, True]), apoptotic process()),
#  Activation(BAX(bound: [BAK1, True]), apoptotic process()),
#  Inhibition(BAX(bound: [They, True]), apoptotic process()),
#  Activation(BAX(muts: (S, 184, V)), apoptotic process()),
#  Activation(BAX(bound: [SH3GLB1, True]), apoptotic process()),
#  Inhibition(BAX(bound: [Ser-62, True], bound: [BCL2L1, True]), apoptotic process()),
#  Inhibition(BAX(bound: [CRYAA, True]), apoptotic process()),
#  Inhibition(BAX(muts: (L, 63, E)), apoptotic process()),
#  Activation(BAX(bound: [CYD-2-11, True]), apoptotic process()),
#  Inhibition(BAX(bound: [Kv1.3, True]), apoptotic process()),
#  Inhibition(BAX(bound: [HSPD1, True]), apoptotic process()),
#  Activation(BAX(muts: (P, 168, G)), apoptotic process()),
#  Activation(BAX(bound: [XRCC6, True]), apoptotic process()),
#  Inhibition(BAX(bound: [XRCC6, True]), apoptotic process()),
#  Activation(BAX(bound: [VDAC1, True]), apoptotic process()),
#  Inhibition(BAX(bound: [CLU, True]), apoptotic process()),
#  Inhibition(BAX(muts: (None, None, None)), apoptotic process()),
#  Inhibition(BAX(bound: [NS5A, True]), apoptotic process()),
#  Activation(BAX(muts: (D, 68, R)), apoptotic process()),
#  Activation(BAX(mods: (modification)), apoptotic process()),
#  Inhibition(BAX(bound: [BAK1, True]), apoptotic process()),
#  Activation(BAX(muts: (G, 179, E)), apoptotic process()),
#  Activation(BAX(mods: (phosphorylation, S, 184)), apoptotic process()),
#  Inhibition(BAX(bound: [Bcl-x L  proteins, True]), apoptotic process()),
#  Activation(BAX(location: mitochondrion), apoptotic process()),
#  Activation(BAX(bound: [Bim SABH, True]), apoptotic process()),
#  Inhibition(BAX(bound: [BCL2L11, True]), apoptotic process()),
#  Inhibition(BAX(bound: [YWHAZ, True]), apoptotic process()),
#  Activation(BAX(muts: (None, None, None)), apoptotic process()),
#  Inhibition(BAX(bound: [BCL2L1, True]), apoptotic process()),
#  Activation(BAX(bound: [BCL2, True]), apoptotic process()),
#  Activation(BAX(bound: [it, True]), apoptotic process()),
#  Activation(BAX(muts: (S, 184, A)), apoptotic process()),
#  Inhibition(BAX(bound: [BCL2, True]), apoptotic process()),
#  Inhibition(BAX(), apoptotic process()),
#  Activation(BAX(), apoptotic process()),
#  Phosphorylation(BAX(), AKT(), D, 1),
#  Activation(BAX(bound: [CRYAA, True]), AKT()),
#  DecreaseAmount(BAX(mods: (modification)), AKT(mods: (phosphorylation))),
#  Phosphorylation(BAX(), AKT(mods: (phosphorylation))),
#  Activation(BAX(), AKT(mods: (phosphorylation))),
#  Inhibition(BAX(bound: [XRCC6, True]), AKT()),
#  DecreaseAmount(BAX(), AKT(mods: (phosphorylation))),
#  Dephosphorylation(BAX(mods: (modification)), AKT()),
#  Activation(BAX(), AKT()),
#  Phosphorylation(BAX(mods: (modification)), AKT()),
#  IncreaseAmount(BAX(mods: (modification)), AKT(mods: (phosphorylation))),
#  Phosphorylation(BAX(), AKT()),
#  IncreaseAmount(BAX(), AKT()),
#  Dephosphorylation(BAX(), AKT()),
#  IncreaseAmount(BAX(), AKT(mods: (phosphorylation))),
#  Inhibition(BAX(), AKT(mods: (phosphorylation))),
#  Inhibition(BAX(), AKT()),
#  Inhibition(BCL2(bound: [BCL2L1, True]), BCL2L11()),
#  Inhibition(BCL2(bound: [BCL2L11, True]), BCL2L11()),
#  Complex(BCL2(), BCL2L11(), glutamine()),
#  Complex(BCL2(), BCL2L11(), panC()),
#  Complex(BCL2(muts: (S, 70, A)), BCL2L11()),
#  Complex(BCL2(), BCL2L11(), Receptors, Antigen, B-Cell()),
#  Activation(BCL2(bound: [BCL2L11, True]), BCL2L11()),
#  Complex(BCL2(), BCL2L11(), L363()),
#  Complex(BCL2(muts: (S, 70, E)), BCL2L11()),
#  IncreaseAmount(BCL2(mods: (modification)), BCL2L11()),
#  DecreaseAmount(BCL2(mods: (modification)), BCL2L11()),
#  DecreaseAmount(BCL2(), BCL2L11()),
#  Activation(BCL2(), BCL2L11()),
#  Complex(BCL2(), BCL2L11(mods: (phosphorylation))),
#  Complex(BCL2(), BCL2L11(), vIRF-1()),
#  IncreaseAmount(BCL2(), BCL2L11()),
#  Complex(BCL2(), BCL2L11()),
#  Inhibition(BCL2(), BCL2L11()),
#  Complex(BCL2(), BCL2L1(), BCL2L2(), BH4()),
#  Complex(BCL2(), BCL2L1(), tmd()),
#  Complex(BCL2(), BCL2L1(), GK()),
#  Complex(BCL2(), BCL2L1(), RyR()),
#  Complex(BCL2(), BCL2L1(), atg6()),
#  DecreaseAmount(BCL2(mods: (modification)), BCL2L1()),
#  Complex(BCL2(), BCL2L1(), Multiple Myeloma()),
#  Complex(BCL2(), BCL2L1(), NCIT:C17764()),
#  Complex(BCL2(), BCL2L1(), p4()),
#  Complex(BCL2(), BCL2L1(), Harakiri()),
#  Activation(BCL2(bound: [BAD, True]), BCL2L1()),
#  Complex(BCL2(), BCL2L1(), BH4()),
#  Complex(BCL2(), BCL2L1(), PTP()),
#  Complex(BCL2(), BCL2L1(), BCL2L11(), BCL2-related protein-11(), BCL2-related protein-11()),
#  Complex(BCL2(), BCL2L1(), GT()),
#  Complex(BCL2(), BCL2L1(), NH()),
#  Complex(BCL2(), BCL2L1(), beclin family()),
#  IncreaseAmount(BCL2(), BCL2L1()),
#  IncreaseAmount(BCL2(mods: (modification)), BCL2L1()),
#  Complex(BCL2(), BCL2L1(), F1L(), N1L()),
#  Complex(BCL2(), BCL2L1(), RAD9()),
#  Complex(BCL2(), BCL2L1(), ryanodine receptor()),
#  Complex(BCL2(), BCL2L1(), thrB(), antp(), ter()),
#  DecreaseAmount(BCL2(), BCL2L1()),
#  Complex(BCL2(), BCL2L1(), thrB()),
#  Complex(BCL2(), BCL2L1(), BCL2-related protein-11()),
#  Phosphorylation(BCL2(), BCL2L1()),
#  Inhibition(BCL2(), BCL2L1()),
#  Complex(BCL2(), BCL2L1(), BH3 domain()),
#  Activation(BCL2(), BCL2L1()),
#  Complex(BCL2(), BCL2L1(), BCL2L2()),
#  Complex(BCL2(), BCL2L1(), HBx()),
#  Complex(BCL2(), BCL2L1(), BCL2L11()),
#  Complex(BCL2(), BCL2L1()),
#  Inhibition(BCL2(bound: [alpha-TOS, True]), BAX()),
#  Activation(BCL2(bound: [TP53, True]), BAX()),
#  Inhibition(BCL2(bound: [TNFRSF10B, True]), BAX()),
#  Inhibition(BCL2(bound: [proteins, True]), BAX()),
#  Inhibition(BCL2(bound: [BNIP3, True]), BAX()),
#  Activation(BCL2(), BAX(muts: (D, 68, R))),
#  Inhibition(BCL2(), BAX(bound: [BAK1, True])),
#  Inhibition(BCL2(), BAX(muts: (None, None, None))),
#  Activation(BCL2(bound: [tBid, True]), BAX()),
#  Inhibition(BCL2(bound: [ABT-737, True]), BAX()),
#  Activation(BCL2(bound: [BIM1, True]), BAX()),
#  Phosphorylation(BCL2(), BAX()),
#  IncreaseAmount(BCL2(mods: (phosphorylation)), BAX()),
#  Inhibition(BCL2(bound: [RTL10, True]), BAX()),
#  Activation(BCL2(bound: [BAD, True]), BAX()),
#  Inhibition(BCL2(muts: (None, None, None)), BAX()),
#  Dephosphorylation(BCL2(), BAX()),
#  Activation(BCL2(bound: [BCL2L11, True]), BAX()),
#  Activation(BCL2(bound: [alpha-TOS, True]), BAX()),
#  Activation(BCL2(bound: [BBC3, True]), BAX()),
#  Activation(BCL2(mods: (modification)), BAX()),
#  Activation(BCL2(bound: [BH3, True]), BAX()),
#  DecreaseAmount(BCL2(mods: (modification)), BAX()),
#  Activation(BCL2(bound: [BAX, True]), BAX()),
#  Activation(BCL2(bound: [its, True]), BAX()),
#  Inhibition(BCL2(bound: [BCL2L11, True]), BAX()),
#  Inhibition(BCL2(catalytic), BAX(), catalytic),
#  Inhibition(BCL2(mods: (modification)), BAX()),
#  IncreaseAmount(BCL2(mods: (modification)), BAX()),
#  DecreaseAmount(BCL2(), BAX()),
#  Inhibition(BCL2(bound: [BAX, True]), BAX()),
#  Activation(BCL2(), BAX()),
#  Inhibition(BCL2(), BAX()),
#  IncreaseAmount(BCL2(), BAX()),
#  DecreaseAmount(BCL2(mods: (modification)), BAD()),
#  Dephosphorylation(BCL2(mods: (modification)), BAD(), S, 99),
#  IncreaseAmount(BCL2(), BAD()),
#  DecreaseAmount(BCL2(), BAD()),
#  Dephosphorylation(BCL2(mods: (modification)), BAD()),
#  Dephosphorylation(BCL2(mods: (modification)), BAD(), S, 118),
#  Dephosphorylation(BCL2(), BAD()),
#  Phosphorylation(BCL2(), BAD()),
#  Inhibition(BCL2(), BAD()),
#  Activation(BCL2(), BAD()),
#  Inhibition(BCL2(bound: [BCL2L11, True]), MCL1()),
#  Activation(BCL2(bound: [4-[4-[[2-(4-chlorophenyl)-5,5-dimethyl-1-cyclohexenyl]methyl]-1-piperazinyl]-N-[4-[[(2R)-4-(4-morpholinyl)-1-(phenylthio)butan-2-yl]amino]-3-(trifluoromethylsulfonyl)phenyl]sulfonylbenzamide, True]), MCL1()),
#  IncreaseAmount(BCL2(mods: (modification)), MCL1()),
#  Activation(BCL2(bound: [ABT-737, True]), MCL1()),
#  Activation(BCL2(bound: [navitoclax, True]), MCL1()),
#  DecreaseAmount(BCL2(), MCL1()),
#  IncreaseAmount(BCL2(), MCL1()),
#  Phosphorylation(BCL2(), MCL1()),
#  DecreaseAmount(BCL2(mods: (modification)), MCL1()),
#  Activation(BCL2(), MCL1()),
#  Inhibition(BCL2(), MCL1()),
#  Phosphorylation(BCL2(), MAPK14()),
#  Phosphorylation(BCL2(), FADD()),
#  Inhibition(BCL2(), FADD()),
#  ...]

# %% [markdown]
# Looking at the statement above, we see a few issues. For example, INDRA picks up and represent n-ary complexes where n > 2 and these complexes can contain entities not in the original query set (i.e., outside the subnetwork) so it makes sense to filter these out. More generally, statements that are not binary (i.e., contain more than 2 agents like a metabolic conversion reaction or contain just 1 agent like an autophosphorylation) are not that relevant for Boolean modeling so we can filter these out.

# %%
stmts = [stmt for stmt in stmts if len(stmt.agent_list()) == 2]
stmts
# Out:
# [IncreaseAmount(BBC3(), BCL2L11()),
#  DecreaseAmount(BBC3(), BCL2L11()),
#  Inhibition(BBC3(), BCL2L11()),
#  Activation(BBC3(), BCL2L11()),
#  Complex(BBC3(), BCL2L11()),
#  Activation(BBC3(), BCL2L1(muts: (None, None, None))),
#  Activation(BBC3(), BCL2L1()),
#  Inhibition(BBC3(bound: [BCL2L1, True]), BCL2L1()),
#  Inhibition(BBC3(), BCL2L1()),
#  Complex(BBC3(), BCL2L1()),
#  Activation(BBC3(bound: [PMAIP1, True]), BCL2()),
#  IncreaseAmount(BBC3(mods: (modification)), BCL2()),
#  IncreaseAmount(BBC3(), BCL2()),
#  DecreaseAmount(BBC3(), BCL2()),
#  DecreaseAmount(BBC3(mods: (modification)), BCL2()),
#  Inhibition(BBC3(), BCL2()),
#  Activation(BBC3(), BCL2()),
#  Complex(BBC3(), BCL2()),
#  Activation(BBC3(bound: [TP53, True]), BAX()),
#  Activation(BBC3(bound: [BCL2, True]), BAX()),
#  Activation(BBC3(catalytic), BAX(), catalytic),
#  DecreaseAmount(BBC3(), BAX()),
#  Activation(BBC3(bound: [BCL2L1, True]), BAX()),
#  Activation(BBC3(bound: [proteins, True]), BAX()),
#  Activation(BBC3(bound: [PMAIP1, True]), BAX()),
#  Inhibition(BBC3(bound: [BCL2, True]), BAX()),
#  Activation(BBC3(bound: [Bcl-X(L), True]), BAX()),
#  Activation(BBC3(bound: [BCL2L11, True]), BAX()),
#  Activation(BBC3(bound: [Bim EL, True]), BAX()),
#  IncreaseAmount(BBC3(), BAX()),
#  Inhibition(BBC3(), BAX()),
#  Complex(BBC3(), BAX()),
#  Activation(BBC3(), BAX()),
#  Activation(BBC3(), BAD()),
#  Inhibition(BBC3(), BAD()),
#  Complex(BBC3(), BAD()),
#  IncreaseAmount(BBC3(), MCL1()),
#  Ubiquitination(BBC3(mods: (modification)), MCL1()),
#  Activation(BBC3(muts: (None, None, None)), MCL1()),
#  Ubiquitination(BBC3(), MCL1()),
#  DecreaseAmount(BBC3(), MCL1()),
#  Inhibition(BBC3(), MCL1()),
#  Activation(BBC3(), MCL1()),
#  Complex(BBC3(muts: (None, None, None)), MCL1()),
#  Complex(BBC3(), MCL1()),
#  Activation(BBC3(), FADD()),
#  Inhibition(BBC3(), FADD()),
#  Activation(BBC3(bound: [BCL2, True]), CYCS()),
#  Complex(BBC3(), CYCS()),
#  Activation(BBC3(bound: [BAX, True]), CYCS()),
#  Activation(BBC3(bound: [BCL2L1, True]), CYCS()),
#  Inhibition(BBC3(), CYCS()),
#  Activation(BBC3(), CYCS()),
#  Inhibition(BBC3(), CASP9()),
#  Activation(BBC3(), CASP9()),
#  Activation(BBC3(), CASP8()),
#  Inhibition(BBC3(), CASP3()),
#  Activation(BBC3(), CASP3()),
#  Inhibition(BBC3(), FAS()),
#  Activation(BBC3(), TNF()),
#  Inhibition(BBC3(), TNF()),
#  Inhibition(BBC3(), BID()),
#  Activation(BBC3(), BID()),
#  Activation(BBC3(bound: [BCL2L1, True]), apoptotic process()),
#  Inhibition(BBC3(mods: (modification)), apoptotic process()),
#  Activation(BBC3(mods: (modification)), apoptotic process()),
#  Activation(BBC3(bound: [BCL2L1, True]), apoptotic process()),
#  Activation(BBC3(muts: (W, 71, A)), apoptotic process()),
#  Activation(BBC3(bound: [BCL2, True]), apoptotic process()),
#  Activation(BBC3(bound: [BAX, True]), apoptotic process()),
#  Inhibition(BBC3(), apoptotic process()),
#  Activation(BBC3(), apoptotic process()),
#  DecreaseAmount(BBC3(), AKT()),
#  Dephosphorylation(BBC3(mods: (modification)), AKT()),
#  Activation(BBC3(), AKT()),
#  Inhibition(BBC3(), AKT()),
#  Inhibition(CYCS(), AKT(mods: (phosphorylation))),
#  IncreaseAmount(CYCS(mods: (modification)), AKT(mods: (phosphorylation))),
#  DecreaseAmount(CYCS(), AKT()),
#  Inhibition(CYCS(), AKT()),
#  Dephosphorylation(CYCS(), AKT()),
#  Activation(CYCS(), AKT()),
#  IncreaseAmount(CYCS(), AKT()),
#  IncreaseAmount(CYCS(), BCL2L11()),
#  Activation(CYCS(), BCL2L11()),
#  Complex(CYCS(), BCL2L11()),
#  DecreaseAmount(CYCS(), BCL2L11()),
#  Inhibition(CYCS(), BCL2L11()),
#  IncreaseAmount(CYCS(), BCL2L1()),
#  Activation(CYCS(), BCL2L1()),
#  Inhibition(CYCS(), BCL2L1()),
#  DecreaseAmount(CYCS(), BCL2L1()),
#  Complex(CYCS(), BCL2L1()),
#  IncreaseAmount(CYCS(), BCL2()),
#  IncreaseAmount(CYCS(mods: (modification)), BCL2()),
#  DecreaseAmount(CYCS(mods: (modification)), BCL2()),
#  Inhibition(CYCS(), BCL2()),
#  Activation(CYCS(), BCL2()),
#  DecreaseAmount(CYCS(), BCL2()),
#  Complex(CYCS(), BCL2()),
#  Dephosphorylation(CYCS(), BAX()),
#  IncreaseAmount(CYCS(mods: (modification)), BAX()),
#  IncreaseAmount(CYCS(), BAX()),
#  DecreaseAmount(CYCS(), BAX()),
#  Inhibition(CYCS(), BAX()),
#  Complex(CYCS(), BAX()),
#  Activation(CYCS(), BAX()),
#  Inhibition(CYCS(), BAD()),
#  Complex(CYCS(), BAD()),
#  Activation(CYCS(), BAD()),
#  Phosphorylation(CYCS(), BAD()),
#  DecreaseAmount(CYCS(), MCL1()),
#  Complex(CYCS(), MCL1()),
#  Dephosphorylation(CYCS(), MCL1()),
#  Activation(CYCS(), FADD()),
#  IncreaseAmount(CYCS(), FADD()),
#  Activation(CYCS(), BBC3()),
#  Activation(CYCS(bound: [Caspase, True]), CASP9()),
#  Activation(CYCS(bound: [protease activator protein-1, True]), CASP9()),
#  Activation(CYCS(bound: [ATP, True]), CASP9()),
#  Activation(CYCS(bound: [procaspase-9, True]), CASP9()),
#  Activation(CYCS(bound: [apoptosis-activating-factor-1, True]), CASP9()),
#  DecreaseAmount(CYCS(), CASP9()),
#  Activation(CYCS(bound: [cytosolic protein, True]), CASP9()),
#  IncreaseAmount(CYCS(), CASP9()),
#  Activation(CYCS(bound: [peptidase, True]), CASP9()),
#  Inhibition(CYCS(bound: [NGB, True]), CASP9()),
#  Activation(CYCS(bound: [CASP9, True]), CASP9()),
#  Inhibition(CYCS(), CASP9()),
#  Inhibition(CYCS(bound: [tRNA, True]), CASP9()),
#  Activation(CYCS(bound: [APAF1, True]), CASP9()),
#  Activation(CYCS(bound: [Protease, True]), CASP9()),
#  Activation(CYCS(), CASP9()),
#  Inhibition(CYCS(), CASP8()),
#  Activation(CYCS(mods: (modification)), CASP8()),
#  Activation(CYCS(), CASP8()),
#  Activation(CYCS(bound: [APAF1, True]), CASP7()),
#  Activation(CYCS(), CASP7()),
#  Activation(CYCS(bound: [Caspase, True]), CASP3()),
#  IncreaseAmount(CYCS(mods: (modification)), CASP3()),
#  Activation(CYCS(bound: [apoptosis-activating-factor-1, True]), CASP3()),
#  Activation(CYCS(bound: [procaspase-9, True]), CASP3()),
#  Activation(CYCS(bound: [CASP9, True], bound: [APAF1, True]), CASP3()),
#  Activation(CYCS(bound: [Protease, True]), CASP3()),
#  Activation(CYCS(bound: [dATP, True]), CASP3()),
#  Activation(CYCS(mods: (modification)), CASP3()),
#  Activation(CYCS(bound: [CASP9, True]), CASP3()),
#  DecreaseAmount(CYCS(), CASP3()),
#  DecreaseAmount(CYCS(mods: (modification)), CASP3()),
#  Activation(CYCS(bound: [APAF1, True]), CASP3()),
#  Inhibition(CYCS(), CASP3()),
#  IncreaseAmount(CYCS(), CASP3()),
#  Activation(CYCS(), CASP3()),
#  IncreaseAmount(CYCS(), FASLG()),
#  Activation(CYCS(), FASLG()),
#  IncreaseAmount(CYCS(), FAS()),
#  Inhibition(CYCS(), FAS()),
#  Inhibition(CYCS(muts: (None, None, None), bound: [APAF1, True]), FAS()),
#  Activation(CYCS(), FAS()),
#  Activation(CYCS(), TNF()),
#  Activation(CYCS(), BID()),
#  Inhibition(CYCS(), BID()),
#  Inhibition(CYCS(), apoptosome()),
#  Activation(CYCS(), apoptosome()),
#  Activation(CYCS(bound: [CASP3, True]), apoptotic process()),
#  Activation(CYCS(bound: [Caspase, True]), apoptotic process()),
#  Activation(CYCS(muts: (N, 52, I)), apoptotic process()),
#  Inhibition(CYCS(bound: [FA, True]), apoptotic process()),
#  Activation(CYCS(bound: [protein, True]), apoptotic process()),
#  Inhibition(CYCS(bound: [HSPB1, True]), apoptotic process()),
#  Activation(CYCS(bound: [ESR1, True]), apoptotic process()),
#  Activation(CYCS(bound: [IP3R post-burn, True]), apoptotic process()),
#  Activation(CYCS(bound: [acetic acid, True]), apoptotic process()),
#  Activation(CYCS(bound: [CASP9, True]), apoptotic process()),
#  Activation(CYCS(bound: [apoptosis-activating-factor-1, True]), apoptotic process()),
#  Activation(CYCS(bound: [APAF1, True]), apoptotic process()),
#  Activation(CYCS(mods: (modification)), apoptotic process()),
#  Inhibition(CYCS(), apoptotic process()),
#  Activation(CYCS(), apoptotic process()),
#  Inhibition(apoptotic process(), BCL2L11()),
#  Activation(apoptotic process(), BCL2L11()),
#  IncreaseAmount(apoptotic process(), BCL2L11()),
#  IncreaseAmount(apoptotic process(), BCL2L1()),
#  Activation(apoptotic process(), BCL2L1()),
#  Inhibition(apoptotic process(), BCL2L1()),
#  IncreaseAmount(apoptotic process(), BCL2()),
#  Inhibition(apoptotic process(), BCL2()),
#  Activation(apoptotic process(), BCL2()),
#  IncreaseAmount(apoptotic process(), BAX()),
#  Activation(apoptotic process(), BAX()),
#  Inhibition(apoptotic process(), BAX()),
#  Activation(apoptotic process(), BAD()),
#  Inhibition(apoptotic process(), MCL1()),
#  Activation(apoptotic process(), MCL1()),
#  IncreaseAmount(apoptotic process(), MCL1()),
#  Inhibition(apoptotic process(), FADD()),
#  Activation(apoptotic process(), FADD()),
#  Activation(apoptotic process(), CYCS()),
#  Inhibition(apoptotic process(), CYCS()),
#  IncreaseAmount(apoptotic process(), BBC3()),
#  Activation(apoptotic process(), BBC3()),
#  Inhibition(apoptotic process(), BBC3()),
#  Activation(apoptotic process(), CASP9()),
#  Inhibition(apoptotic process(), CASP9()),
#  Inhibition(apoptotic process(), CASP9(muts: (None, None, None))),
#  Inhibition(apoptotic process(), CASP8()),
#  Activation(apoptotic process(), CASP8()),
#  Inhibition(apoptotic process(), CASP7()),
#  Activation(apoptotic process(), CASP7()),
#  Inhibition(apoptotic process(), CASP3()),
#  Activation(apoptotic process(), CASP3()),
#  IncreaseAmount(apoptotic process(), CASP3()),
#  Inhibition(apoptotic process(), TRADD()),
#  IncreaseAmount(apoptotic process(), FASLG()),
#  Inhibition(apoptotic process(), FASLG()),
#  Activation(apoptotic process(), FASLG()),
#  Inhibition(apoptotic process(), FAS()),
#  IncreaseAmount(apoptotic process(), FAS()),
#  Activation(apoptotic process(), FAS()),
#  Inhibition(apoptotic process(), TNFRSF1A()),
#  Activation(apoptotic process(), TNFRSF1A()),
#  IncreaseAmount(apoptotic process(), TNF()),
#  Inhibition(apoptotic process(), TNF()),
#  Activation(apoptotic process(), TNF()),
#  Inhibition(apoptotic process(), BID()),
#  Activation(apoptotic process(), BID()),
#  Inhibition(apoptotic process(), AKT(mods: (phosphorylation))),
#  Activation(apoptotic process(), AKT()),
#  Inhibition(apoptotic process(), AKT()),
#  Complex(FADD(), BCL2L1()),
#  Activation(FADD(), BCL2()),
#  Complex(FADD(), BCL2()),
#  Inhibition(FADD(), BCL2()),
#  IncreaseAmount(FADD(), BAX()),
#  Activation(FADD(), BAX()),
#  Inhibition(FADD(), CYCS()),
#  Activation(FADD(), CYCS()),
#  Activation(FADD(), BBC3()),
#  Activation(FADD(), CASP9()),
#  Inhibition(FADD(), CASP9()),
#  IncreaseAmount(FADD(), CASP9()),
#  Inhibition(FADD(muts: (None, None, None)), CASP8()),
#  Activation(FADD(bound: [FAS, True]), CASP8()),
#  Inhibition(FADD(bound: [FCMR, True]), CASP8()),
#  Activation(FADD(bound: [procaspase-8 molecules, True]), CASP8()),
#  Activation(FADD(muts: (None, None, None)), CASP8()),
#  Inhibition(FADD(bound: [MUC1-C, True]), CASP8()),
#  Activation(FADD(bound: [CASP8, True], bound: [RIPK1, True]), CASP8()),
#  Ubiquitination(FADD(), CASP8()),
#  Activation(FADD(catalytic), CASP8(), catalytic),
#  Activation(FADD(), CASP8(), catalytic),
#  Activation(FADD(bound: [TNFRSF1A, True]), CASP8()),
#  Activation(FADD(bound: [death domain, True]), CASP8()),
#  IncreaseAmount(FADD(), CASP8()),
#  Inhibition(FADD(mods: (modification)), CASP8()),
#  IncreaseAmount(FADD(mods: (modification)), CASP8()),
#  Activation(FADD(mods: (modification)), CASP8()),
#  Activation(FADD(bound: [caspase-8/10, True]), CASP8()),
#  Activation(FADD(bound: [CASP8, True]), CASP8()),
#  Activation(FADD(bound: [it, True]), CASP8()),
#  DecreaseAmount(FADD(), CASP8()),
#  Inhibition(FADD(bound: [CFLAR, True]), CASP8()),
#  Inhibition(FADD(), CASP8()),
#  Activation(FADD(bound: [ATG13, True]), CASP8()),
#  Inhibition(FADD(), CASP8(muts: (D, 387, A))),
#  Activation(FADD(), CASP8()),
#  Activation(FADD(bound: [CASP8, True]), CASP7()),
#  Inhibition(FADD(muts: (None, None, None)), CASP3()),
#  Activation(FADD(bound: [CASP8, True]), CASP3()),
#  IncreaseAmount(FADD(), CASP3()),
#  Inhibition(FADD(), CASP3()),
#  Acetylation(FADD(), CASP3()),
#  Activation(FADD(), CASP3()),
#  Activation(FADD(), TRADD()),
#  DecreaseAmount(FADD(), FASLG()),
#  Inhibition(FADD(), FASLG()),
#  Activation(FADD(), FASLG()),
#  Activation(FADD(muts: (S, 191, D)), FAS()),
#  Inhibition(FADD(), FAS()),
#  Inhibition(FADD(muts: (None, None, None)), FAS()),
#  Activation(FADD(), FAS()),
#  IncreaseAmount(FADD(), FAS()),
#  Activation(FADD(bound: [PRKCZ, True]), FAS(), catalytic),
#  Inhibition(FADD(), TNFRSF1A()),
#  Activation(FADD(), TNFRSF1A()),
#  Activation(FADD(bound: [RIP1-caspase 8, True]), TNF()),
#  IncreaseAmount(FADD(), TNF()),
#  Inhibition(FADD(), TNF()),
#  Activation(FADD(), TNF()),
#  Inhibition(FADD(), BID()),
#  Activation(FADD(), BID()),
#  Inhibition(FADD(bound: [S116, True], bound: [PEA15, True]), apoptotic process()),
#  Activation(FADD(muts: (S, 191, D)), apoptotic process()),
#  Inhibition(FADD(bound: [PEA15, True]), apoptotic process()),
#  Activation(FADD(bound: [Death Domain, True]), apoptotic process()),
#  Inhibition(FADD(muts: (None, None, None)), apoptotic process()),
#  Activation(FADD(muts: (S, 191, A)), apoptotic process()),
#  Activation(FADD(muts: (S, 194, E)), apoptotic process()),
#  Activation(FADD(bound: [CASP10, True]), apoptotic process()),
#  Activation(FADD(bound: [it, True]), apoptotic process()),
#  Activation(FADD(bound: [TRADD, True]), apoptotic process()),
#  Activation(FADD(bound: [procaspase 8, True]), apoptotic process()),
#  Inhibition(FADD(mods: (modification)), apoptotic process()),
#  Activation(FADD(bound: [caspase-8 form cytosolic, True]), apoptotic process()),
#  Activation(FADD(bound: [CASP8, True]), apoptotic process()),
#  Activation(FADD(bound: [ATG13, True]), apoptotic process()),
#  Activation(FADD(bound: [MYD88, True]), apoptotic process()),
#  Activation(FADD(bound: [TNFRSF1A, True]), apoptotic process()),
#  Activation(FADD(bound: [death domain, True]), apoptotic process()),
#  Activation(FADD(bound: [Death_receptor, True]), apoptotic process()),
#  Activation(FADD(muts: (None, None, None)), apoptotic process()),
#  Activation(FADD(), apoptotic process()),
#  Inhibition(FADD(), apoptotic process()),
#  Activation(apoptosome(), BAX()),
#  Inhibition(apoptosome(), FADD()),
#  Complex(apoptosome(), CYCS()),
#  Activation(apoptosome(), CYCS()),
#  Activation(apoptosome(activity), CASP9()),
#  Activation(apoptosome(), CASP9()),
#  Complex(apoptosome(), CASP9()),
#  Activation(apoptosome(), CASP7()),
#  Complex(apoptosome(), CASP3()),
#  Activation(apoptosome(), CASP3()),
#  Inhibition(apoptosome(), FAS()),
#  Activation(apoptosome(), apoptotic process()),
#  Phosphorylation(MAPK14(), BCL2L11()),
#  Activation(MAPK14(), BCL2L11()),
#  Activation(MAPK14(), BCL2L1()),
#  Phosphorylation(MAPK14(), BCL2L1()),
#  Inhibition(MAPK14(), BCL2L1()),
#  Complex(MAPK14(), BCL2L1()),
#  Phosphorylation(MAPK14(), BCL2L1(), S, 62),
#  Activation(MAPK14(), BCL2()),
#  Phosphorylation(MAPK14(), BCL2(), S, 87),
#  Phosphorylation(MAPK14(), BCL2(), T, 56),
#  Inhibition(MAPK14(), BCL2()),
#  Complex(MAPK14(), BCL2()),
#  Phosphorylation(MAPK14(), BCL2()),
#  IncreaseAmount(MAPK14(), BAX()),
#  Activation(MAPK14(kinase), BAX(), catalytic),
#  Phosphorylation(MAPK14(), BAX()),
#  Inhibition(MAPK14(), BAX()),
#  Activation(MAPK14(), BAX()),
#  Activation(MAPK14(), MCL1()),
#  IncreaseAmount(MAPK14(), BBC3()),
#  Inhibition(MAPK14(), BBC3()),
#  Phosphorylation(MAPK14(), CASP9()),
#  Inhibition(MAPK14(), CASP9()),
#  Inhibition(MAPK14(), CASP8()),
#  Phosphorylation(MAPK14(kinase), CASP8(), S, 347),
#  DecreaseAmount(MAPK14(), CASP8()),
#  Phosphorylation(MAPK14(), CASP8(), S, 347),
#  Activation(MAPK14(), CASP8()),
#  Phosphorylation(MAPK14(), CASP8()),
#  Activation(MAPK14(kinase), CASP3(), catalytic),
#  Activation(MAPK14(), CASP3()),
#  Phosphorylation(MAPK14(kinase), CASP3(), S, 150),
#  DecreaseAmount(MAPK14(), CASP3()),
#  IncreaseAmount(MAPK14(), CASP3()),
#  Phosphorylation(MAPK14(), CASP3()),
#  Inhibition(MAPK14(), CASP3()),
#  Phosphorylation(MAPK14(), CASP3(), S, 150),
#  DecreaseAmount(MAPK14(), CASP3(muts: (S, 150, A))),
#  Activation(MAPK14(), FASLG()),
#  IncreaseAmount(MAPK14(), FASLG()),
#  Activation(MAPK14(), TNF()),
#  IncreaseAmount(MAPK14(), TNF()),
#  DecreaseAmount(MAPK14(), TNF()),
#  Inhibition(MAPK14(), TNF()),
#  Activation(MAPK14(), apoptotic process()),
#  Inhibition(MAPK14(), apoptotic process()),
#  Activation(MAPK14(), AKT()),
#  Inhibition(MAPK14(), AKT()),
#  Phosphorylation(MAPK14(), AKT()),
#  IncreaseAmount(MCL1(mods: (modification)), BCL2L11()),
#  Phosphorylation(MCL1(), BCL2L11(), S, 87),
#  Phosphorylation(MCL1(mods: (modification)), BCL2L11()),
#  DecreaseAmount(MCL1(), BCL2L11()),
#  Inhibition(MCL1(bound: [it, True]), BCL2L11()),
#  Dephosphorylation(MCL1(), BCL2L11(), S, 69),
#  IncreaseAmount(MCL1(), BCL2L11()),
#  IncreaseAmount(MCL1(bound: [BCL2L11, True]), BCL2L11()),
#  Activation(MCL1(), BCL2L11()),
#  Complex(MCL1(), BCL2L11()),
#  Inhibition(MCL1(), BCL2L11()),
#  DecreaseAmount(MCL1(), BCL2L1()),
#  Phosphorylation(MCL1(), BCL2L1()),
#  Inhibition(MCL1(mods: (modification)), BCL2L1()),
#  Activation(MCL1(), BCL2L1()),
#  Inhibition(MCL1(), BCL2L1()),
#  Complex(MCL1(), BCL2L1()),
#  Dephosphorylation(MCL1(), BCL2()),
#  Activation(MCL1(bound: [BCL2L11, True]), BCL2()),
#  Inhibition(MCL1(mods: (modification)), BCL2()),
#  DecreaseAmount(MCL1(mods: (modification)), BCL2()),
#  IncreaseAmount(MCL1(mods: (modification)), BCL2()),
#  Activation(MCL1(mods: (modification)), BCL2()),
#  DecreaseAmount(MCL1(), BCL2()),
#  Phosphorylation(MCL1(), BCL2()),
#  Phosphorylation(MCL1(), BCL2(), T, 56),
#  IncreaseAmount(MCL1(), BCL2()),
#  Inhibition(MCL1(), BCL2()),
#  Activation(MCL1(), BCL2()),
#  Complex(MCL1(), BCL2()),
#  Complex(MCL1(), BAX(bound: [BAK1, True])),
#  Activation(MCL1(bound: [BCL2L11, True]), BAX()),
#  Inhibition(MCL1(), BAX(bound: [BAK1, True])),
#  Inhibition(MCL1(bound: [BAK1, True]), BAX()),
#  Inhibition(MCL1(catalytic), BAX(), catalytic),
#  DecreaseAmount(MCL1(mods: (modification)), BAX()),
#  IncreaseAmount(MCL1(), BAX()),
#  DecreaseAmount(MCL1(), BAX()),
#  IncreaseAmount(MCL1(mods: (modification)), BAX()),
#  Activation(MCL1(mods: (modification)), BAX()),
#  Activation(MCL1(), BAX()),
#  Complex(MCL1(), BAX()),
#  Inhibition(MCL1(), BAX()),
#  Activation(MCL1(), BAD()),
#  Phosphorylation(MCL1(), BAD()),
#  DecreaseAmount(MCL1(), BAD()),
#  Inhibition(MCL1(), BAD()),
#  Complex(MCL1(), BAD()),
#  Inhibition(MCL1(bound: [BAK1, True]), CYCS()),
#  Inhibition(MCL1(), CYCS()),
#  Inhibition(MCL1(mods: (modification)), CYCS()),
#  Activation(MCL1(), CYCS()),
#  IncreaseAmount(MCL1(), BBC3()),
#  Inhibition(MCL1(), BBC3()),
#  Activation(MCL1(), BBC3()),
#  Inhibition(MCL1(mods: (modification)), CASP9()),
#  Activation(MCL1(), CASP9()),
#  Inhibition(MCL1(), CASP9()),
#  Activation(MCL1(), CASP8()),
#  Inhibition(MCL1(), CASP8()),
#  Inhibition(MCL1(), CASP7()),
#  IncreaseAmount(MCL1(), CASP3()),
#  Activation(MCL1(), CASP3()),
#  Inhibition(MCL1(), CASP3()),
#  IncreaseAmount(MCL1(mods: (modification)), FASLG()),
#  Inhibition(MCL1(), FASLG()),
#  Inhibition(MCL1(), FAS()),
#  IncreaseAmount(MCL1(), FAS()),
#  Inhibition(MCL1(), TNF()),
#  Activation(MCL1(), TNF()),
#  DecreaseAmount(MCL1(), BID()),
#  Activation(MCL1(mods: (modification)), BID()),
#  Activation(MCL1(), BID()),
#  Inhibition(MCL1(), BID()),
#  Activation(MCL1(bound: [IP3R, True]), apoptotic process()),
#  Inhibition(MCL1(bound: [BBC3, True]), apoptotic process()),
#  Activation(MCL1(bound: [their, True]), apoptotic process()),
#  Activation(MCL1(bound: [MFF, True]), apoptotic process()),
#  Activation(MCL1(bound: [BCL2L11, True]), apoptotic process()),
#  Inhibition(MCL1(bound: [BCL2, True]), apoptotic process()),
#  Inhibition(MCL1(bound: [BAK1, True]), apoptotic process()),
#  Inhibition(MCL1(bound: [HSPA8, True]), apoptotic process()),
#  Inhibition(MCL1(bound: [BCL2L11, True]), apoptotic process()),
#  Activation(MCL1(bound: [it, True]), apoptotic process()),
#  Inhibition(MCL1(bound: [BAX, True]), apoptotic process()),
#  Inhibition(MCL1(mods: (modification)), apoptotic process()),
#  Activation(MCL1(bound: [PMAIP1, True]), apoptotic process()),
#  Inhibition(MCL1(muts: (T, 92, A)), apoptotic process()),
#  Inhibition(MCL1(bound: [killer, True]), apoptotic process()),
#  Inhibition(MCL1(), apoptotic process()),
#  Activation(MCL1(), apoptotic process()),
#  Activation(MCL1(), AKT(mods: (phosphorylation))),
#  Inhibition(MCL1(bound: [AKT, True]), AKT()),
#  Phosphorylation(MCL1(), AKT()),
#  Activation(MCL1(bound: [AKT, True]), AKT()),
#  Inhibition(MCL1(), AKT()),
#  Activation(MCL1(), AKT()),
#  DecreaseAmount(BAD(), BCL2L11()),
#  Activation(BAD(), BCL2L11()),
#  Complex(BAD(), BCL2L11()),
#  Inhibition(BAD(), BCL2L11()),
#  Inhibition(BAD(bound: [BCL2L1, True]), BCL2L1()),
#  DecreaseAmount(BAD(mods: (phosphorylation)), BCL2L1()),
#  Inhibition(BAD(mods: (phosphorylation)), BCL2L1()),
#  DecreaseAmount(BAD(mods: (modification)), BCL2L1()),
#  Inhibition(BAD(bound: [p14_3_3, True]), BCL2L1()),
#  IncreaseAmount(BAD(mods: (modification)), BCL2L1()),
#  Complex(BAD(mods: (phosphorylation)), BCL2L1()),
#  Phosphorylation(BAD(), BCL2L1()),
#  IncreaseAmount(BAD(), BCL2L1()),
#  Activation(BAD(bound: [BCL2L1, True]), BCL2L1()),
#  IncreaseAmount(BAD(mods: (phosphorylation)), BCL2L1()),
#  Inhibition(BAD(), BCL2L1()),
#  Activation(BAD(), BCL2L1()),
#  Complex(BAD(), BCL2L1()),
#  Complex(BAD(muts: (None, None, None)), BCL2()),
#  Activation(BAD(mods: (phosphorylation, False)), BCL2()),
#  Inhibition(BAD(bound: [p14_3_3, True]), BCL2()),
#  Inhibition(BAD(bound: [BCL2, True]), BCL2()),
#  IncreaseAmount(BAD(mods: (modification)), BCL2()),
#  Phosphorylation(BAD(), BCL2()),
#  DecreaseAmount(BAD(mods: (phosphorylation)), BCL2()),
#  DecreaseAmount(BAD(), BCL2()),
#  IncreaseAmount(BAD(mods: (phosphorylation)), BCL2()),
#  IncreaseAmount(BAD(), BCL2()),
#  Inhibition(BAD(bound: [BAX, True]), BCL2()),
#  Activation(BAD(mods: (phosphorylation)), BCL2()),
#  DecreaseAmount(BAD(mods: (modification)), BCL2()),
#  Inhibition(BAD(), BCL2()),
#  Complex(BAD(mods: (phosphorylation)), BCL2()),
#  Activation(BAD(), BCL2()),
#  Complex(BAD(), BCL2()),
#  DecreaseAmount(BAD(mods: (modification)), BAX()),
#  Activation(BAD(catalytic), BAX(), catalytic),
#  Activation(BAD(mods: (phosphorylation, False)), BAX()),
#  Activation(BAD(mods: (phosphorylation)), BAX()),
#  Inhibition(BAD(bound: [BCL2L1, True]), BAX()),
#  DecreaseAmount(BAD(), BAX()),
#  Inhibition(BAD(bound: [BCL2, True]), BAX()),
#  Activation(BAD(bound: [BCL2, True]), BAX()),
#  IncreaseAmount(BAD(), BAX()),
#  Activation(BAD(bound: [BCL2L1, True]), BAX()),
#  IncreaseAmount(BAD(mods: (modification)), BAX()),
#  Phosphorylation(BAD(), BAX()),
#  Dephosphorylation(BAD(), BAX()),
#  Inhibition(BAD(), BAX()),
#  Activation(BAD(), BAX()),
#  Complex(BAD(), BAX()),
#  Inhibition(BAD(mods: (phosphorylation)), BAX()),
#  Phosphorylation(BAD(), MCL1()),
#  Inhibition(BAD(), MCL1()),
#  Activation(BAD(), MCL1()),
#  DecreaseAmount(BAD(mods: (modification)), CYCS()),
#  Inhibition(BAD(mods: (phosphorylation)), CYCS()),
#  IncreaseAmount(BAD(mods: (modification)), CYCS()),
#  Inhibition(BAD(), CYCS()),
#  Activation(BAD(mods: (phosphorylation, False)), CYCS()),
#  Phosphorylation(BAD(), CYCS()),
#  Activation(BAD(), CYCS()),
#  DecreaseAmount(BAD(mods: (modification)), CASP9()),
#  IncreaseAmount(BAD(), CASP9()),
#  Dephosphorylation(BAD(), CASP9()),
#  Activation(BAD(), CASP9()),
#  Inhibition(BAD(), CASP9()),
#  Activation(BAD(), CASP8()),
#  Inhibition(BAD(), CASP8()),
#  IncreaseAmount(BAD(mods: (modification)), CASP3()),
#  Phosphorylation(BAD(), CASP3()),
#  Activation(BAD(), CASP3()),
#  Inhibition(BAD(), CASP3()),
#  Activation(BAD(), FASLG()),
#  IncreaseAmount(BAD(), FASLG()),
#  Inhibition(BAD(), FAS()),
#  IncreaseAmount(BAD(), FAS()),
#  Activation(BAD(), FAS()),
#  Activation(BAD(), TNF()),
#  Inhibition(BAD(), TNF()),
#  IncreaseAmount(BAD(), BID()),
#  Inhibition(BAD(), BID()),
#  Activation(BAD(), BID()),
#  Activation(BAD(mods: (modification)), apoptotic process()),
#  Activation(BAD(bound: [TP53, True]), apoptotic process()),
#  Inhibition(BAD(bound: [14-3-3beta, True]), apoptotic process()),
#  Activation(BAD(muts: (S, 113, A)), apoptotic process()),
#  Activation(BAD(mods: (phosphorylation)), apoptotic process()),
#  Inhibition(BAD(bound: [BCL2, True]), apoptotic process()),
#  Activation(BAD(mods: (phosphorylation, False)), apoptotic process()),
#  Activation(BAD(bound: [BCL2L1, True]), apoptotic process()),
#  Activation(BAD(muts: (S, 112, A)), apoptotic process()),
#  Activation(BAD(bound: [BCL2, True]), apoptotic process()),
#  Activation(BAD(muts: (None, None, None)), apoptotic process()),
#  Inhibition(BAD(muts: (None, None, None)), apoptotic process()),
#  Inhibition(BAD(mods: (phosphorylation)), apoptotic process()),
#  Inhibition(BAD(), apoptotic process()),
#  Activation(BAD(), apoptotic process()),
#  Phosphorylation(BAD(mods: (phosphorylation, S, 118)), AKT(), S, 99),
#  Phosphorylation(BAD(), AKT(), S, 136),
#  Inhibition(BAD(), AKT()),
#  Phosphorylation(BAD(), AKT(), T, 308),
#  Phosphorylation(BAD(), AKT(), S, 473),
#  Inhibition(BAD(), AKT(mods: (phosphorylation))),
#  Phosphorylation(BAD(mods: (phosphorylation)), AKT()),
#  DecreaseAmount(BAD(), AKT()),
#  DecreaseAmount(BAD(mods: (modification)), AKT()),
#  Phosphorylation(BAD(), AKT()),
#  Activation(BAD(), AKT()),
#  DecreaseAmount(BAD(), AKT(mods: (phosphorylation))),
#  Complex(BAX(muts: (S, 184, E)), BCL2L11()),
#  Complex(BAX(bound: [BAK1, True]), BCL2L11()),
#  IncreaseAmount(BAX(), BCL2L11()),
#  Complex(BAX(), BCL2L11(mods: (phosphorylation))),
#  Inhibition(BAX(), BCL2L11()),
#  Activation(BAX(), BCL2L11()),
#  Complex(BAX(), BCL2L11()),
#  Complex(BAX(activity: False), BCL2L1()),
#  IncreaseAmount(BAX(mods: (modification)), BCL2L1()),
#  IncreaseAmount(BAX(bound: [BBC3, True]), BCL2L1()),
#  DecreaseAmount(BAX(), BCL2L1()),
#  DecreaseAmount(BAX(mods: (modification)), BCL2L1()),
#  IncreaseAmount(BAX(), BCL2L1()),
#  Activation(BAX(), BCL2L1()),
#  Inhibition(BAX(), BCL2L1()),
#  Complex(BAX(), BCL2L1()),
#  Complex(BAX(location: nucleus), BCL2(location: nucleus)),
#  Inhibition(BAX(mods: (modification)), BCL2()),
#  Activation(BAX(muts: (V, 177, C)), BCL2()),
#  Methylation(BAX(), BCL2()),
#  Complex(BAX(), BCL2(mods: (phosphorylation))),
#  Phosphorylation(BAX(), BCL2()),
#  Inhibition(BAX(bound: [ABT-737, True]), BCL2()),
#  Activation(BAX(mods: (modification)), BCL2()),
#  Inhibition(BAX(bound: [BCL2, True]), BCL2()),
#  Complex(BAX(bound: [BAK1, True]), BCL2()),
#  Complex(BAX(activity), BCL2()),
#  IncreaseAmount(BAX(mods: (modification)), BCL2()),
#  DecreaseAmount(BAX(), BCL2()),
#  DecreaseAmount(BAX(mods: (modification)), BCL2()),
#  Activation(BAX(), BCL2()),
#  Inhibition(BAX(), BCL2()),
#  IncreaseAmount(BAX(), BCL2()),
#  Complex(BAX(), BCL2()),
#  IncreaseAmount(BAX(), BAD()),
#  Phosphorylation(BAX(), BAD()),
#  Inhibition(BAX(), BAD()),
#  Activation(BAX(), BAD()),
#  DecreaseAmount(BAX(), MCL1()),
#  DecreaseAmount(BAX(mods: (modification)), MCL1()),
#  IncreaseAmount(BAX(mods: (modification)), MCL1()),
#  Activation(BAX(bound: [BAK1, True]), MCL1()),
#  IncreaseAmount(BAX(), MCL1()),
#  Inhibition(BAX(), MCL1()),
#  Activation(BAX(), MCL1()),
#  Activation(BAX(bound: [MCL1, True]), MCL1()),
#  Activation(BAX(), MAPK14()),
#  DecreaseAmount(BAX(), FADD()),
#  Inhibition(BAX(bound: [MUC1, True]), FADD()),
#  Activation(BAX(bound: [voltage-dependent anion channel, True]), CYCS()),
#  Activation(BAX(mods: (modification)), CYCS()),
#  Inhibition(BAX(bound: [It, True]), CYCS()),
#  Activation(BAX(muts: (P, 168, G)), CYCS()),
#  Activation(BAX(mods: (phosphorylation)), CYCS()),
#  Inhibition(BAX(bound: [HSPA, True]), CYCS()),
#  Activation(BAX(bound: [BCL2, True]), CYCS()),
#  Inhibition(BAX(bound: [BCL2, True]), CYCS()),
#  Activation(BAX(bound: [it, True]), CYCS()),
#  IncreaseAmount(BAX(mods: (modification)), CYCS()),
#  Inhibition(BAX(mods: (modification)), CYCS()),
#  DecreaseAmount(BAX(), CYCS()),
#  Activation(BAX(bound: [BCL2L11, True]), CYCS()),
#  Activation(BAX(bound: [BAK1, True]), CYCS()),
#  Activation(BAX(bound: [VDAC1, True]), CYCS()),
#  Inhibition(BAX(bound: [BCL2L1, True]), CYCS()),
#  IncreaseAmount(BAX(), CYCS()),
#  DecreaseAmount(BAX(mods: (modification)), CYCS()),
#  Inhibition(BAX(), CYCS()),
#  Activation(BAX(), CYCS()),
#  IncreaseAmount(BAX(), BBC3()),
#  Inhibition(BAX(), BBC3()),
#  DecreaseAmount(BAX(), BBC3()),
#  Activation(BAX(), BBC3()),
#  Inhibition(BAX(mods: (modification)), CASP9()),
#  Ubiquitination(BAX(), CASP9()),
#  DecreaseAmount(BAX(mods: (modification)), CASP9()),
#  IncreaseAmount(BAX(mods: (modification)), CASP9()),
#  DecreaseAmount(BAX(), CASP9()),
#  IncreaseAmount(BAX(), CASP9()),
#  Inhibition(BAX(), CASP9()),
#  Activation(BAX(), CASP9()),
#  IncreaseAmount(BAX(), CASP8()),
#  DecreaseAmount(BAX(), CASP8()),
#  Activation(BAX(), CASP8()),
#  Inhibition(BAX(), CASP8()),
#  Inhibition(BAX(), CASP7()),
#  Activation(BAX(), CASP7()),
#  DecreaseAmount(BAX(), CASP7()),
#  Activation(BAX(bound: [BCL2, True]), CASP3()),
#  Inhibition(BAX(bound: [BCL2L1, True]), CASP3()),
#  DecreaseAmount(BAX(), CASP3()),
#  Inhibition(BAX(mods: (modification)), CASP3()),
#  DecreaseAmount(BAX(mods: (modification)), CASP3()),
#  IncreaseAmount(BAX(mods: (modification)), CASP3()),
#  Activation(BAX(bound: [SH3GLB1, True]), CASP3()),
#  Inhibition(BAX(), CASP3()),
#  Activation(BAX(), CASP3()),
#  IncreaseAmount(BAX(), CASP3()),
#  DecreaseAmount(BAX(), TRADD()),
#  Activation(BAX(), FASLG()),
#  DecreaseAmount(BAX(), FASLG()),
#  Inhibition(BAX(), FAS()),
#  DecreaseAmount(BAX(), FAS()),
#  IncreaseAmount(BAX(), FAS()),
#  Activation(BAX(), FAS()),
#  Activation(BAX(), TNFRSF1A()),
#  DecreaseAmount(BAX(), TNF()),
#  Activation(BAX(), TNF()),
#  IncreaseAmount(BAX(), TNF()),
#  Inhibition(BAX(), TNF()),
#  Inhibition(BAX(), BID()),
#  IncreaseAmount(BAX(), BID()),
#  Activation(BAX(), BID()),
#  Inhibition(BAX(), apoptosome()),
#  Activation(BAX(), apoptosome()),
#  Activation(BAX(bound: [ERN1, True]), apoptotic process()),
#  Inhibition(BAX(bound: [BCL2L10, True]), apoptotic process()),
#  Inhibition(BAX(bound: [VDAC1, True]), apoptotic process()),
#  Activation(BAX(muts: (E, 69, A)), apoptotic process()),
#  IncreaseAmount(BAX(), apoptotic process()),
#  Inhibition(BAX(mods: (modification)), apoptotic process()),
#  Activation(BAX(muts: (D, 68, A)), apoptotic process()),
#  Activation(BAX(bound: [TP73, True]), apoptotic process()),
#  Activation(BAX(bound: [It, True]), apoptotic process()),
#  Activation(BAX(bound: [proteins, True]), apoptotic process()),
#  Activation(BAX(bound: [SMBA(s), True]), apoptotic process()),
#  Activation(BAX(bound: [PRPF6, True]), apoptotic process()),
#  Activation(BAX(bound: [BAK1, True]), apoptotic process()),
#  Inhibition(BAX(bound: [They, True]), apoptotic process()),
#  Activation(BAX(muts: (S, 184, V)), apoptotic process()),
#  Activation(BAX(bound: [SH3GLB1, True]), apoptotic process()),
#  Inhibition(BAX(bound: [Ser-62, True], bound: [BCL2L1, True]), apoptotic process()),
#  Inhibition(BAX(bound: [CRYAA, True]), apoptotic process()),
#  Inhibition(BAX(muts: (L, 63, E)), apoptotic process()),
#  Activation(BAX(bound: [CYD-2-11, True]), apoptotic process()),
#  Inhibition(BAX(bound: [Kv1.3, True]), apoptotic process()),
#  Inhibition(BAX(bound: [HSPD1, True]), apoptotic process()),
#  Activation(BAX(muts: (P, 168, G)), apoptotic process()),
#  Activation(BAX(bound: [XRCC6, True]), apoptotic process()),
#  Inhibition(BAX(bound: [XRCC6, True]), apoptotic process()),
#  Activation(BAX(bound: [VDAC1, True]), apoptotic process()),
#  Inhibition(BAX(bound: [CLU, True]), apoptotic process()),
#  Inhibition(BAX(muts: (None, None, None)), apoptotic process()),
#  Inhibition(BAX(bound: [NS5A, True]), apoptotic process()),
#  Activation(BAX(muts: (D, 68, R)), apoptotic process()),
#  Activation(BAX(mods: (modification)), apoptotic process()),
#  Inhibition(BAX(bound: [BAK1, True]), apoptotic process()),
#  Activation(BAX(muts: (G, 179, E)), apoptotic process()),
#  Activation(BAX(mods: (phosphorylation, S, 184)), apoptotic process()),
#  Inhibition(BAX(bound: [Bcl-x L  proteins, True]), apoptotic process()),
#  Activation(BAX(location: mitochondrion), apoptotic process()),
#  Activation(BAX(bound: [Bim SABH, True]), apoptotic process()),
#  Inhibition(BAX(bound: [BCL2L11, True]), apoptotic process()),
#  Inhibition(BAX(bound: [YWHAZ, True]), apoptotic process()),
#  Activation(BAX(muts: (None, None, None)), apoptotic process()),
#  Inhibition(BAX(bound: [BCL2L1, True]), apoptotic process()),
#  Activation(BAX(bound: [BCL2, True]), apoptotic process()),
#  Activation(BAX(bound: [it, True]), apoptotic process()),
#  Activation(BAX(muts: (S, 184, A)), apoptotic process()),
#  Inhibition(BAX(bound: [BCL2, True]), apoptotic process()),
#  Inhibition(BAX(), apoptotic process()),
#  Activation(BAX(), apoptotic process()),
#  Phosphorylation(BAX(), AKT(), D, 1),
#  Activation(BAX(bound: [CRYAA, True]), AKT()),
#  DecreaseAmount(BAX(mods: (modification)), AKT(mods: (phosphorylation))),
#  Phosphorylation(BAX(), AKT(mods: (phosphorylation))),
#  Activation(BAX(), AKT(mods: (phosphorylation))),
#  Inhibition(BAX(bound: [XRCC6, True]), AKT()),
#  DecreaseAmount(BAX(), AKT(mods: (phosphorylation))),
#  Dephosphorylation(BAX(mods: (modification)), AKT()),
#  Activation(BAX(), AKT()),
#  Phosphorylation(BAX(mods: (modification)), AKT()),
#  IncreaseAmount(BAX(mods: (modification)), AKT(mods: (phosphorylation))),
#  Phosphorylation(BAX(), AKT()),
#  IncreaseAmount(BAX(), AKT()),
#  Dephosphorylation(BAX(), AKT()),
#  IncreaseAmount(BAX(), AKT(mods: (phosphorylation))),
#  Inhibition(BAX(), AKT(mods: (phosphorylation))),
#  Inhibition(BAX(), AKT()),
#  Inhibition(BCL2(bound: [BCL2L1, True]), BCL2L11()),
#  Inhibition(BCL2(bound: [BCL2L11, True]), BCL2L11()),
#  Complex(BCL2(muts: (S, 70, A)), BCL2L11()),
#  Activation(BCL2(bound: [BCL2L11, True]), BCL2L11()),
#  Complex(BCL2(muts: (S, 70, E)), BCL2L11()),
#  IncreaseAmount(BCL2(mods: (modification)), BCL2L11()),
#  DecreaseAmount(BCL2(mods: (modification)), BCL2L11()),
#  DecreaseAmount(BCL2(), BCL2L11()),
#  Activation(BCL2(), BCL2L11()),
#  Complex(BCL2(), BCL2L11(mods: (phosphorylation))),
#  IncreaseAmount(BCL2(), BCL2L11()),
#  Complex(BCL2(), BCL2L11()),
#  Inhibition(BCL2(), BCL2L11()),
#  DecreaseAmount(BCL2(mods: (modification)), BCL2L1()),
#  Activation(BCL2(bound: [BAD, True]), BCL2L1()),
#  IncreaseAmount(BCL2(), BCL2L1()),
#  IncreaseAmount(BCL2(mods: (modification)), BCL2L1()),
#  DecreaseAmount(BCL2(), BCL2L1()),
#  Phosphorylation(BCL2(), BCL2L1()),
#  Inhibition(BCL2(), BCL2L1()),
#  Activation(BCL2(), BCL2L1()),
#  Complex(BCL2(), BCL2L1()),
#  Inhibition(BCL2(bound: [alpha-TOS, True]), BAX()),
#  Activation(BCL2(bound: [TP53, True]), BAX()),
#  Inhibition(BCL2(bound: [TNFRSF10B, True]), BAX()),
#  Inhibition(BCL2(bound: [proteins, True]), BAX()),
#  Inhibition(BCL2(bound: [BNIP3, True]), BAX()),
#  Activation(BCL2(), BAX(muts: (D, 68, R))),
#  Inhibition(BCL2(), BAX(bound: [BAK1, True])),
#  Inhibition(BCL2(), BAX(muts: (None, None, None))),
#  Activation(BCL2(bound: [tBid, True]), BAX()),
#  Inhibition(BCL2(bound: [ABT-737, True]), BAX()),
#  Activation(BCL2(bound: [BIM1, True]), BAX()),
#  Phosphorylation(BCL2(), BAX()),
#  IncreaseAmount(BCL2(mods: (phosphorylation)), BAX()),
#  Inhibition(BCL2(bound: [RTL10, True]), BAX()),
#  Activation(BCL2(bound: [BAD, True]), BAX()),
#  Inhibition(BCL2(muts: (None, None, None)), BAX()),
#  Dephosphorylation(BCL2(), BAX()),
#  Activation(BCL2(bound: [BCL2L11, True]), BAX()),
#  Activation(BCL2(bound: [alpha-TOS, True]), BAX()),
#  Activation(BCL2(bound: [BBC3, True]), BAX()),
#  Activation(BCL2(mods: (modification)), BAX()),
#  Activation(BCL2(bound: [BH3, True]), BAX()),
#  DecreaseAmount(BCL2(mods: (modification)), BAX()),
#  Activation(BCL2(bound: [BAX, True]), BAX()),
#  Activation(BCL2(bound: [its, True]), BAX()),
#  Inhibition(BCL2(bound: [BCL2L11, True]), BAX()),
#  Inhibition(BCL2(catalytic), BAX(), catalytic),
#  Inhibition(BCL2(mods: (modification)), BAX()),
#  IncreaseAmount(BCL2(mods: (modification)), BAX()),
#  DecreaseAmount(BCL2(), BAX()),
#  Inhibition(BCL2(bound: [BAX, True]), BAX()),
#  Activation(BCL2(), BAX()),
#  Inhibition(BCL2(), BAX()),
#  IncreaseAmount(BCL2(), BAX()),
#  DecreaseAmount(BCL2(mods: (modification)), BAD()),
#  Dephosphorylation(BCL2(mods: (modification)), BAD(), S, 99),
#  IncreaseAmount(BCL2(), BAD()),
#  DecreaseAmount(BCL2(), BAD()),
#  Dephosphorylation(BCL2(mods: (modification)), BAD()),
#  Dephosphorylation(BCL2(mods: (modification)), BAD(), S, 118),
#  Dephosphorylation(BCL2(), BAD()),
#  Phosphorylation(BCL2(), BAD()),
#  Inhibition(BCL2(), BAD()),
#  Activation(BCL2(), BAD()),
#  Inhibition(BCL2(bound: [BCL2L11, True]), MCL1()),
#  Activation(BCL2(bound: [4-[4-[[2-(4-chlorophenyl)-5,5-dimethyl-1-cyclohexenyl]methyl]-1-piperazinyl]-N-[4-[[(2R)-4-(4-morpholinyl)-1-(phenylthio)butan-2-yl]amino]-3-(trifluoromethylsulfonyl)phenyl]sulfonylbenzamide, True]), MCL1()),
#  IncreaseAmount(BCL2(mods: (modification)), MCL1()),
#  Activation(BCL2(bound: [ABT-737, True]), MCL1()),
#  Activation(BCL2(bound: [navitoclax, True]), MCL1()),
#  DecreaseAmount(BCL2(), MCL1()),
#  IncreaseAmount(BCL2(), MCL1()),
#  Phosphorylation(BCL2(), MCL1()),
#  DecreaseAmount(BCL2(mods: (modification)), MCL1()),
#  Activation(BCL2(), MCL1()),
#  Inhibition(BCL2(), MCL1()),
#  Phosphorylation(BCL2(), MAPK14()),
#  Phosphorylation(BCL2(), FADD()),
#  Inhibition(BCL2(), FADD()),
#  Activation(BCL2(), FADD()),
#  Activation(BCL2(bound: [BCL2L1, True]), CYCS()),
#  Activation(BCL2(bound: [it, True]), CYCS()),
#  Activation(BCL2(bound: [BBC3, True]), CYCS()),
#  Inhibition(BCL2(bound: [VDAC1, True]), CYCS()),
#  Inhibition(BCL2(bound: [BAX, True]), CYCS()),
#  DecreaseAmount(BCL2(mods: (modification)), CYCS()),
#  Activation(BCL2(bound: [BAX, True]), CYCS()),
#  Inhibition(BCL2(bound: [vMAP, True]), CYCS()),
#  Activation(BCL2(muts: (None, None, None)), CYCS()),
#  Activation(BCL2(bound: [BAK1, True]), CYCS()),
#  Activation(BCL2(mods: (modification)), CYCS()),
#  IncreaseAmount(BCL2(mods: (modification)), CYCS()),
#  DecreaseAmount(BCL2(), CYCS()),
#  Inhibition(BCL2(mods: (modification)), CYCS()),
#  IncreaseAmount(BCL2(), CYCS()),
#  Activation(BCL2(), CYCS()),
#  Inhibition(BCL2(), CYCS()),
#  DecreaseAmount(BCL2(mods: (modification)), BBC3()),
#  IncreaseAmount(BCL2(), BBC3()),
#  DecreaseAmount(BCL2(), BBC3()),
#  Activation(BCL2(), BBC3()),
#  Inhibition(BCL2(), BBC3()),
#  Activation(BCL2(bound: [BCL2L1, True]), AKT()),
#  Activation(BCL2(), AKT(mods: (phosphorylation))),
#  Phosphorylation(BCL2(mods: (modification)), AKT()),
#  Activation(BCL2(bound: [BECN1, True]), AKT()),
#  Inhibition(BCL2(), AKT(mods: (phosphorylation))),
#  Phosphorylation(BCL2(), AKT(mods: (phosphorylation))),
#  IncreaseAmount(BCL2(), AKT()),
#  Phosphorylation(BCL2(), AKT(), S, 473),
#  Inhibition(BCL2(mods: (modification)), AKT()),
#  Activation(BCL2(), AKT()),
#  IncreaseAmount(BCL2(), AKT(mods: (phosphorylation))),
#  Dephosphorylation(BCL2(), AKT()),
#  Phosphorylation(BCL2(), AKT()),
#  Inhibition(BCL2(), AKT()),
#  Inhibition(BCL2(bound: [CASP9, True], bound: [APAF1, True]), CASP9()),
#  Activation(BCL2(bound: [BAX, True]), CASP9()),
#  Activation(BCL2(bound: [BAK1, True]), CASP9()),
#  DecreaseAmount(BCL2(mods: (modification)), CASP9()),
#  IncreaseAmount(BCL2(mods: (modification)), CASP9()),
#  Activation(BCL2(bound: [HA-HMGA1b (1-43) deletion mutant protein, True]), CASP9()),
#  Activation(BCL2(mods: (modification)), CASP9()),
#  IncreaseAmount(BCL2(), CASP9()),
#  Phosphorylation(BCL2(), CASP9()),
#  DecreaseAmount(BCL2(), CASP9()),
#  Inhibition(BCL2(), CASP9()),
#  Activation(BCL2(), CASP9()),
#  DecreaseAmount(BCL2(mods: (modification)), CASP8()),
#  IncreaseAmount(BCL2(mods: (modification)), CASP8()),
#  Inhibition(BCL2(catalytic), CASP8(), catalytic),
#  DecreaseAmount(BCL2(), CASP8()),
#  Inhibition(BCL2(), CASP8()),
#  Activation(BCL2(), CASP8()),
#  Inhibition(BCL2(mods: (modification)), CASP7()),
#  Activation(BCL2(), CASP7()),
#  Inhibition(BCL2(), CASP7()),
#  Activation(BCL2(muts: (None, None, None)), CASP3()),
#  Activation(BCL2(bound: [BAX, True]), CASP3()),
#  Inhibition(BCL2(mods: (modification)), CASP3()),
#  Phosphorylation(BCL2(), CASP3()),
#  Inhibition(BCL2(), CASP3(), catalytic),
#  Inhibition(BCL2(bound: [BAG4, True]), CASP3()),
#  IncreaseAmount(BCL2(mods: (modification)), CASP3()),
#  Inhibition(BCL2(bound: [BIRC5, True], bound: [DeltaEx3, True]), CASP3()),
#  DecreaseAmount(BCL2(), CASP3()),
#  Activation(BCL2(mods: (modification)), CASP3()),
#  DecreaseAmount(BCL2(mods: (modification)), CASP3()),
#  Activation(BCL2(), CASP3()),
#  IncreaseAmount(BCL2(), CASP3()),
#  Inhibition(BCL2(), CASP3()),
#  DecreaseAmount(BCL2(mods: (modification)), FASLG()),
#  DecreaseAmount(BCL2(), FASLG()),
#  Activation(BCL2(), FASLG()),
#  Inhibition(BCL2(), FASLG()),
#  Phosphorylation(BCL2(), FASLG()),
#  IncreaseAmount(BCL2(), FAS()),
#  DecreaseAmount(BCL2(mods: (modification)), FAS()),
#  Inhibition(BCL2(), FAS()),
#  Activation(BCL2(), FAS()),
#  DecreaseAmount(BCL2(mods: (modification)), TNFRSF1A()),
#  DecreaseAmount(BCL2(), TNF()),
#  IncreaseAmount(BCL2(), TNF()),
#  Activation(BCL2(), TNF()),
#  Inhibition(BCL2(), TNF()),
#  DecreaseAmount(BCL2(mods: (modification)), TNF()),
#  Inhibition(BCL2(mods: (modification)), BID()),
#  IncreaseAmount(BCL2(), BID()),
#  Activation(BCL2(mods: (modification)), BID()),
#  Inhibition(BCL2(), BID()),
#  Activation(BCL2(), BID()),
#  Inhibition(BCL2(), apoptosome()),
#  Activation(BCL2(), apoptosome()),
#  Activation(BCL2(bound: [Its, True]), apoptotic process()),
#  Inhibition(BCL2(muts: (D, 34, A)), apoptotic process()),
#  Inhibition(BCL2(bound: [rs956572 G-allele, True]), apoptotic process()),
#  Activation(BCL2(bound: [IP3R, True]), apoptotic process()),
#  Activation(BCL2(mods: (phosphorylation), bound: [BAX, True]), apoptotic process()),
#  Activation(BCL2(bound: [HBSP, True]), apoptotic process()),
#  Activation(BCL2(bound: [paclitaxel, True]), apoptotic process()),
#  Activation(BCL2(bound: [CDKN1B, True]), apoptotic process()),
#  Activation(BCL2(bound: [NR4A1, True]), apoptotic process()),
#  Activation(BCL2(bound: [BCL2L11, True]), apoptotic process()),
#  Activation(BCL2(bound: [ATG12, True]), apoptotic process()),
#  Activation(BCL2(bound: [1b, True]), apoptotic process()),
#  Inhibition(BCL2(bound: [TMBIM6, True]), apoptotic process()),
#  Activation(BCL2(bound: [AMBRA1, True]), apoptotic process()),
#  Inhibition(BCL2(mods: (phosphorylation)), apoptotic process()),
#  Inhibition(BCL2(bound: [BAG1, True]), apoptotic process()),
#  Inhibition(BCL2(bound: [SERCA, True]), apoptotic process()),
#  Inhibition(BCL2(bound: [BAG3, True]), apoptotic process()),
#  Activation(BCL2(bound: [bax protein-a bcl-2-associated protein, True]), apoptotic process()),
#  Activation(BCL2(bound: [G0S2, True]), apoptotic process()),
#  Activation(BCL2(bound: [HSPB3, True]), apoptotic process()),
#  Activation(BCL2(bound: [cpm-1285, True]), apoptotic process()),
#  Activation(BCL2(muts: (G, 4, S)), apoptotic process()),
#  Activation(BCL2(bound: [PI3K, True]), apoptotic process()),
#  Activation(BCL2(muts: (None, None, None)), apoptotic process()),
#  Inhibition(BCL2(muts: (S, 70, A)), apoptotic process()),
#  Inhibition(BCL2(bound: [BCL2L11, True]), apoptotic process()),
#  Activation(BCL2(bound: [BCL2L1, True]), apoptotic process()),
#  Inhibition(BCL2(bound: [MAPK, True]), apoptotic process()),
#  Inhibition(BCL2(bound: [BBC3, True]), apoptotic process()),
#  Activation(BCL2(bound: [its, True]), apoptotic process()),
#  Inhibition(BCL2(muts: (S, 70, E)), apoptotic process()),
#  Inhibition(BCL2(bound: [ERK, True]), apoptotic process()),
#  Activation(BCL2(mods: (modification)), apoptotic process()),
#  Activation(BCL2(bound: [BAK1, True]), apoptotic process()),
#  Inhibition(BCL2(bound: [BAK1, True]), apoptotic process()),
#  Inhibition(BCL2(muts: (G, 145, A)), apoptotic process()),
#  Activation(BCL2(bound: [RTL10, True]), apoptotic process()),
#  Activation(BCL2(bound: [TP53, True]), apoptotic process()),
#  Activation(BCL2(bound: [BCL2L11, True]), apoptotic process()),
#  Inhibition(BCL2(mods: (modification)), apoptotic process()),
#  Activation(BCL2(bound: [venetoclax, True]), apoptotic process()),
#  Activation(BCL2(bound: [BECN1, True]), apoptotic process()),
#  Inhibition(BCL2(bound: [BCL2L1, True]), apoptotic process()),
#  Inhibition(BCL2(bound: [FKBP8, True]), apoptotic process()),
#  Activation(BCL2(bound: [BBC3, True]), apoptotic process()),
#  Activation(BCL2(bound: [BECN1, True]), apoptotic process()),
#  Inhibition(BCL2(bound: [BCL2L2-PABPN1, True]), apoptotic process()),
#  Activation(BCL2(bound: [BAX, True]), apoptotic process()),
#  Inhibition(BCL2(bound: [LGALS3, True]), apoptotic process()),
#  Inhibition(BCL2(bound: [HSPA9, True]), apoptotic process()),
#  Activation(BCL2(bound: [CDKN1A, True]), apoptotic process()),
#  Inhibition(BCL2(bound: [BECN1, True]), apoptotic process()),
#  Inhibition(BCL2(muts: (None, None, None)), apoptotic process()),
#  Activation(BCL2(bound: [BAD, True]), apoptotic process()),
#  Inhibition(BCL2(bound: [BAX, True]), apoptotic process()),
#  Activation(BCL2(bound: [BMF, True]), apoptotic process()),
#  Inhibition(BCL2(bound: [Casp8p41, True]), apoptotic process()),
#  Activation(BCL2(bound: [it, True]), apoptotic process()),
#  Activation(BCL2(), apoptotic process()),
#  Inhibition(BCL2(), apoptotic process()),
#  Complex(BCL2L1(), Envelope small membrane protein()),
#  Complex(BCL2L1(), BCL2L11(muts: (I, 155, R))),
#  IncreaseAmount(BCL2L1(), BCL2L11()),
#  DecreaseAmount(BCL2L1(), BCL2L11()),
#  Complex(BCL2L1(), BCL2L11(muts: (L, 152, E))),
#  ...]

# %% [markdown]
# Next, we notice that there are many statements that only differ from one another because of some detailed agent states (which include modification states, mutations, bound conditions, activities and cellular location). In this use case, keeping track of these statements is not very useful so we can discard them.

# %%
stmts = [stmt for stmt in stmts if
  all(
    (not agent.location
     and not agent.mods
     and not agent.mutations
     and not agent.bound_conditions
     and not agent.activity) for agent in stmt.agent_list())]
stmts
# Out:
# [IncreaseAmount(BBC3(), BCL2L11()),
#  DecreaseAmount(BBC3(), BCL2L11()),
#  Inhibition(BBC3(), BCL2L11()),
#  Activation(BBC3(), BCL2L11()),
#  Complex(BBC3(), BCL2L11()),
#  Activation(BBC3(), BCL2L1()),
#  Inhibition(BBC3(), BCL2L1()),
#  Complex(BBC3(), BCL2L1()),
#  IncreaseAmount(BBC3(), BCL2()),
#  DecreaseAmount(BBC3(), BCL2()),
#  Inhibition(BBC3(), BCL2()),
#  Activation(BBC3(), BCL2()),
#  Complex(BBC3(), BCL2()),
#  DecreaseAmount(BBC3(), BAX()),
#  IncreaseAmount(BBC3(), BAX()),
#  Inhibition(BBC3(), BAX()),
#  Complex(BBC3(), BAX()),
#  Activation(BBC3(), BAX()),
#  Activation(BBC3(), BAD()),
#  Inhibition(BBC3(), BAD()),
#  Complex(BBC3(), BAD()),
#  IncreaseAmount(BBC3(), MCL1()),
#  Ubiquitination(BBC3(), MCL1()),
#  DecreaseAmount(BBC3(), MCL1()),
#  Inhibition(BBC3(), MCL1()),
#  Activation(BBC3(), MCL1()),
#  Complex(BBC3(), MCL1()),
#  Activation(BBC3(), FADD()),
#  Inhibition(BBC3(), FADD()),
#  Complex(BBC3(), CYCS()),
#  Inhibition(BBC3(), CYCS()),
#  Activation(BBC3(), CYCS()),
#  Inhibition(BBC3(), CASP9()),
#  Activation(BBC3(), CASP9()),
#  Activation(BBC3(), CASP8()),
#  Inhibition(BBC3(), CASP3()),
#  Activation(BBC3(), CASP3()),
#  Inhibition(BBC3(), FAS()),
#  Activation(BBC3(), TNF()),
#  Inhibition(BBC3(), TNF()),
#  Inhibition(BBC3(), BID()),
#  Activation(BBC3(), BID()),
#  Inhibition(BBC3(), apoptotic process()),
#  Activation(BBC3(), apoptotic process()),
#  DecreaseAmount(BBC3(), AKT()),
#  Activation(BBC3(), AKT()),
#  Inhibition(BBC3(), AKT()),
#  DecreaseAmount(CYCS(), AKT()),
#  Inhibition(CYCS(), AKT()),
#  Dephosphorylation(CYCS(), AKT()),
#  Activation(CYCS(), AKT()),
#  IncreaseAmount(CYCS(), AKT()),
#  IncreaseAmount(CYCS(), BCL2L11()),
#  Activation(CYCS(), BCL2L11()),
#  Complex(CYCS(), BCL2L11()),
#  DecreaseAmount(CYCS(), BCL2L11()),
#  Inhibition(CYCS(), BCL2L11()),
#  IncreaseAmount(CYCS(), BCL2L1()),
#  Activation(CYCS(), BCL2L1()),
#  Inhibition(CYCS(), BCL2L1()),
#  DecreaseAmount(CYCS(), BCL2L1()),
#  Complex(CYCS(), BCL2L1()),
#  IncreaseAmount(CYCS(), BCL2()),
#  Inhibition(CYCS(), BCL2()),
#  Activation(CYCS(), BCL2()),
#  DecreaseAmount(CYCS(), BCL2()),
#  Complex(CYCS(), BCL2()),
#  Dephosphorylation(CYCS(), BAX()),
#  IncreaseAmount(CYCS(), BAX()),
#  DecreaseAmount(CYCS(), BAX()),
#  Inhibition(CYCS(), BAX()),
#  Complex(CYCS(), BAX()),
#  Activation(CYCS(), BAX()),
#  Inhibition(CYCS(), BAD()),
#  Complex(CYCS(), BAD()),
#  Activation(CYCS(), BAD()),
#  Phosphorylation(CYCS(), BAD()),
#  DecreaseAmount(CYCS(), MCL1()),
#  Complex(CYCS(), MCL1()),
#  Dephosphorylation(CYCS(), MCL1()),
#  Activation(CYCS(), FADD()),
#  IncreaseAmount(CYCS(), FADD()),
#  Activation(CYCS(), BBC3()),
#  DecreaseAmount(CYCS(), CASP9()),
#  IncreaseAmount(CYCS(), CASP9()),
#  Inhibition(CYCS(), CASP9()),
#  Activation(CYCS(), CASP9()),
#  Inhibition(CYCS(), CASP8()),
#  Activation(CYCS(), CASP8()),
#  Activation(CYCS(), CASP7()),
#  DecreaseAmount(CYCS(), CASP3()),
#  Inhibition(CYCS(), CASP3()),
#  IncreaseAmount(CYCS(), CASP3()),
#  Activation(CYCS(), CASP3()),
#  IncreaseAmount(CYCS(), FASLG()),
#  Activation(CYCS(), FASLG()),
#  IncreaseAmount(CYCS(), FAS()),
#  Inhibition(CYCS(), FAS()),
#  Activation(CYCS(), FAS()),
#  Activation(CYCS(), TNF()),
#  Activation(CYCS(), BID()),
#  Inhibition(CYCS(), BID()),
#  Inhibition(CYCS(), apoptosome()),
#  Activation(CYCS(), apoptosome()),
#  Inhibition(CYCS(), apoptotic process()),
#  Activation(CYCS(), apoptotic process()),
#  Inhibition(apoptotic process(), BCL2L11()),
#  Activation(apoptotic process(), BCL2L11()),
#  IncreaseAmount(apoptotic process(), BCL2L11()),
#  IncreaseAmount(apoptotic process(), BCL2L1()),
#  Activation(apoptotic process(), BCL2L1()),
#  Inhibition(apoptotic process(), BCL2L1()),
#  IncreaseAmount(apoptotic process(), BCL2()),
#  Inhibition(apoptotic process(), BCL2()),
#  Activation(apoptotic process(), BCL2()),
#  IncreaseAmount(apoptotic process(), BAX()),
#  Activation(apoptotic process(), BAX()),
#  Inhibition(apoptotic process(), BAX()),
#  Activation(apoptotic process(), BAD()),
#  Inhibition(apoptotic process(), MCL1()),
#  Activation(apoptotic process(), MCL1()),
#  IncreaseAmount(apoptotic process(), MCL1()),
#  Inhibition(apoptotic process(), FADD()),
#  Activation(apoptotic process(), FADD()),
#  Activation(apoptotic process(), CYCS()),
#  Inhibition(apoptotic process(), CYCS()),
#  IncreaseAmount(apoptotic process(), BBC3()),
#  Activation(apoptotic process(), BBC3()),
#  Inhibition(apoptotic process(), BBC3()),
#  Activation(apoptotic process(), CASP9()),
#  Inhibition(apoptotic process(), CASP9()),
#  Inhibition(apoptotic process(), CASP8()),
#  Activation(apoptotic process(), CASP8()),
#  Inhibition(apoptotic process(), CASP7()),
#  Activation(apoptotic process(), CASP7()),
#  Inhibition(apoptotic process(), CASP3()),
#  Activation(apoptotic process(), CASP3()),
#  IncreaseAmount(apoptotic process(), CASP3()),
#  Inhibition(apoptotic process(), TRADD()),
#  IncreaseAmount(apoptotic process(), FASLG()),
#  Inhibition(apoptotic process(), FASLG()),
#  Activation(apoptotic process(), FASLG()),
#  Inhibition(apoptotic process(), FAS()),
#  IncreaseAmount(apoptotic process(), FAS()),
#  Activation(apoptotic process(), FAS()),
#  Inhibition(apoptotic process(), TNFRSF1A()),
#  Activation(apoptotic process(), TNFRSF1A()),
#  IncreaseAmount(apoptotic process(), TNF()),
#  Inhibition(apoptotic process(), TNF()),
#  Activation(apoptotic process(), TNF()),
#  Inhibition(apoptotic process(), BID()),
#  Activation(apoptotic process(), BID()),
#  Activation(apoptotic process(), AKT()),
#  Inhibition(apoptotic process(), AKT()),
#  Complex(FADD(), BCL2L1()),
#  Activation(FADD(), BCL2()),
#  Complex(FADD(), BCL2()),
#  Inhibition(FADD(), BCL2()),
#  IncreaseAmount(FADD(), BAX()),
#  Activation(FADD(), BAX()),
#  Inhibition(FADD(), CYCS()),
#  Activation(FADD(), CYCS()),
#  Activation(FADD(), BBC3()),
#  Activation(FADD(), CASP9()),
#  Inhibition(FADD(), CASP9()),
#  IncreaseAmount(FADD(), CASP9()),
#  Ubiquitination(FADD(), CASP8()),
#  Activation(FADD(), CASP8(), catalytic),
#  IncreaseAmount(FADD(), CASP8()),
#  DecreaseAmount(FADD(), CASP8()),
#  Inhibition(FADD(), CASP8()),
#  Activation(FADD(), CASP8()),
#  IncreaseAmount(FADD(), CASP3()),
#  Inhibition(FADD(), CASP3()),
#  Acetylation(FADD(), CASP3()),
#  Activation(FADD(), CASP3()),
#  Activation(FADD(), TRADD()),
#  DecreaseAmount(FADD(), FASLG()),
#  Inhibition(FADD(), FASLG()),
#  Activation(FADD(), FASLG()),
#  Inhibition(FADD(), FAS()),
#  Activation(FADD(), FAS()),
#  IncreaseAmount(FADD(), FAS()),
#  Inhibition(FADD(), TNFRSF1A()),
#  Activation(FADD(), TNFRSF1A()),
#  IncreaseAmount(FADD(), TNF()),
#  Inhibition(FADD(), TNF()),
#  Activation(FADD(), TNF()),
#  Inhibition(FADD(), BID()),
#  Activation(FADD(), BID()),
#  Activation(FADD(), apoptotic process()),
#  Inhibition(FADD(), apoptotic process()),
#  Activation(apoptosome(), BAX()),
#  Inhibition(apoptosome(), FADD()),
#  Complex(apoptosome(), CYCS()),
#  Activation(apoptosome(), CYCS()),
#  Activation(apoptosome(), CASP9()),
#  Complex(apoptosome(), CASP9()),
#  Activation(apoptosome(), CASP7()),
#  Complex(apoptosome(), CASP3()),
#  Activation(apoptosome(), CASP3()),
#  Inhibition(apoptosome(), FAS()),
#  Activation(apoptosome(), apoptotic process()),
#  Phosphorylation(MAPK14(), BCL2L11()),
#  Activation(MAPK14(), BCL2L11()),
#  Activation(MAPK14(), BCL2L1()),
#  Phosphorylation(MAPK14(), BCL2L1()),
#  Inhibition(MAPK14(), BCL2L1()),
#  Complex(MAPK14(), BCL2L1()),
#  Phosphorylation(MAPK14(), BCL2L1(), S, 62),
#  Activation(MAPK14(), BCL2()),
#  Phosphorylation(MAPK14(), BCL2(), S, 87),
#  Phosphorylation(MAPK14(), BCL2(), T, 56),
#  Inhibition(MAPK14(), BCL2()),
#  Complex(MAPK14(), BCL2()),
#  Phosphorylation(MAPK14(), BCL2()),
#  IncreaseAmount(MAPK14(), BAX()),
#  Phosphorylation(MAPK14(), BAX()),
#  Inhibition(MAPK14(), BAX()),
#  Activation(MAPK14(), BAX()),
#  Activation(MAPK14(), MCL1()),
#  IncreaseAmount(MAPK14(), BBC3()),
#  Inhibition(MAPK14(), BBC3()),
#  Phosphorylation(MAPK14(), CASP9()),
#  Inhibition(MAPK14(), CASP9()),
#  Inhibition(MAPK14(), CASP8()),
#  DecreaseAmount(MAPK14(), CASP8()),
#  Phosphorylation(MAPK14(), CASP8(), S, 347),
#  Activation(MAPK14(), CASP8()),
#  Phosphorylation(MAPK14(), CASP8()),
#  Activation(MAPK14(), CASP3()),
#  DecreaseAmount(MAPK14(), CASP3()),
#  IncreaseAmount(MAPK14(), CASP3()),
#  Phosphorylation(MAPK14(), CASP3()),
#  Inhibition(MAPK14(), CASP3()),
#  Phosphorylation(MAPK14(), CASP3(), S, 150),
#  Activation(MAPK14(), FASLG()),
#  IncreaseAmount(MAPK14(), FASLG()),
#  Activation(MAPK14(), TNF()),
#  IncreaseAmount(MAPK14(), TNF()),
#  DecreaseAmount(MAPK14(), TNF()),
#  Inhibition(MAPK14(), TNF()),
#  Activation(MAPK14(), apoptotic process()),
#  Inhibition(MAPK14(), apoptotic process()),
#  Activation(MAPK14(), AKT()),
#  Inhibition(MAPK14(), AKT()),
#  Phosphorylation(MAPK14(), AKT()),
#  Phosphorylation(MCL1(), BCL2L11(), S, 87),
#  DecreaseAmount(MCL1(), BCL2L11()),
#  Dephosphorylation(MCL1(), BCL2L11(), S, 69),
#  IncreaseAmount(MCL1(), BCL2L11()),
#  Activation(MCL1(), BCL2L11()),
#  Complex(MCL1(), BCL2L11()),
#  Inhibition(MCL1(), BCL2L11()),
#  DecreaseAmount(MCL1(), BCL2L1()),
#  Phosphorylation(MCL1(), BCL2L1()),
#  Activation(MCL1(), BCL2L1()),
#  Inhibition(MCL1(), BCL2L1()),
#  Complex(MCL1(), BCL2L1()),
#  Dephosphorylation(MCL1(), BCL2()),
#  DecreaseAmount(MCL1(), BCL2()),
#  Phosphorylation(MCL1(), BCL2()),
#  Phosphorylation(MCL1(), BCL2(), T, 56),
#  IncreaseAmount(MCL1(), BCL2()),
#  Inhibition(MCL1(), BCL2()),
#  Activation(MCL1(), BCL2()),
#  Complex(MCL1(), BCL2()),
#  IncreaseAmount(MCL1(), BAX()),
#  DecreaseAmount(MCL1(), BAX()),
#  Activation(MCL1(), BAX()),
#  Complex(MCL1(), BAX()),
#  Inhibition(MCL1(), BAX()),
#  Activation(MCL1(), BAD()),
#  Phosphorylation(MCL1(), BAD()),
#  DecreaseAmount(MCL1(), BAD()),
#  Inhibition(MCL1(), BAD()),
#  Complex(MCL1(), BAD()),
#  Inhibition(MCL1(), CYCS()),
#  Activation(MCL1(), CYCS()),
#  IncreaseAmount(MCL1(), BBC3()),
#  Inhibition(MCL1(), BBC3()),
#  Activation(MCL1(), BBC3()),
#  Activation(MCL1(), CASP9()),
#  Inhibition(MCL1(), CASP9()),
#  Activation(MCL1(), CASP8()),
#  Inhibition(MCL1(), CASP8()),
#  Inhibition(MCL1(), CASP7()),
#  IncreaseAmount(MCL1(), CASP3()),
#  Activation(MCL1(), CASP3()),
#  Inhibition(MCL1(), CASP3()),
#  Inhibition(MCL1(), FASLG()),
#  Inhibition(MCL1(), FAS()),
#  IncreaseAmount(MCL1(), FAS()),
#  Inhibition(MCL1(), TNF()),
#  Activation(MCL1(), TNF()),
#  DecreaseAmount(MCL1(), BID()),
#  Activation(MCL1(), BID()),
#  Inhibition(MCL1(), BID()),
#  Inhibition(MCL1(), apoptotic process()),
#  Activation(MCL1(), apoptotic process()),
#  Phosphorylation(MCL1(), AKT()),
#  Inhibition(MCL1(), AKT()),
#  Activation(MCL1(), AKT()),
#  DecreaseAmount(BAD(), BCL2L11()),
#  Activation(BAD(), BCL2L11()),
#  Complex(BAD(), BCL2L11()),
#  Inhibition(BAD(), BCL2L11()),
#  Phosphorylation(BAD(), BCL2L1()),
#  IncreaseAmount(BAD(), BCL2L1()),
#  Inhibition(BAD(), BCL2L1()),
#  Activation(BAD(), BCL2L1()),
#  Complex(BAD(), BCL2L1()),
#  Phosphorylation(BAD(), BCL2()),
#  DecreaseAmount(BAD(), BCL2()),
#  IncreaseAmount(BAD(), BCL2()),
#  Inhibition(BAD(), BCL2()),
#  Activation(BAD(), BCL2()),
#  Complex(BAD(), BCL2()),
#  DecreaseAmount(BAD(), BAX()),
#  IncreaseAmount(BAD(), BAX()),
#  Phosphorylation(BAD(), BAX()),
#  Dephosphorylation(BAD(), BAX()),
#  Inhibition(BAD(), BAX()),
#  Activation(BAD(), BAX()),
#  Complex(BAD(), BAX()),
#  Phosphorylation(BAD(), MCL1()),
#  Inhibition(BAD(), MCL1()),
#  Activation(BAD(), MCL1()),
#  Inhibition(BAD(), CYCS()),
#  Phosphorylation(BAD(), CYCS()),
#  Activation(BAD(), CYCS()),
#  IncreaseAmount(BAD(), CASP9()),
#  Dephosphorylation(BAD(), CASP9()),
#  Activation(BAD(), CASP9()),
#  Inhibition(BAD(), CASP9()),
#  Activation(BAD(), CASP8()),
#  Inhibition(BAD(), CASP8()),
#  Phosphorylation(BAD(), CASP3()),
#  Activation(BAD(), CASP3()),
#  Inhibition(BAD(), CASP3()),
#  Activation(BAD(), FASLG()),
#  IncreaseAmount(BAD(), FASLG()),
#  Inhibition(BAD(), FAS()),
#  IncreaseAmount(BAD(), FAS()),
#  Activation(BAD(), FAS()),
#  Activation(BAD(), TNF()),
#  Inhibition(BAD(), TNF()),
#  IncreaseAmount(BAD(), BID()),
#  Inhibition(BAD(), BID()),
#  Activation(BAD(), BID()),
#  Inhibition(BAD(), apoptotic process()),
#  Activation(BAD(), apoptotic process()),
#  Phosphorylation(BAD(), AKT(), S, 136),
#  Inhibition(BAD(), AKT()),
#  Phosphorylation(BAD(), AKT(), T, 308),
#  Phosphorylation(BAD(), AKT(), S, 473),
#  DecreaseAmount(BAD(), AKT()),
#  Phosphorylation(BAD(), AKT()),
#  Activation(BAD(), AKT()),
#  IncreaseAmount(BAX(), BCL2L11()),
#  Inhibition(BAX(), BCL2L11()),
#  Activation(BAX(), BCL2L11()),
#  Complex(BAX(), BCL2L11()),
#  DecreaseAmount(BAX(), BCL2L1()),
#  IncreaseAmount(BAX(), BCL2L1()),
#  Activation(BAX(), BCL2L1()),
#  Inhibition(BAX(), BCL2L1()),
#  Complex(BAX(), BCL2L1()),
#  Methylation(BAX(), BCL2()),
#  Phosphorylation(BAX(), BCL2()),
#  DecreaseAmount(BAX(), BCL2()),
#  Activation(BAX(), BCL2()),
#  Inhibition(BAX(), BCL2()),
#  IncreaseAmount(BAX(), BCL2()),
#  Complex(BAX(), BCL2()),
#  IncreaseAmount(BAX(), BAD()),
#  Phosphorylation(BAX(), BAD()),
#  Inhibition(BAX(), BAD()),
#  Activation(BAX(), BAD()),
#  DecreaseAmount(BAX(), MCL1()),
#  IncreaseAmount(BAX(), MCL1()),
#  Inhibition(BAX(), MCL1()),
#  Activation(BAX(), MCL1()),
#  Activation(BAX(), MAPK14()),
#  DecreaseAmount(BAX(), FADD()),
#  DecreaseAmount(BAX(), CYCS()),
#  IncreaseAmount(BAX(), CYCS()),
#  Inhibition(BAX(), CYCS()),
#  Activation(BAX(), CYCS()),
#  IncreaseAmount(BAX(), BBC3()),
#  Inhibition(BAX(), BBC3()),
#  DecreaseAmount(BAX(), BBC3()),
#  Activation(BAX(), BBC3()),
#  Ubiquitination(BAX(), CASP9()),
#  DecreaseAmount(BAX(), CASP9()),
#  IncreaseAmount(BAX(), CASP9()),
#  Inhibition(BAX(), CASP9()),
#  Activation(BAX(), CASP9()),
#  IncreaseAmount(BAX(), CASP8()),
#  DecreaseAmount(BAX(), CASP8()),
#  Activation(BAX(), CASP8()),
#  Inhibition(BAX(), CASP8()),
#  Inhibition(BAX(), CASP7()),
#  Activation(BAX(), CASP7()),
#  DecreaseAmount(BAX(), CASP7()),
#  DecreaseAmount(BAX(), CASP3()),
#  Inhibition(BAX(), CASP3()),
#  Activation(BAX(), CASP3()),
#  IncreaseAmount(BAX(), CASP3()),
#  DecreaseAmount(BAX(), TRADD()),
#  Activation(BAX(), FASLG()),
#  DecreaseAmount(BAX(), FASLG()),
#  Inhibition(BAX(), FAS()),
#  DecreaseAmount(BAX(), FAS()),
#  IncreaseAmount(BAX(), FAS()),
#  Activation(BAX(), FAS()),
#  Activation(BAX(), TNFRSF1A()),
#  DecreaseAmount(BAX(), TNF()),
#  Activation(BAX(), TNF()),
#  IncreaseAmount(BAX(), TNF()),
#  Inhibition(BAX(), TNF()),
#  Inhibition(BAX(), BID()),
#  IncreaseAmount(BAX(), BID()),
#  Activation(BAX(), BID()),
#  Inhibition(BAX(), apoptosome()),
#  Activation(BAX(), apoptosome()),
#  IncreaseAmount(BAX(), apoptotic process()),
#  Inhibition(BAX(), apoptotic process()),
#  Activation(BAX(), apoptotic process()),
#  Phosphorylation(BAX(), AKT(), D, 1),
#  Activation(BAX(), AKT()),
#  Phosphorylation(BAX(), AKT()),
#  IncreaseAmount(BAX(), AKT()),
#  Dephosphorylation(BAX(), AKT()),
#  Inhibition(BAX(), AKT()),
#  DecreaseAmount(BCL2(), BCL2L11()),
#  Activation(BCL2(), BCL2L11()),
#  IncreaseAmount(BCL2(), BCL2L11()),
#  Complex(BCL2(), BCL2L11()),
#  Inhibition(BCL2(), BCL2L11()),
#  IncreaseAmount(BCL2(), BCL2L1()),
#  DecreaseAmount(BCL2(), BCL2L1()),
#  Phosphorylation(BCL2(), BCL2L1()),
#  Inhibition(BCL2(), BCL2L1()),
#  Activation(BCL2(), BCL2L1()),
#  Complex(BCL2(), BCL2L1()),
#  Phosphorylation(BCL2(), BAX()),
#  Dephosphorylation(BCL2(), BAX()),
#  DecreaseAmount(BCL2(), BAX()),
#  Activation(BCL2(), BAX()),
#  Inhibition(BCL2(), BAX()),
#  IncreaseAmount(BCL2(), BAX()),
#  IncreaseAmount(BCL2(), BAD()),
#  DecreaseAmount(BCL2(), BAD()),
#  Dephosphorylation(BCL2(), BAD()),
#  Phosphorylation(BCL2(), BAD()),
#  Inhibition(BCL2(), BAD()),
#  Activation(BCL2(), BAD()),
#  DecreaseAmount(BCL2(), MCL1()),
#  IncreaseAmount(BCL2(), MCL1()),
#  Phosphorylation(BCL2(), MCL1()),
#  Activation(BCL2(), MCL1()),
#  Inhibition(BCL2(), MCL1()),
#  Phosphorylation(BCL2(), MAPK14()),
#  Phosphorylation(BCL2(), FADD()),
#  Inhibition(BCL2(), FADD()),
#  Activation(BCL2(), FADD()),
#  DecreaseAmount(BCL2(), CYCS()),
#  IncreaseAmount(BCL2(), CYCS()),
#  Activation(BCL2(), CYCS()),
#  Inhibition(BCL2(), CYCS()),
#  IncreaseAmount(BCL2(), BBC3()),
#  DecreaseAmount(BCL2(), BBC3()),
#  Activation(BCL2(), BBC3()),
#  Inhibition(BCL2(), BBC3()),
#  IncreaseAmount(BCL2(), AKT()),
#  Phosphorylation(BCL2(), AKT(), S, 473),
#  Activation(BCL2(), AKT()),
#  Dephosphorylation(BCL2(), AKT()),
#  Phosphorylation(BCL2(), AKT()),
#  Inhibition(BCL2(), AKT()),
#  IncreaseAmount(BCL2(), CASP9()),
#  Phosphorylation(BCL2(), CASP9()),
#  DecreaseAmount(BCL2(), CASP9()),
#  Inhibition(BCL2(), CASP9()),
#  Activation(BCL2(), CASP9()),
#  DecreaseAmount(BCL2(), CASP8()),
#  Inhibition(BCL2(), CASP8()),
#  Activation(BCL2(), CASP8()),
#  Activation(BCL2(), CASP7()),
#  Inhibition(BCL2(), CASP7()),
#  Phosphorylation(BCL2(), CASP3()),
#  Inhibition(BCL2(), CASP3(), catalytic),
#  DecreaseAmount(BCL2(), CASP3()),
#  Activation(BCL2(), CASP3()),
#  IncreaseAmount(BCL2(), CASP3()),
#  Inhibition(BCL2(), CASP3()),
#  DecreaseAmount(BCL2(), FASLG()),
#  Activation(BCL2(), FASLG()),
#  Inhibition(BCL2(), FASLG()),
#  Phosphorylation(BCL2(), FASLG()),
#  IncreaseAmount(BCL2(), FAS()),
#  Inhibition(BCL2(), FAS()),
#  Activation(BCL2(), FAS()),
#  DecreaseAmount(BCL2(), TNF()),
#  IncreaseAmount(BCL2(), TNF()),
#  Activation(BCL2(), TNF()),
#  Inhibition(BCL2(), TNF()),
#  IncreaseAmount(BCL2(), BID()),
#  Inhibition(BCL2(), BID()),
#  Activation(BCL2(), BID()),
#  Inhibition(BCL2(), apoptosome()),
#  Activation(BCL2(), apoptosome()),
#  Activation(BCL2(), apoptotic process()),
#  Inhibition(BCL2(), apoptotic process()),
#  Complex(BCL2L1(), Envelope small membrane protein()),
#  IncreaseAmount(BCL2L1(), BCL2L11()),
#  DecreaseAmount(BCL2L1(), BCL2L11()),
#  Phosphorylation(BCL2L1(), BCL2L11(), S, 69),
#  Dephosphorylation(BCL2L1(), BCL2L11(), S, 87),
#  Inhibition(BCL2L1(), BCL2L11()),
#  Complex(BCL2L1(), BCL2L11()),
#  Activation(BCL2L1(), BCL2L11()),
#  Dephosphorylation(BCL2L1(), BCL2()),
#  DecreaseAmount(BCL2L1(), BCL2()),
#  Phosphorylation(BCL2L1(), BCL2()),
#  Ubiquitination(BCL2L1(), BCL2()),
#  Activation(BCL2L1(), BCL2()),
#  IncreaseAmount(BCL2L1(), BCL2()),
#  Inhibition(BCL2L1(), BCL2()),
#  Phosphorylation(BCL2L1(), BAX()),
#  DecreaseAmount(BCL2L1(), BAX()),
#  IncreaseAmount(BCL2L1(), BAX()),
#  Activation(BCL2L1(), BAX()),
#  Inhibition(BCL2L1(), BAX()),
#  Phosphorylation(BCL2L1(), BAD(), S, 75),
#  IncreaseAmount(BCL2L1(), BAD()),
#  Inhibition(BCL2L1(), BAD()),
#  Dephosphorylation(BCL2L1(), BAD()),
#  Activation(BCL2L1(), BAD()),
#  DecreaseAmount(BCL2L1(), MCL1()),
#  IncreaseAmount(BCL2L1(), MCL1()),
#  Phosphorylation(BCL2L1(), MCL1()),
#  Activation(BCL2L1(), MCL1()),
#  Inhibition(BCL2L1(), MCL1()),
#  Activation(BCL2L1(), MAPK14()),
#  Activation(BCL2L1(), FADD()),
#  Inhibition(BCL2L1(), FADD()),
#  IncreaseAmount(BCL2L1(), CYCS()),
#  DecreaseAmount(BCL2L1(), CYCS()),
#  Activation(BCL2L1(), CYCS()),
#  Inhibition(BCL2L1(), CYCS()),
#  DecreaseAmount(BCL2L1(), BBC3()),
#  Activation(BCL2L1(), BBC3()),
#  Inhibition(BCL2L1(), BBC3()),
#  Activation(BCL2L1(), CASP9()),
#  Inhibition(BCL2L1(), CASP9()),
#  Activation(BCL2L1(), CASP8()),
#  Inhibition(BCL2L1(), CASP8()),
#  Phosphorylation(BCL2L1(), CASP3()),
#  DecreaseAmount(BCL2L1(), CASP3()),
#  IncreaseAmount(BCL2L1(), CASP3()),
#  Inhibition(BCL2L1(), CASP3()),
#  Activation(BCL2L1(), CASP3()),
#  DecreaseAmount(BCL2L1(), FAS()),
#  Activation(BCL2L1(), FAS()),
#  Inhibition(BCL2L1(), FAS()),
#  Activation(BCL2L1(), TNF()),
#  DecreaseAmount(BCL2L1(), TNF()),
#  Inhibition(BCL2L1(), TNF()),
#  DecreaseAmount(BCL2L1(), BID()),
#  Inhibition(BCL2L1(), BID()),
#  Activation(BCL2L1(), BID()),
#  Activation(BCL2L1(), apoptotic process()),
#  Inhibition(BCL2L1(), apoptotic process()),
#  Phosphorylation(BCL2L1(), AKT()),
#  Inhibition(BCL2L1(), AKT()),
#  Phosphorylation(BCL2L1(), AKT(), A, 549),
#  Activation(BCL2L1(), AKT()),
#  DecreaseAmount(BCL2L11(), BCL2L1()),
#  IncreaseAmount(BCL2L11(), BCL2L1()),
#  Activation(BCL2L11(), BCL2L1()),
#  Inhibition(BCL2L11(), BCL2L1()),
#  IncreaseAmount(BCL2L11(), BCL2()),
#  Phosphorylation(BCL2L11(), BCL2()),
#  Activation(BCL2L11(), BCL2()),
#  DecreaseAmount(BCL2L11(), BCL2()),
#  Inhibition(BCL2L11(), BCL2()),
#  IncreaseAmount(BCL2L11(), BAX()),
#  Inhibition(BCL2L11(), BAX()),
#  Activation(BCL2L11(), BAX()),
#  Activation(BCL2L11(), BAD()),
#  Inhibition(BCL2L11(), BAD()),
#  DecreaseAmount(BCL2L11(), MCL1()),
#  IncreaseAmount(BCL2L11(), MCL1()),
#  Inhibition(BCL2L11(), MCL1()),
#  Activation(BCL2L11(), MCL1()),
#  IncreaseAmount(BCL2L11(), CYCS()),
#  Inhibition(BCL2L11(), CYCS()),
#  Activation(BCL2L11(), CYCS()),
#  IncreaseAmount(BCL2L11(), BBC3()),
#  DecreaseAmount(BCL2L11(), BBC3()),
#  Activation(BCL2L11(), BBC3()),
#  Inhibition(BCL2L11(), BBC3()),
#  Activation(BCL2L11(), CASP9()),
#  Inhibition(BCL2L11(), CASP9()),
#  Activation(BCL2L11(), CASP7()),
#  Dephosphorylation(BCL2L11(), CASP3()),
#  Activation(BCL2L11(), CASP3()),
#  Inhibition(BCL2L11(), CASP3()),
#  IncreaseAmount(BCL2L11(), CASP3()),
#  IncreaseAmount(BCL2L11(), FASLG()),
#  Activation(BCL2L11(), FAS()),
#  Inhibition(BCL2L11(), TNF()),
#  Activation(BCL2L11(), TNF()),
#  Activation(BCL2L11(), BID()),
#  IncreaseAmount(BCL2L11(), BID()),
#  Inhibition(BCL2L11(), BID()),
#  Activation(BCL2L11(), apoptotic process()),
#  Inhibition(BCL2L11(), apoptotic process()),
#  Dephosphorylation(BCL2L11(), AKT(), S, 473),
#  IncreaseAmount(BCL2L11(), AKT()),
#  Activation(BCL2L11(), AKT()),
#  Inhibition(BCL2L11(), AKT()),
#  Phosphorylation(BCL2L11(), AKT()),
#  Dephosphorylation(BCL2L11(), AKT()),
#  Complex(BID(), FADD()),
#  IncreaseAmount(BID(), CYCS()),
#  DecreaseAmount(BID(), CYCS()),
#  Complex(BID(), CYCS()),
#  Inhibition(BID(), CYCS()),
#  Activation(BID(), CYCS()),
#  Inhibition(BID(), BBC3()),
#  Complex(BID(), BBC3()),
#  Activation(BID(), BBC3()),
#  DecreaseAmount(BID(), CASP9()),
#  Complex(BID(), CASP9()),
#  Inhibition(BID(), CASP9()),
#  Activation(BID(), CASP9()),
#  IncreaseAmount(BID(), CASP8()),
#  Inhibition(BID(), CASP8()),
#  Complex(BID(), CASP8()),
#  Activation(BID(), CASP8()),
#  Activation(BID(), CASP7()),
#  Complex(BID(), CASP3()),
#  Inhibition(BID(), CASP3()),
#  Activation(BID(), CASP3()),
#  Activation(BID(), FASLG()),
#  IncreaseAmount(BID(), FASLG()),
#  Complex(BID(), FASLG()),
#  IncreaseAmount(BID(), FAS()),
#  Complex(BID(), FAS()),
#  Activation(BID(), FAS()),
#  Inhibition(BID(), FAS()),
#  Complex(BID(), TNFRSF1A()),
#  Activation(BID(), TNF()),
#  Inhibition(BID(), TNF()),
#  IncreaseAmount(BID(), TNF()),
#  Complex(BID(), TNF()),
#  Activation(BID(), apoptosome()),
#  Inhibition(BID(), apoptotic process()),
#  Activation(BID(), apoptotic process()),
#  Inhibition(BID(), AKT()),
#  IncreaseAmount(BID(), BCL2L11()),
#  Activation(BID(), BCL2L11()),
#  Inhibition(BID(), BCL2L11()),
#  Complex(BID(), BCL2L11()),
#  IncreaseAmount(BID(), BCL2L1()),
#  Inhibition(BID(), BCL2L1()),
#  Activation(BID(), BCL2L1()),
#  Complex(BID(), BCL2L1()),
#  IncreaseAmount(BID(), BCL2()),
#  Phosphorylation(BID(), BCL2()),
#  Activation(BID(), BCL2()),
#  Complex(BID(), BCL2()),
#  Inhibition(BID(), BCL2()),
#  IncreaseAmount(BID(), BAX()),
#  Inhibition(BID(), BAX()),
#  Activation(BID(), BAX()),
#  Complex(BID(), BAX()),
#  IncreaseAmount(BID(), BAD()),
#  Inhibition(BID(), BAD()),
#  Complex(BID(), BAD()),
#  Activation(BID(), BAD()),
#  IncreaseAmount(BID(), MCL1()),
#  Activation(BID(), MCL1()),
#  Inhibition(BID(), MCL1()),
#  Complex(BID(), MCL1()),
#  Complex(TNF(), BCL2L11()),
#  IncreaseAmount(TNF(), BCL2L11()),
#  Activation(TNF(), BCL2L11()),
#  Dephosphorylation(TNF(), BCL2L1()),
#  Inhibition(TNF(), BCL2L1()),
#  Phosphorylation(TNF(), BCL2L1()),
#  Complex(TNF(), BCL2L1()),
#  DecreaseAmount(TNF(), BCL2L1()),
#  IncreaseAmount(TNF(), BCL2L1()),
#  Activation(TNF(), BCL2L1()),
#  Ubiquitination(TNF(), BCL2()),
#  Phosphorylation(TNF(), BCL2()),
#  Dephosphorylation(TNF(), BCL2(), S, 87),
#  IncreaseAmount(TNF(), BCL2()),
#  Complex(TNF(), BCL2()),
#  Activation(TNF(), BCL2()),
#  Inhibition(TNF(), BCL2()),
#  DecreaseAmount(TNF(), BCL2()),
#  DecreaseAmount(TNF(), BAX()),
#  Complex(TNF(), BAX()),
#  Inhibition(TNF(), BAX()),
#  IncreaseAmount(TNF(), BAX()),
#  Activation(TNF(), BAX()),
#  Complex(TNF(), BAD()),
#  Dephosphorylation(TNF(), BAD()),
#  Phosphorylation(TNF(), BAD(), S, 75),
#  Phosphorylation(TNF(), BAD(), S, 118),
#  Phosphorylation(TNF(), BAD(), S, 99),
#  Inhibition(TNF(), BAD()),
#  IncreaseAmount(TNF(), BAD()),
#  Phosphorylation(TNF(), BAD()),
#  Activation(TNF(), BAD()),
#  Inhibition(TNF(), MCL1()),
#  DecreaseAmount(TNF(), MCL1()),
#  Activation(TNF(), MCL1()),
#  Phosphorylation(TNF(), MCL1()),
#  IncreaseAmount(TNF(), MCL1()),
#  Inhibition(TNF(), MAPK14()),
#  IncreaseAmount(TNF(), MAPK14()),
#  Activation(TNF(), MAPK14()),
#  Phosphorylation(TNF(), MAPK14()),
#  Complex(TNF(), FADD()),
#  Inhibition(TNF(), FADD()),
#  IncreaseAmount(TNF(), FADD()),
#  DecreaseAmount(TNF(), FADD()),
#  Activation(TNF(), FADD()),
#  Dephosphorylation(TNF(), CASP9()),
#  DecreaseAmount(TNF(), CASP9()),
#  Inhibition(TNF(), CASP9()),
#  IncreaseAmount(TNF(), CASP9()),
#  Activation(TNF(), CASP9()),
#  Activation(TNF(), CASP8(), catalytic),
#  Complex(TNF(), CASP8()),
#  Inhibition(TNF(), CASP8()),
#  DecreaseAmount(TNF(), CASP8()),
#  IncreaseAmount(TNF(), CASP8()),
#  Activation(TNF(), CASP8()),
#  IncreaseAmount(TNF(), CASP7()),
#  Complex(TNF(), CASP7()),
#  Activation(TNF(), CASP7()),
#  Inhibition(TNF(), CASP7()),
#  Activation(TNF(), CASP7(), catalytic),
#  DecreaseAmount(TNF(), CASP3()),
#  Dephosphorylation(TNF(), CASP3()),
#  Complex(TNF(), CASP3()),
#  IncreaseAmount(TNF(), CASP3()),
#  Activation(TNF(), CASP3(), catalytic),
#  Inhibition(TNF(), CASP3()),
#  Activation(TNF(), CASP3()),
#  IncreaseAmount(TNF(), CYCS()),
#  Inhibition(TNF(), CYCS()),
#  Activation(TNF(), CYCS()),
#  DecreaseAmount(TNF(), TRADD()),
#  Inhibition(TNF(), TRADD()),
#  IncreaseAmount(TNF(), TRADD()),
#  Phosphorylation(TNF(), TRADD()),
#  Activation(TNF(), TRADD()),
#  Complex(TNF(), TRADD()),
#  IncreaseAmount(TNF(), FASLG()),
#  DecreaseAmount(TNF(), FASLG()),
#  Activation(TNF(), FASLG()),
#  Inhibition(TNF(), FASLG()),
#  Complex(TNF(), FASLG()),
#  Inhibition(TNF(), apoptotic process()),
#  Activation(TNF(), apoptotic process()),
#  Activation(TNF(), FAS(), catalytic),
#  DecreaseAmount(TNF(), FAS()),
#  IncreaseAmount(TNF(), FAS()),
#  Complex(TNF(), FAS()),
#  Activation(TNF(), FAS()),
#  Inhibition(TNF(), FAS()),
#  Ubiquitination(TNF(), TNFRSF1A()),
#  Phosphorylation(TNF(), TNFRSF1A(), S, 381),
#  Phosphorylation(TNF(), TNFRSF1A()),
#  DecreaseAmount(TNF(), TNFRSF1A()),
#  Activation(TNF(), TNFRSF1A(), catalytic),
#  Inhibition(TNF(), TNFRSF1A()),
#  IncreaseAmount(TNF(), TNFRSF1A()),
#  Complex(TNF(), TNFRSF1A()),
#  Activation(TNF(), TNFRSF1A()),
#  Dephosphorylation(TNF(), AKT(), Y),
#  Phosphorylation(TNF(), AKT(), S),
#  Phosphorylation(TNF(), AKT(), 473),
#  Dephosphorylation(TNF(), AKT(), 473),
#  Phosphorylation(TNF(), AKT(), S, 473),
#  Dephosphorylation(TNF(), AKT(), S, 473),
#  Phosphorylation(TNF(), AKT(), T, 427),
#  DecreaseAmount(TNF(), AKT()),
#  IncreaseAmount(TNF(), AKT()),
#  Ubiquitination(TNF(), AKT()),
#  Dephosphorylation(TNF(), AKT(), T, 308),
#  Phosphorylation(TNF(), AKT(), T),
#  Phosphorylation(TNF(), AKT(), T, 308),
#  Phosphorylation(TNF(), AKT()),
#  Dephosphorylation(TNF(), AKT()),
#  Activation(TNF(), AKT()),
#  Inhibition(TNF(), AKT()),
#  IncreaseAmount(TNF(), BID()),
#  Inhibition(TNF(), BID()),
#  DecreaseAmount(TNF(), BID()),
#  Activation(TNF(), BID()),
#  Complex(TNF(), BBC3()),
#  DecreaseAmount(TNF(), BBC3()),
#  Inhibition(TNF(), BBC3()),
#  IncreaseAmount(TNF(), BBC3()),
#  Activation(TNF(), BBC3()),
#  DecreaseAmount(TNFRSF1A(), BCL2()),
#  IncreaseAmount(TNFRSF1A(), BAX()),
#  Activation(TNFRSF1A(), BAX()),
#  Activation(TNFRSF1A(), MAPK14()),
#  IncreaseAmount(TNFRSF1A(), FADD()),
#  Phosphorylation(TNFRSF1A(), FADD()),
#  Activation(TNFRSF1A(), FADD()),
#  Complex(TNFRSF1A(), FADD()),
#  IncreaseAmount(TNFRSF1A(), CASP8()),
#  Inhibition(TNFRSF1A(), CASP8()),
#  Complex(TNFRSF1A(), CASP8()),
#  Activation(TNFRSF1A(), CASP8()),
#  Complex(TNFRSF1A(), CASP7()),
#  IncreaseAmount(TNFRSF1A(), CASP3()),
#  Complex(TNFRSF1A(), CASP3()),
#  DecreaseAmount(TNFRSF1A(), CASP3()),
#  Activation(TNFRSF1A(), CASP3()),
#  Inhibition(TNFRSF1A(), TRADD()),
#  Activation(TNFRSF1A(), TRADD()),
#  Complex(TNFRSF1A(), TRADD()),
#  Activation(TNFRSF1A(), FASLG()),
#  Complex(TNFRSF1A(), FASLG()),
#  Inhibition(TNFRSF1A(), FAS()),
#  IncreaseAmount(TNFRSF1A(), FAS()),
#  Activation(TNFRSF1A(), FAS()),
#  Complex(TNFRSF1A(), FAS()),
#  Phosphorylation(TNFRSF1A(), TNF()),
#  DecreaseAmount(TNFRSF1A(), TNF()),
#  IncreaseAmount(TNFRSF1A(), TNF()),
#  Inhibition(TNFRSF1A(), TNF()),
#  Activation(TNFRSF1A(), TNF()),
#  Activation(TNFRSF1A(), BID()),
#  Inhibition(TNFRSF1A(), apoptotic process()),
#  Activation(TNFRSF1A(), apoptotic process()),
#  Phosphorylation(TNFRSF1A(), AKT(), S, 473),
#  Phosphorylation(TNFRSF1A(), AKT(), T, 308),
#  Phosphorylation(TNFRSF1A(), AKT()),
#  Inhibition(TNFRSF1A(), AKT()),
#  Activation(TNFRSF1A(), AKT()),
#  Inhibition(FAS(), TNFRSF1A()),
#  IncreaseAmount(FAS(), TNFRSF1A()),
#  DecreaseAmount(FAS(), TNFRSF1A()),
#  Activation(FAS(), TNFRSF1A()),
#  DecreaseAmount(FAS(), TNF()),
#  IncreaseAmount(FAS(), TNF()),
#  Activation(FAS(), TNF()),
#  Inhibition(FAS(), TNF()),
#  IncreaseAmount(FAS(), BID()),
#  DecreaseAmount(FAS(), BID()),
#  Activation(FAS(), BID()),
#  Inhibition(FAS(), BID()),
#  Dephosphorylation(FAS(), BID()),
#  Inhibition(FAS(), apoptotic process()),
#  Activation(FAS(), apoptotic process()),
#  Activation(FAS(), BCL2L11()),
#  IncreaseAmount(FAS(), BCL2L11()),
#  Complex(FAS(), BCL2L11()),
#  Activation(FAS(), BCL2L1()),
#  Complex(FAS(), BCL2L1()),
#  Inhibition(FAS(), BCL2L1()),
#  DecreaseAmount(FAS(), BCL2L1()),
#  IncreaseAmount(FAS(), BCL2()),
#  Dephosphorylation(FAS(), BCL2()),
#  Inhibition(FAS(), BCL2()),
#  Complex(FAS(), BCL2()),
#  DecreaseAmount(FAS(), BCL2()),
#  Activation(FAS(), BCL2()),
#  Phosphorylation(FAS(), AKT(), T, 308),
#  Phosphorylation(FAS(), AKT()),
#  Inhibition(FAS(), AKT()),
#  DecreaseAmount(FAS(), AKT()),
#  Activation(FAS(), AKT()),
#  Complex(FAS(), BAX()),
#  Inhibition(FAS(), BAX()),
#  IncreaseAmount(FAS(), BAX()),
#  DecreaseAmount(FAS(), BAX()),
#  Activation(FAS(), BAX()),
#  Phosphorylation(FAS(), BAD(), S, 99),
#  Inhibition(FAS(), BAD()),
#  DecreaseAmount(FAS(), MCL1()),
#  IncreaseAmount(FAS(), MCL1()),
#  Inhibition(FAS(), MCL1()),
#  Inhibition(FAS(), MAPK14()),
#  Phosphorylation(FAS(), FADD(), 194),
#  Phosphorylation(FAS(), FADD(), S),
#  Inhibition(FAS(), FADD()),
#  Phosphorylation(FAS(), FADD(), S, 194),
#  IncreaseAmount(FAS(), FADD()),
#  Dephosphorylation(FAS(), FADD(), S, 194),
#  Phosphorylation(FAS(), FADD()),
#  Activation(FAS(), FADD()),
#  Complex(FAS(), FADD()),
#  Dephosphorylation(FAS(), CYCS()),
#  Complex(FAS(), CYCS()),
#  DecreaseAmount(FAS(), CYCS()),
#  Activation(FAS(), CYCS()),
#  Inhibition(FAS(), CYCS()),
#  IncreaseAmount(FAS(), CYCS()),
#  Inhibition(FAS(), CASP9()),
#  Activation(FAS(), CASP9()),
#  Dephosphorylation(FAS(), CASP8()),
#  DecreaseAmount(FAS(), CASP8()),
#  Activation(FAS(), CASP8(), catalytic),
#  Phosphorylation(FAS(), CASP8()),
#  IncreaseAmount(FAS(), CASP8()),
#  Inhibition(FAS(), CASP8()),
#  Complex(FAS(), CASP8()),
#  Activation(FAS(), CASP8()),
#  Activation(FAS(), CASP7()),
#  DecreaseAmount(FAS(), CASP3()),
#  Acetylation(FAS(), CASP3()),
#  Dephosphorylation(FAS(), CASP3()),
#  IncreaseAmount(FAS(), CASP3()),
#  Complex(FAS(), CASP3()),
#  Activation(FAS(), CASP3(), catalytic),
#  Activation(FAS(), CASP3()),
#  Inhibition(FAS(), CASP3()),
#  Activation(FAS(), TRADD()),
#  Complex(FAS(), TRADD()),
#  IncreaseAmount(FAS(), FASLG()),
#  DecreaseAmount(FAS(), FASLG()),
#  Inhibition(FAS(), FASLG()),
#  Activation(FAS(), FASLG()),
#  Complex(FAS(), FASLG()),
#  Complex(FASLG(), BCL2L11()),
#  Activation(FASLG(), BCL2L11()),
#  Activation(FASLG(), BCL2L1()),
#  DecreaseAmount(FASLG(), BCL2L1()),
#  IncreaseAmount(FASLG(), BCL2L1()),
#  Inhibition(FASLG(), BCL2L1()),
#  Complex(FASLG(), BCL2()),
#  IncreaseAmount(FASLG(), BCL2()),
#  DecreaseAmount(FASLG(), BCL2()),
#  Inhibition(FASLG(), BCL2()),
#  Activation(FASLG(), BCL2()),
#  Inhibition(FASLG(), BAX()),
#  IncreaseAmount(FASLG(), BAX()),
#  Activation(FASLG(), BAX()),
#  Inhibition(FASLG(), BAD()),
#  Activation(FASLG(), BAD()),
#  DecreaseAmount(FASLG(), BAD()),
#  Inhibition(FASLG(), MCL1()),
#  IncreaseAmount(FASLG(), MCL1()),
#  Activation(FASLG(), MAPK14()),
#  IncreaseAmount(FASLG(), FADD()),
#  Activation(FASLG(), FADD()),
#  Complex(FASLG(), FADD()),
#  IncreaseAmount(FASLG(), CYCS()),
#  Inhibition(FASLG(), CYCS()),
#  Complex(FASLG(), CYCS()),
#  Activation(FASLG(), CYCS()),
#  Activation(FASLG(), BBC3()),
#  Complex(FASLG(), CASP9()),
#  IncreaseAmount(FASLG(), CASP9()),
#  Inhibition(FASLG(), CASP9()),
#  Activation(FASLG(), CASP9()),
#  DecreaseAmount(FASLG(), CASP8()),
#  Complex(FASLG(), CASP8()),
#  IncreaseAmount(FASLG(), CASP8()),
#  Activation(FASLG(), CASP8()),
#  Inhibition(FASLG(), CASP8()),
#  IncreaseAmount(FASLG(), CASP3()),
#  DecreaseAmount(FASLG(), CASP3()),
#  Complex(FASLG(), CASP3()),
#  Inhibition(FASLG(), CASP3()),
#  Activation(FASLG(), CASP3()),
#  Activation(FASLG(), TRADD()),
#  Phosphorylation(FASLG(), FAS(), Y),
#  Dephosphorylation(FASLG(), FAS()),
#  DecreaseAmount(FASLG(), FAS()),
#  Activation(FASLG(), FAS(), catalytic),
#  IncreaseAmount(FASLG(), FAS()),
#  Inhibition(FASLG(), FAS()),
#  Activation(FASLG(), FAS()),
#  IncreaseAmount(FASLG(), TNFRSF1A()),
#  Activation(FASLG(), TNFRSF1A()),
#  IncreaseAmount(FASLG(), TNF()),
#  DecreaseAmount(FASLG(), TNF()),
#  Inhibition(FASLG(), TNF()),
#  Activation(FASLG(), TNF()),
#  IncreaseAmount(FASLG(), BID()),
#  Inhibition(FASLG(), BID()),
#  Activation(FASLG(), BID()),
#  Inhibition(FASLG(), apoptotic process()),
#  Activation(FASLG(), apoptotic process()),
#  Dephosphorylation(FASLG(), AKT()),
#  ...]

# %% [markdown]
# We now have fairly clean binary statements that are well suited to start Boolean modeling. However, we notice that for each pair of agents, there are actually several statement types, sometimes conflicting, being reported (e.g.,
# ```
# IncreaseAmount(BBC3(), BCL2L11()),
# DecreaseAmount(BBC3(), BCL2L11())
# ```
# Since Boolean models rely on the polarity of interactions, we can try to resolve these using some heuristic. Let's build up some ad-hoc data structures to explore this issue a bit more. For each pair of agents, we will list the type of interaction and the number/source of evidences supporting it.

# %%
# This will be a lookup of evidence source counts by statement hash
source_counts_by_statement_hash = {rel['data']['stmt_hash']: json.loads(rel['data']['source_counts'])
                                   for rel in subnetwork_relations}

# %%
def get_stmts_by_agent_pair(stmts, source_counts_by_statement_hash):
    from collections import defaultdict
    stmts_by_agent_pair = defaultdict(list)
    for stmt in stmts:
        # At this point we know we have two agents
        agents = stmt.agent_list()
        stmts_by_agent_pair[(agents[0].name, agents[1].name)].append(
            (stmt, source_counts_by_statement_hash[stmt.get_hash()]))
    # We sort in descending order by evidence count the different statements between each pair of genes
    stmts_by_agent_pair = dict(stmts_by_agent_pair)
    for agent_pair, stmt_tuples in stmts_by_agent_pair.items():
        stmts_by_agent_pair[agent_pair] = sorted(stmt_tuples, key=lambda x: sum(x[1].values()), reverse=True)
    return stmts_by_agent_pair
stmts_by_agent_pair = get_stmts_by_agent_pair(stmts, source_counts_by_statement_hash)
stmts_by_agent_pair
# Out:
# {('BBC3',
#   'BCL2L11'): [(Complex(BBC3(), BCL2L11()),
#    {'reach': 19,
#     'sparser': 43}), (Inhibition(BBC3(), BCL2L11()), {'reach': 8}), (Activation(BBC3(), BCL2L11()),
#    {'reach': 7, 'medscan': 1}), (DecreaseAmount(BBC3(), BCL2L11()),
#    {'reach': 2}), (IncreaseAmount(BBC3(), BCL2L11()), {'reach': 1})],
#  ('BBC3',
#   'BCL2L1'): [(Complex(BBC3(), BCL2L1()),
#    {'hprd': 3,
#     'signor': 1,
#     'reach': 61,
#     'biogrid': 5,
#     'sparser': 49,
#     'trips': 2,
#     'medscan': 15}), (Inhibition(BBC3(), BCL2L1()),
#    {'signor': 1,
#     'reach': 8,
#     'sparser': 4,
#     'medscan': 4}), (Activation(BBC3(), BCL2L1()),
#    {'reach': 8, 'medscan': 5})],
#  ('BBC3',
#   'BCL2'): [(Complex(BBC3(), BCL2()),
#    {'hprd': 2,
#     'signor': 2,
#     'reach': 95,
#     'biogrid': 4,
#     'sparser': 42,
#     'trips': 1,
#     'medscan': 4}), (Inhibition(BBC3(), BCL2()),
#    {'signor': 2,
#     'reach': 39,
#     'sparser': 10,
#     'medscan': 3}), (Activation(BBC3(), BCL2()),
#    {'reach': 28, 'sparser': 1}), (DecreaseAmount(BBC3(), BCL2()),
#    {'reach': 3, 'medscan': 1}), (IncreaseAmount(BBC3(), BCL2()),
#    {'reach': 1})],
#  ('BBC3',
#   'BAX'): [(Activation(BBC3(), BAX()),
#    {'signor': 2,
#     'eidos': 1,
#     'reach': 202,
#     'sparser': 50,
#     'trips': 1,
#     'medscan': 17}), (Complex(BBC3(), BAX()),
#    {'hprd': 1,
#     'signor': 1,
#     'reach': 60,
#     'sparser': 55,
#     'medscan': 7}), (Inhibition(BBC3(), BAX()),
#    {'reach': 11, 'sparser': 1, 'medscan': 2}), (IncreaseAmount(BBC3(), BAX()),
#    {'isi': 1, 'reach': 4, 'medscan': 1}), (DecreaseAmount(BBC3(), BAX()),
#    {'reach': 2})],
#  ('BBC3', 'BAD'): [(Complex(BBC3(), BAD()), {'reach': 1, 'sparser': 3}),
#   (Activation(BBC3(), BAD()), {'reach': 2}),
#   (Inhibition(BBC3(), BAD()), {'reach': 1})],
#  ('BBC3',
#   'MCL1'): [(Complex(BBC3(), MCL1()),
#    {'hprd': 1,
#     'signor': 1,
#     'reach': 58,
#     'biogrid': 9,
#     'sparser': 48,
#     'trips': 1,
#     'medscan': 15}), (Inhibition(BBC3(), MCL1()),
#    {'signor': 1,
#     'reach': 10,
#     'sparser': 1,
#     'medscan': 5}), (Activation(BBC3(), MCL1()),
#    {'reach': 9, 'medscan': 3}), (IncreaseAmount(BBC3(), MCL1()),
#    {'reach': 1, 'medscan': 2}), (DecreaseAmount(BBC3(), MCL1()),
#    {'reach': 2}), (Ubiquitination(BBC3(), MCL1()), {'reach': 1})],
#  ('BBC3', 'FADD'): [(Activation(BBC3(), FADD()), {'reach': 2}),
#   (Inhibition(BBC3(), FADD()), {'reach': 1})],
#  ('BBC3', 'CYCS'): [(Activation(BBC3(), CYCS()), {'reach': 19}),
#   (Inhibition(BBC3(), CYCS()), {'reach': 4}),
#   (Complex(BBC3(), CYCS()), {'sparser': 1})],
#  ('BBC3',
#   'CASP9'): [(Activation(BBC3(), CASP9()),
#    {'reach': 9, 'sparser': 1, 'medscan': 3}), (Inhibition(BBC3(), CASP9()),
#    {'reach': 3})],
#  ('BBC3', 'CASP8'): [(Activation(BBC3(), CASP8()), {'reach': 1})],
#  ('BBC3',
#   'CASP3'): [(Activation(BBC3(), CASP3()),
#    {'reach': 21, 'sparser': 3, 'medscan': 3}), (Inhibition(BBC3(), CASP3()),
#    {'reach': 15})],
#  ('BBC3', 'FAS'): [(Inhibition(BBC3(), FAS()), {'reach': 1})],
#  ('BBC3', 'TNF'): [(Inhibition(BBC3(), TNF()), {'reach': 3}),
#   (Activation(BBC3(), TNF()), {'reach': 1})],
#  ('BBC3', 'BID'): [(Activation(BBC3(), BID()), {'reach': 5, 'sparser': 2}),
#   (Inhibition(BBC3(), BID()), {'reach': 1})],
#  ('BBC3',
#   'apoptotic process'): [(Activation(BBC3(), apoptotic process()),
#    {'eidos': 1,
#     'reach': 886,
#     'sparser': 2,
#     'medscan': 48}), (Inhibition(BBC3(), apoptotic process()),
#    {'reach': 136, 'sparser': 3, 'medscan': 23})],
#  ('BBC3', 'AKT'): [(Activation(BBC3(), AKT()), {'reach': 2}),
#   (DecreaseAmount(BBC3(), AKT()), {'reach': 1}),
#   (Inhibition(BBC3(), AKT()), {'reach': 1})],
#  ('CYCS', 'AKT'): [(Activation(CYCS(), AKT()), {'reach': 2, 'sparser': 2}),
#   (Inhibition(CYCS(), AKT()), {'reach': 2}),
#   (Dephosphorylation(CYCS(), AKT()), {'reach': 2}),
#   (DecreaseAmount(CYCS(), AKT()), {'reach': 1}),
#   (IncreaseAmount(CYCS(), AKT()), {'medscan': 1})],
#  ('CYCS', 'BCL2L11'): [(DecreaseAmount(CYCS(), BCL2L11()), {'reach': 2}),
#   (Inhibition(CYCS(), BCL2L11()), {'reach': 2}),
#   (IncreaseAmount(CYCS(), BCL2L11()), {'reach': 1}),
#   (Activation(CYCS(), BCL2L11()), {'reach': 1}),
#   (Complex(CYCS(), BCL2L11()), {'sparser': 1})],
#  ('CYCS',
#   'BCL2L1'): [(Complex(CYCS(), BCL2L1()),
#    {'hprd': 1,
#     'reach': 6,
#     'biogrid': 2,
#     'sparser': 11,
#     'trips': 1,
#     'medscan': 1}), (DecreaseAmount(CYCS(), BCL2L1()),
#    {'reach': 6, 'medscan': 1}), (Inhibition(CYCS(), BCL2L1()),
#    {'reach': 3}), (IncreaseAmount(CYCS(), BCL2L1()), {'reach': 2}), (Activation(CYCS(), BCL2L1()),
#    {'reach': 1})],
#  ('CYCS',
#   'BCL2'): [(Complex(CYCS(), BCL2()),
#    {'hprd': 1,
#     'reach': 2,
#     'sparser': 26,
#     'trips': 1,
#     'medscan': 2}), (Inhibition(CYCS(), BCL2()),
#    {'reach': 28, 'medscan': 2}), (Activation(CYCS(), BCL2()),
#    {'reach': 23, 'sparser': 1}), (DecreaseAmount(CYCS(), BCL2()),
#    {'reach': 24}), (IncreaseAmount(CYCS(), BCL2()), {'reach': 3})],
#  ('CYCS',
#   'BAX'): [(Complex(CYCS(), BAX()),
#    {'reach': 5, 'biogrid': 1, 'sparser': 45}), (Activation(CYCS(), BAX()),
#    {'reach': 39, 'sparser': 3}), (Inhibition(CYCS(), BAX()),
#    {'reach': 14}), (IncreaseAmount(CYCS(), BAX()), {'reach': 13}), (DecreaseAmount(CYCS(), BAX()),
#    {'reach': 9}), (Dephosphorylation(CYCS(), BAX()), {'reach': 1})],
#  ('CYCS', 'BAD'): [(Activation(CYCS(), BAD()), {'reach': 1, 'sparser': 3}),
#   (Inhibition(CYCS(), BAD()), {'reach': 2}),
#   (Complex(CYCS(), BAD()), {'reach': 1, 'sparser': 1}),
#   (Phosphorylation(CYCS(), BAD()), {'reach': 1})],
#  ('CYCS', 'MCL1'): [(Complex(CYCS(), MCL1()), {'reach': 1, 'sparser': 1}),
#   (DecreaseAmount(CYCS(), MCL1()), {'reach': 1}),
#   (Dephosphorylation(CYCS(), MCL1()), {'reach': 1})],
#  ('CYCS', 'FADD'): [(Activation(CYCS(), FADD()), {'sparser': 1}),
#   (IncreaseAmount(CYCS(), FADD()), {'reach': 1})],
#  ('CYCS', 'BBC3'): [(Activation(CYCS(), BBC3()), {'reach': 1})],
#  ('CYCS',
#   'CASP9'): [(Activation(CYCS(), CASP9()),
#    {'signor': 1,
#     'eidos': 7,
#     'reach': 725,
#     'sparser': 307,
#     'trips': 2,
#     'medscan': 29}), (Inhibition(CYCS(), CASP9()),
#    {'reach': 33, 'sparser': 3}), (IncreaseAmount(CYCS(), CASP9()),
#    {'reach': 5}), (DecreaseAmount(CYCS(), CASP9()), {'reach': 1})],
#  ('CYCS',
#   'CASP8'): [(Activation(CYCS(), CASP8()),
#    {'eidos': 1,
#     'reach': 27,
#     'sparser': 13,
#     'medscan': 1}), (Inhibition(CYCS(), CASP8()),
#    {'reach': 1})],
#  ('CYCS',
#   'CASP7'): [(Activation(CYCS(), CASP7()),
#    {'eidos': 1, 'reach': 10, 'sparser': 5})],
#  ('CYCS',
#   'CASP3'): [(Activation(CYCS(), CASP3()),
#    {'eidos': 11,
#     'reach': 561,
#     'sparser': 256,
#     'trips': 3,
#     'medscan': 20}), (Inhibition(CYCS(), CASP3()),
#    {'reach': 40, 'sparser': 2}), (IncreaseAmount(CYCS(), CASP3()),
#    {'reach': 8}), (DecreaseAmount(CYCS(), CASP3()), {'reach': 1})],
#  ('CYCS', 'FASLG'): [(Activation(CYCS(), FASLG()), {'reach': 3}),
#   (IncreaseAmount(CYCS(), FASLG()), {'reach': 2})],
#  ('CYCS', 'FAS'): [(Activation(CYCS(), FAS()), {'reach': 5}),
#   (IncreaseAmount(CYCS(), FAS()), {'reach': 1, 'medscan': 2}),
#   (Inhibition(CYCS(), FAS()), {'reach': 1})],
#  ('CYCS', 'TNF'): [(Activation(CYCS(), TNF()), {'reach': 5})],
#  ('CYCS', 'BID'): [(Activation(CYCS(), BID()), {'reach': 15}),
#   (Inhibition(CYCS(), BID()), {'reach': 4})],
#  ('CYCS',
#   'apoptosome'): [(Activation(CYCS(), apoptosome()),
#    {'eidos': 2,
#     'conib': 1,
#     'trips': 1,
#     'medscan': 11}), (Inhibition(CYCS(), apoptosome()),
#    {'medscan': 1})],
#  ('CYCS',
#   'apoptotic process'): [(Activation(CYCS(), apoptotic process()),
#    {'eidos': 17,
#     'reach': 1293,
#     'sparser': 10,
#     'medscan': 12}), (Inhibition(CYCS(), apoptotic process()),
#    {'eidos': 1, 'reach': 125, 'sparser': 6, 'medscan': 1})],
#  ('apoptotic process',
#   'BCL2L11'): [(Activation(apoptotic process(), BCL2L11()),
#    {'reach': 6}), (IncreaseAmount(apoptotic process(), BCL2L11()), {'medscan': 2}), (Inhibition(apoptotic process(), BCL2L11()),
#    {'reach': 1})],
#  ('apoptotic process',
#   'BCL2L1'): [(Inhibition(apoptotic process(), BCL2L1()),
#    {'reach': 7}), (Activation(apoptotic process(), BCL2L1()), {'reach': 5}), (IncreaseAmount(apoptotic process(), BCL2L1()),
#    {'medscan': 2})],
#  ('apoptotic process',
#   'BCL2'): [(Inhibition(apoptotic process(), BCL2()),
#    {'eidos': 1, 'reach': 56}), (Activation(apoptotic process(), BCL2()),
#    {'reach': 33}), (IncreaseAmount(apoptotic process(), BCL2()),
#    {'medscan': 12})],
#  ('apoptotic process',
#   'BAX'): [(Activation(apoptotic process(), BAX()),
#    {'reach': 38}), (Inhibition(apoptotic process(), BAX()), {'reach': 27}), (IncreaseAmount(apoptotic process(), BAX()),
#    {'medscan': 2})],
#  ('apoptotic process',
#   'BAD'): [(Activation(apoptotic process(), BAD()), {'reach': 2})],
#  ('apoptotic process',
#   'MCL1'): [(Activation(apoptotic process(), MCL1()), {'reach': 13}),
#   (Inhibition(apoptotic process(), MCL1()), {'reach': 11}),
#   (IncreaseAmount(apoptotic process(), MCL1()), {'medscan': 1})],
#  ('apoptotic process',
#   'FADD'): [(Activation(apoptotic process(), FADD()),
#    {'reach': 5}), (Inhibition(apoptotic process(), FADD()), {'reach': 1})],
#  ('apoptotic process',
#   'CYCS'): [(Activation(apoptotic process(), CYCS()),
#    {'eidos': 1, 'reach': 23}), (Inhibition(apoptotic process(), CYCS()),
#    {'reach': 11})],
#  ('apoptotic process',
#   'BBC3'): [(Activation(apoptotic process(), BBC3()),
#    {'reach': 4}), (IncreaseAmount(apoptotic process(), BBC3()), {'medscan': 1}), (Inhibition(apoptotic process(), BBC3()),
#    {'reach': 1})],
#  ('apoptotic process',
#   'CASP9'): [(Activation(apoptotic process(), CASP9()),
#    {'reach': 18}), (Inhibition(apoptotic process(), CASP9()), {'reach': 7})],
#  ('apoptotic process',
#   'CASP8'): [(Activation(apoptotic process(), CASP8()),
#    {'eidos': 4, 'reach': 45}), (Inhibition(apoptotic process(), CASP8()),
#    {'reach': 12, 'trips': 1})],
#  ('apoptotic process',
#   'CASP7'): [(Activation(apoptotic process(), CASP7()),
#    {'reach': 4}), (Inhibition(apoptotic process(), CASP7()), {'reach': 2})],
#  ('apoptotic process',
#   'CASP3'): [(Activation(apoptotic process(), CASP3()),
#    {'eidos': 9, 'reach': 97}), (Inhibition(apoptotic process(), CASP3()),
#    {'reach': 27, 'trips': 2}), (IncreaseAmount(apoptotic process(), CASP3()),
#    {'medscan': 1})],
#  ('apoptotic process',
#   'TRADD'): [(Inhibition(apoptotic process(), TRADD()), {'reach': 1})],
#  ('apoptotic process',
#   'FASLG'): [(IncreaseAmount(apoptotic process(), FASLG()),
#    {'reach': 1, 'medscan': 9}),
#   (Inhibition(apoptotic process(), FASLG()), {'reach': 4}),
#   (Activation(apoptotic process(), FASLG()), {'reach': 4})],
#  ('apoptotic process',
#   'FAS'): [(Activation(apoptotic process(), FAS()),
#    {'reach': 29}), (IncreaseAmount(apoptotic process(), FAS()), {'medscan': 9}), (Inhibition(apoptotic process(), FAS()),
#    {'reach': 8})],
#  ('apoptotic process',
#   'TNFRSF1A'): [(Inhibition(apoptotic process(), TNFRSF1A()),
#    {'reach': 3}), (Activation(apoptotic process(), TNFRSF1A()), {'reach': 1})],
#  ('apoptotic process',
#   'TNF'): [(Inhibition(apoptotic process(), TNF()),
#    {'reach': 16}), (Activation(apoptotic process(), TNF()),
#    {'eidos': 1, 'reach': 10}), (IncreaseAmount(apoptotic process(), TNF()),
#    {'medscan': 3})],
#  ('apoptotic process',
#   'BID'): [(Activation(apoptotic process(), BID()),
#    {'reach': 14}), (Inhibition(apoptotic process(), BID()), {'reach': 1})],
#  ('apoptotic process',
#   'AKT'): [(Inhibition(apoptotic process(), AKT()),
#    {'reach': 26}), (Activation(apoptotic process(), AKT()), {'reach': 23})],
#  ('FADD', 'BCL2L1'): [(Complex(FADD(), BCL2L1()), {'sparser': 1})],
#  ('FADD', 'BCL2'): [(Inhibition(FADD(), BCL2()), {'reach': 2, 'medscan': 1}),
#   (Activation(FADD(), BCL2()), {'reach': 1}),
#   (Complex(FADD(), BCL2()), {'sparser': 1})],
#  ('FADD', 'BAX'): [(IncreaseAmount(FADD(), BAX()), {'reach': 1}),
#   (Activation(FADD(), BAX()), {'reach': 1})],
#  ('FADD', 'CYCS'): [(Inhibition(FADD(), CYCS()), {'reach': 4}),
#   (Activation(FADD(), CYCS()), {'reach': 1})],
#  ('FADD', 'BBC3'): [(Activation(FADD(), BBC3()), {'reach': 1})],
#  ('FADD', 'CASP9'): [(Inhibition(FADD(), CASP9()), {'reach': 5}),
#   (Activation(FADD(), CASP9()), {'reach': 2}),
#   (IncreaseAmount(FADD(), CASP9()), {'bel_lc': 1})],
#  ('FADD',
#   'CASP8'): [(Activation(FADD(), CASP8()),
#    {'signor': 1,
#     'eidos': 4,
#     'reach': 169,
#     'sparser': 78,
#     'trips': 1,
#     'medscan': 19}), (Inhibition(FADD(), CASP8()),
#    {'reach': 21,
#     'sparser': 1,
#     'medscan': 3}), (DecreaseAmount(FADD(), CASP8()),
#    {'reach': 1, 'medscan': 2}), (IncreaseAmount(FADD(), CASP8()),
#    {'isi': 1, 'reach': 1}), (Ubiquitination(FADD(), CASP8()),
#    {'reach': 1}), (Activation(FADD(), CASP8(), catalytic), {'bel_lc': 1})],
#  ('FADD',
#   'CASP3'): [(Activation(FADD(), CASP3()),
#    {'reach': 15, 'sparser': 6, 'medscan': 1}), (Inhibition(FADD(), CASP3()),
#    {'reach': 4, 'medscan': 2}), (IncreaseAmount(FADD(), CASP3()),
#    {'reach': 1, 'bel_lc': 1}), (Acetylation(FADD(), CASP3()), {'reach': 1})],
#  ('FADD',
#   'TRADD'): [(Activation(FADD(), TRADD()), {'reach': 1, 'medscan': 1})],
#  ('FADD', 'FASLG'): [(Inhibition(FADD(), FASLG()), {'reach': 2}),
#   (Activation(FADD(), FASLG()), {'reach': 2}),
#   (DecreaseAmount(FADD(), FASLG()), {'reach': 1})],
#  ('FADD', 'FAS'): [(Activation(FADD(), FAS()), {'reach': 29, 'medscan': 4}),
#   (Inhibition(FADD(), FAS()), {'reach': 3, 'medscan': 6}),
#   (IncreaseAmount(FADD(), FAS()), {'reach': 3})],
#  ('FADD',
#   'TNFRSF1A'): [(Activation(FADD(), TNFRSF1A()),
#    {'reach': 1,
#     'medscan': 1}), (Inhibition(FADD(), TNFRSF1A()), {'sparser': 1})],
#  ('FADD', 'TNF'): [(Activation(FADD(), TNF()), {'reach': 14}),
#   (Inhibition(FADD(), TNF()), {'reach': 6}),
#   (IncreaseAmount(FADD(), TNF()), {'reach': 2})],
#  ('FADD',
#   'BID'): [(Activation(FADD(), BID()),
#    {'reach': 7, 'sparser': 1, 'medscan': 1}), (Inhibition(FADD(), BID()),
#    {'reach': 3, 'medscan': 1})],
#  ('FADD',
#   'apoptotic process'): [(Activation(FADD(), apoptotic process()),
#    {'eidos': 7,
#     'reach': 337,
#     'sparser': 4,
#     'medscan': 14}), (Inhibition(FADD(), apoptotic process()),
#    {'reach': 68, 'sparser': 7, 'medscan': 12})],
#  ('apoptosome', 'BAX'): [(Activation(apoptosome(), BAX()), {'medscan': 1})],
#  ('apoptosome', 'FADD'): [(Inhibition(apoptosome(), FADD()), {'medscan': 1})],
#  ('apoptosome', 'CYCS'): [(Complex(apoptosome(), CYCS()), {'medscan': 5}),
#   (Activation(apoptosome(), CYCS()), {'eidos': 1})],
#  ('apoptosome',
#   'CASP9'): [(Activation(apoptosome(), CASP9()),
#    {'eidos': 11, 'trips': 1, 'medscan': 23}), (Complex(apoptosome(), CASP9()),
#    {'medscan': 17})],
#  ('apoptosome',
#   'CASP7'): [(Activation(apoptosome(), CASP7()), {'medscan': 2})],
#  ('apoptosome',
#   'CASP3'): [(Activation(apoptosome(), CASP3()),
#    {'eidos': 3, 'trips': 1, 'medscan': 7}), (Complex(apoptosome(), CASP3()),
#    {'medscan': 1})],
#  ('apoptosome', 'FAS'): [(Inhibition(apoptosome(), FAS()), {'medscan': 1})],
#  ('apoptosome',
#   'apoptotic process'): [(Activation(apoptosome(), apoptotic process()),
#    {'eidos': 3, 'medscan': 3})],
#  ('MAPK14', 'BCL2L11'): [(Phosphorylation(MAPK14(), BCL2L11()), {'reach': 1}),
#   (Activation(MAPK14(), BCL2L11()), {'medscan': 1})],
#  ('MAPK14',
#   'BCL2L1'): [(Phosphorylation(MAPK14(), BCL2L1(), S, 62),
#    {'reach': 3, 'psp': 1, 'medscan': 1}), (Activation(MAPK14(), BCL2L1()),
#    {'reach': 1}), (Phosphorylation(MAPK14(), BCL2L1()),
#    {'sparser': 1}), (Inhibition(MAPK14(), BCL2L1()), {'medscan': 1}), (Complex(MAPK14(), BCL2L1()),
#    {'biogrid': 1})],
#  ('MAPK14',
#   'BCL2'): [(Inhibition(MAPK14(), BCL2()),
#    {'signor': 2, 'medscan': 2}), (Complex(MAPK14(), BCL2()), {'hprd': 1,
#     'reach': 1,
#     'sparser': 2}), (Phosphorylation(MAPK14(), BCL2()),
#    {'rlimsp': 1, 'sparser': 3}), (Phosphorylation(MAPK14(), BCL2(), S, 87),
#    {'signor': 1,
#     'sparser': 1,
#     'psp': 1}), (Phosphorylation(MAPK14(), BCL2(), T, 56),
#    {'signor': 1, 'sparser': 1, 'psp': 1}), (Activation(MAPK14(), BCL2()),
#    {'medscan': 1})],
#  ('MAPK14',
#   'BAX'): [(Activation(MAPK14(), BAX()),
#    {'sparser': 1,
#     'medscan': 4}), (IncreaseAmount(MAPK14(), BAX()), {'medscan': 2}), (Phosphorylation(MAPK14(), BAX()),
#    {'medscan': 1}), (Inhibition(MAPK14(), BAX()), {'medscan': 1})],
#  ('MAPK14', 'MCL1'): [(Activation(MAPK14(), MCL1()), {'medscan': 1})],
#  ('MAPK14', 'BBC3'): [(IncreaseAmount(MAPK14(), BBC3()), {'medscan': 1}),
#   (Inhibition(MAPK14(), BBC3()), {'medscan': 1})],
#  ('MAPK14', 'CASP9'): [(Phosphorylation(MAPK14(), CASP9()), {'medscan': 1}),
#   (Inhibition(MAPK14(), CASP9()), {'medscan': 1})],
#  ('MAPK14', 'CASP8'): [(Phosphorylation(MAPK14(), CASP8()), {'medscan': 4}),
#   (Phosphorylation(MAPK14(), CASP8(), S, 347),
#    {'signor': 1, 'pe': 1, 'psp': 1}),
#   (Inhibition(MAPK14(), CASP8()), {'signor': 1, 'medscan': 1}),
#   (DecreaseAmount(MAPK14(), CASP8()), {'medscan': 2}),
#   (Activation(MAPK14(), CASP8()), {'medscan': 2})],
#  ('MAPK14',
#   'CASP3'): [(Activation(MAPK14(), CASP3()),
#    {'reach': 1, 'medscan': 7}), (Inhibition(MAPK14(), CASP3()), {'signor': 1,
#     'medscan': 3}), (Phosphorylation(MAPK14(), CASP3()),
#    {'medscan': 3}), (Phosphorylation(MAPK14(), CASP3(), S, 150), {'signor': 1,
#     'pe': 1,
#     'psp': 1}), (DecreaseAmount(MAPK14(), CASP3()),
#    {'medscan': 2}), (IncreaseAmount(MAPK14(), CASP3()), {'medscan': 1})],
#  ('MAPK14', 'FASLG'): [(Activation(MAPK14(), FASLG()), {'medscan': 1}),
#   (IncreaseAmount(MAPK14(), FASLG()), {'medscan': 1})],
#  ('MAPK14', 'TNF'): [(Activation(MAPK14(), TNF()), {'reach': 1, 'medscan': 3}),
#   (DecreaseAmount(MAPK14(), TNF()), {'medscan': 4}),
#   (Inhibition(MAPK14(), TNF()), {'reach': 1, 'medscan': 2}),
#   (IncreaseAmount(MAPK14(), TNF()), {'medscan': 2})],
#  ('MAPK14',
#   'apoptotic process'): [(Activation(MAPK14(), apoptotic process()),
#    {'reach': 9, 'medscan': 18}), (Inhibition(MAPK14(), apoptotic process()),
#    {'reach': 1, 'sparser': 1, 'medscan': 8})],
#  ('MAPK14',
#   'AKT'): [(Activation(MAPK14(), AKT()),
#    {'signor': 1, 'reach': 1, 'medscan': 8}), (Inhibition(MAPK14(), AKT()),
#    {'signor': 1, 'medscan': 4}), (Phosphorylation(MAPK14(), AKT()),
#    {'medscan': 2})],
#  ('MCL1',
#   'BCL2L11'): [(Complex(MCL1(), BCL2L11()),
#    {'hprd': 2,
#     'reach': 227,
#     'biogrid': 20,
#     'sparser': 189,
#     'trips': 2,
#     'medscan': 26}), (Inhibition(MCL1(), BCL2L11()),
#    {'eidos': 3,
#     'reach': 50,
#     'sparser': 2,
#     'medscan': 6}), (Activation(MCL1(), BCL2L11()),
#    {'reach': 21, 'medscan': 2}), (DecreaseAmount(MCL1(), BCL2L11()),
#    {'reach': 5, 'medscan': 1}), (IncreaseAmount(MCL1(), BCL2L11()),
#    {'reach': 3, 'medscan': 2}), (Phosphorylation(MCL1(), BCL2L11(), S, 87),
#    {'reach': 1}), (Dephosphorylation(MCL1(), BCL2L11(), S, 69), {'reach': 1})],
#  ('MCL1',
#   'BCL2L1'): [(Complex(MCL1(), BCL2L1()),
#    {'hprd': 1,
#     'reach': 36,
#     'biogrid': 1,
#     'sparser': 152}), (Inhibition(MCL1(), BCL2L1()),
#    {'reach': 13, 'sparser': 5}), (Activation(MCL1(), BCL2L1()),
#    {'reach': 11, 'medscan': 2}), (DecreaseAmount(MCL1(), BCL2L1()),
#    {'reach': 2}), (Phosphorylation(MCL1(), BCL2L1()), {'reach': 1})],
#  ('MCL1',
#   'BCL2'): [(Complex(MCL1(), BCL2()),
#    {'reach': 34, 'sparser': 86, 'medscan': 2}), (Inhibition(MCL1(), BCL2()),
#    {'reach': 35, 'sparser': 1}), (Activation(MCL1(), BCL2()),
#    {'reach': 20, 'medscan': 1}), (DecreaseAmount(MCL1(), BCL2()),
#    {'reach': 5, 'medscan': 1}), (Phosphorylation(MCL1(), BCL2()),
#    {'rlimsp': 1, 'reach': 2}), (IncreaseAmount(MCL1(), BCL2()),
#    {'reach': 1, 'medscan': 1}), (Dephosphorylation(MCL1(), BCL2()),
#    {'reach': 1}), (Phosphorylation(MCL1(), BCL2(), T, 56), {'reach': 1})],
#  ('MCL1',
#   'BAX'): [(Inhibition(MCL1(), BAX()),
#    {'signor': 1,
#     'eidos': 1,
#     'reach': 88,
#     'sparser': 12,
#     'trips': 1,
#     'medscan': 8}), (Complex(MCL1(), BAX()),
#    {'hprd': 2,
#     'signor': 1,
#     'reach': 54,
#     'biogrid': 7,
#     'sparser': 20,
#     'trips': 2,
#     'medscan': 13}), (Activation(MCL1(), BAX()),
#    {'reach': 32, 'sparser': 1, 'medscan': 7}), (DecreaseAmount(MCL1(), BAX()),
#    {'reach': 2}), (IncreaseAmount(MCL1(), BAX()), {'reach': 1})],
#  ('MCL1',
#   'BAD'): [(Complex(MCL1(), BAD()),
#    {'hprd': 3,
#     'reach': 6,
#     'biogrid': 3,
#     'sparser': 13}), (Activation(MCL1(), BAD()),
#    {'reach': 1}), (Phosphorylation(MCL1(), BAD()),
#    {'sparser': 1}), (DecreaseAmount(MCL1(), BAD()), {'reach': 1}), (Inhibition(MCL1(), BAD()),
#    {'reach': 1})],
#  ('MCL1', 'CYCS'): [(Inhibition(MCL1(), CYCS()), {'reach': 23}),
#   (Activation(MCL1(), CYCS()), {'reach': 7})],
#  ('MCL1', 'BBC3'): [(Inhibition(MCL1(), BBC3()), {'reach': 5, 'sparser': 1}),
#   (Activation(MCL1(), BBC3()), {'reach': 2, 'medscan': 2}),
#   (IncreaseAmount(MCL1(), BBC3()), {'medscan': 1})],
#  ('MCL1', 'CASP9'): [(Inhibition(MCL1(), CASP9()), {'reach': 8, 'medscan': 2}),
#   (Activation(MCL1(), CASP9()), {'reach': 6})],
#  ('MCL1', 'CASP8'): [(Inhibition(MCL1(), CASP8()), {'reach': 3, 'medscan': 1}),
#   (Activation(MCL1(), CASP8()), {'reach': 2})],
#  ('MCL1', 'CASP7'): [(Inhibition(MCL1(), CASP7()), {'medscan': 1})],
#  ('MCL1',
#   'CASP3'): [(Inhibition(MCL1(), CASP3()),
#    {'reach': 24, 'medscan': 3}), (Activation(MCL1(), CASP3()), {'reach': 15,
#     'medscan': 1}), (IncreaseAmount(MCL1(), CASP3()), {'medscan': 1})],
#  ('MCL1', 'FASLG'): [(Inhibition(MCL1(), FASLG()), {'reach': 4})],
#  ('MCL1', 'FAS'): [(Inhibition(MCL1(), FAS()), {'reach': 4}),
#   (IncreaseAmount(MCL1(), FAS()), {'reach': 1})],
#  ('MCL1', 'TNF'): [(Activation(MCL1(), TNF()), {'reach': 3}),
#   (Inhibition(MCL1(), TNF()), {'reach': 1})],
#  ('MCL1', 'BID'): [(Activation(MCL1(), BID()), {'reach': 6}),
#   (Inhibition(MCL1(), BID()), {'reach': 5, 'sparser': 1}),
#   (DecreaseAmount(MCL1(), BID()), {'medscan': 1})],
#  ('MCL1',
#   'apoptotic process'): [(Inhibition(MCL1(), apoptotic process()),
#    {'eidos': 27,
#     'reach': 637,
#     'sparser': 45,
#     'trips': 3,
#     'medscan': 74}), (Activation(MCL1(), apoptotic process()),
#    {'eidos': 3, 'reach': 444, 'medscan': 45})],
#  ('MCL1',
#   'AKT'): [(Activation(MCL1(), AKT()),
#    {'eidos': 2, 'reach': 15, 'sparser': 1}), (Inhibition(MCL1(), AKT()),
#    {'reach': 2}), (Phosphorylation(MCL1(), AKT()), {'sparser': 1})],
#  ('BAD', 'BCL2L11'): [(Complex(BAD(), BCL2L11()), {'reach': 1, 'sparser': 10}),
#   (Activation(BAD(), BCL2L11()), {'reach': 2}),
#   (Inhibition(BAD(), BCL2L11()), {'reach': 2}),
#   (DecreaseAmount(BAD(), BCL2L11()), {'reach': 1})],
#  ('BAD',
#   'BCL2L1'): [(Complex(BAD(), BCL2L1()),
#    {'hprd': 8,
#     'signor': 3,
#     'reach': 199,
#     'biogrid': 30,
#     'sparser': 181,
#     'trips': 12}), (Inhibition(BAD(), BCL2L1()),
#    {'signor': 2, 'reach': 39, 'sparser': 27}), (Activation(BAD(), BCL2L1()),
#    {'reach': 20}), (IncreaseAmount(BAD(), BCL2L1()),
#    {'isi': 2, 'reach': 2}), (Phosphorylation(BAD(), BCL2L1()), {'isi': 1,
#     'sparser': 1})],
#  ('BAD',
#   'BCL2'): [(Complex(BAD(), BCL2()),
#    {'hprd': 5,
#     'reach': 129,
#     'biogrid': 11,
#     'sparser': 118,
#     'bel_lc': 1,
#     'trips': 6}), (Inhibition(BAD(), BCL2()),
#    {'signor': 1, 'reach': 64, 'sparser': 24}), (Activation(BAD(), BCL2()),
#    {'reach': 35, 'sparser': 1}), (DecreaseAmount(BAD(), BCL2()),
#    {'reach': 7}), (IncreaseAmount(BAD(), BCL2()),
#    {'isi': 2, 'reach': 2}), (Phosphorylation(BAD(), BCL2()), {'rlimsp': 2,
#     'reach': 1})],
#  ('BAD', 'BAX'): [(Activation(BAD(), BAX()), {'reach': 40, 'sparser': 10}),
#   (Complex(BAD(), BAX()),
#    {'isi': 1, 'reach': 12, 'biogrid': 1, 'sparser': 28, 'medscan': 1}),
#   (Inhibition(BAD(), BAX()), {'reach': 7}),
#   (IncreaseAmount(BAD(), BAX()), {'isi': 2, 'reach': 2}),
#   (Phosphorylation(BAD(), BAX()), {'rlimsp': 1, 'sparser': 3}),
#   (DecreaseAmount(BAD(), BAX()), {'reach': 1}),
#   (Dephosphorylation(BAD(), BAX()), {'sparser': 1})],
#  ('BAD',
#   'MCL1'): [(Phosphorylation(BAD(), MCL1()),
#    {'rlimsp': 3, 'sparser': 2}), (Inhibition(BAD(), MCL1()), {'reach': 3,
#     'sparser': 1}), (Activation(BAD(), MCL1()), {'reach': 3})],
#  ('BAD', 'CYCS'): [(Activation(BAD(), CYCS()), {'reach': 26}),
#   (Inhibition(BAD(), CYCS()), {'reach': 17}),
#   (Phosphorylation(BAD(), CYCS()), {'sparser': 1})],
#  ('BAD', 'CASP9'): [(Activation(BAD(), CASP9()), {'reach': 12}),
#   (Inhibition(BAD(), CASP9()), {'reach': 3}),
#   (IncreaseAmount(BAD(), CASP9()), {'isi': 1, 'reach': 1}),
#   (Dephosphorylation(BAD(), CASP9()), {'sparser': 1})],
#  ('BAD', 'CASP8'): [(Activation(BAD(), CASP8()), {'reach': 2}),
#   (Inhibition(BAD(), CASP8()), {'reach': 1})],
#  ('BAD', 'CASP3'): [(Activation(BAD(), CASP3()), {'reach': 18, 'sparser': 3}),
#   (Inhibition(BAD(), CASP3()), {'reach': 21}),
#   (Phosphorylation(BAD(), CASP3()), {'sparser': 2})],
#  ('BAD', 'FASLG'): [(Activation(BAD(), FASLG()), {'reach': 1}),
#   (IncreaseAmount(BAD(), FASLG()), {'reach': 1})],
#  ('BAD', 'FAS'): [(Activation(BAD(), FAS()), {'reach': 3}),
#   (Inhibition(BAD(), FAS()), {'reach': 1}),
#   (IncreaseAmount(BAD(), FAS()), {'reach': 1})],
#  ('BAD', 'TNF'): [(Activation(BAD(), TNF()), {'reach': 6}),
#   (Inhibition(BAD(), TNF()), {'reach': 2})],
#  ('BAD', 'BID'): [(Activation(BAD(), BID()), {'reach': 2}),
#   (IncreaseAmount(BAD(), BID()), {'isi': 1}),
#   (Inhibition(BAD(), BID()), {'reach': 1})],
#  ('BAD',
#   'apoptotic process'): [(Activation(BAD(), apoptotic process()),
#    {'eidos': 11,
#     'reach': 384,
#     'medscan': 2}), (Inhibition(BAD(), apoptotic process()),
#    {'reach': 125, 'sparser': 9})],
#  ('BAD', 'AKT'): [(Activation(BAD(), AKT()), {'reach': 38}),
#   (Phosphorylation(BAD(), AKT()), {'reach': 15, 'sparser': 4}),
#   (Inhibition(BAD(), AKT()), {'reach': 7, 'sparser': 1, 'medscan': 1}),
#   (Phosphorylation(BAD(), AKT(), S, 136), {'sparser': 1}),
#   (Phosphorylation(BAD(), AKT(), T, 308), {'reach': 1}),
#   (Phosphorylation(BAD(), AKT(), S, 473), {'reach': 1}),
#   (DecreaseAmount(BAD(), AKT()), {'reach': 1})],
#  ('BAX',
#   'BCL2L11'): [(Complex(BAX(), BCL2L11()),
#    {'signor': 4,
#     'reach': 98,
#     'biogrid': 1,
#     'sparser': 86,
#     'trips': 1,
#     'medscan': 19}), (Activation(BAX(), BCL2L11()),
#    {'reach': 13, 'sparser': 8}), (Inhibition(BAX(), BCL2L11()),
#    {'reach': 2}), (IncreaseAmount(BAX(), BCL2L11()), {'reach': 1})],
#  ('BAX',
#   'BCL2L1'): [(Complex(BAX(), BCL2L1()),
#    {'hprd': 5,
#     'signor': 1,
#     'reach': 253,
#     'biogrid': 17,
#     'sparser': 235,
#     'trips': 8,
#     'medscan': 45}), (Inhibition(BAX(), BCL2L1()),
#    {'reach': 34, 'sparser': 2, 'medscan': 11}), (Activation(BAX(), BCL2L1()),
#    {'reach': 15, 'medscan': 4}), (IncreaseAmount(BAX(), BCL2L1()),
#    {'isi': 3, 'reach': 4}), (DecreaseAmount(BAX(), BCL2L1()), {'reach': 4})],
#  ('BAX',
#   'BCL2'): [(Complex(BAX(), BCL2()),
#    {'isi': 2,
#     'hprd': 6,
#     'signor': 2,
#     'reach': 755,
#     'biogrid': 14,
#     'sparser': 811,
#     'bel_lc': 1,
#     'trips': 4,
#     'medscan': 36}), (Inhibition(BAX(), BCL2()),
#    {'signor': 1,
#     'eidos': 3,
#     'reach': 367,
#     'sparser': 11,
#     'medscan': 62}), (Activation(BAX(), BCL2()),
#    {'reach': 198, 'sparser': 5, 'medscan': 1}), (IncreaseAmount(BAX(), BCL2()),
#    {'isi': 112, 'reach': 59, 'medscan': 2}), (DecreaseAmount(BAX(), BCL2()),
#    {'isi': 1, 'reach': 72, 'medscan': 2}), (Phosphorylation(BAX(), BCL2()),
#    {'isi': 1, 'reach': 1, 'medscan': 1}), (Methylation(BAX(), BCL2()),
#    {'sparser': 1})],
#  ('BAX', 'BAD'): [(Activation(BAX(), BAD()), {'reach': 8}),
#   (IncreaseAmount(BAX(), BAD()), {'isi': 5, 'reach': 1}),
#   (Inhibition(BAX(), BAD()), {'reach': 5, 'sparser': 1}),
#   (Phosphorylation(BAX(), BAD()), {'isi': 1})],
#  ('BAX',
#   'MCL1'): [(Inhibition(BAX(), MCL1()),
#    {'eidos': 1,
#     'reach': 8,
#     'sparser': 1,
#     'medscan': 1}), (Activation(BAX(), MCL1()),
#    {'isi': 1, 'reach': 5, 'medscan': 4}), (IncreaseAmount(BAX(), MCL1()),
#    {'isi': 1, 'reach': 4}), (DecreaseAmount(BAX(), MCL1()), {'reach': 1})],
#  ('BAX', 'MAPK14'): [(Activation(BAX(), MAPK14()), {'medscan': 1})],
#  ('BAX', 'FADD'): [(DecreaseAmount(BAX(), FADD()), {'reach': 1})],
#  ('BAX',
#   'CYCS'): [(Activation(BAX(), CYCS()),
#    {'signor': 2,
#     'reach': 822,
#     'sparser': 1,
#     'medscan': 2}), (Inhibition(BAX(), CYCS()),
#    {'reach': 113, 'sparser': 1}), (IncreaseAmount(BAX(), CYCS()),
#    {'reach': 21}), (DecreaseAmount(BAX(), CYCS()), {'reach': 7})],
#  ('BAX',
#   'BBC3'): [(Activation(BAX(), BBC3()),
#    {'reach': 7, 'sparser': 1, 'medscan': 1}), (Inhibition(BAX(), BBC3()),
#    {'reach': 3}), (IncreaseAmount(BAX(), BBC3()),
#    {'isi': 1, 'reach': 1}), (DecreaseAmount(BAX(), BBC3()), {'reach': 1})],
#  ('BAX',
#   'CASP9'): [(Activation(BAX(), CASP9()),
#    {'reach': 104, 'sparser': 10, 'medscan': 9}), (Inhibition(BAX(), CASP9()),
#    {'reach': 33, 'medscan': 3}), (IncreaseAmount(BAX(), CASP9()),
#    {'isi': 10, 'reach': 1}), (DecreaseAmount(BAX(), CASP9()),
#    {'isi': 1, 'reach': 2}), (Ubiquitination(BAX(), CASP9()), {'reach': 1})],
#  ('BAX',
#   'CASP8'): [(Activation(BAX(), CASP8()),
#    {'reach': 11, 'sparser': 1, 'medscan': 1}), (Inhibition(BAX(), CASP8()),
#    {'reach': 4}), (DecreaseAmount(BAX(), CASP8()),
#    {'reach': 3}), (IncreaseAmount(BAX(), CASP8()), {'isi': 1})],
#  ('BAX', 'CASP7'): [(Activation(BAX(), CASP7()), {'reach': 4, 'sparser': 1}),
#   (Inhibition(BAX(), CASP7()), {'reach': 1}),
#   (DecreaseAmount(BAX(), CASP7()), {'reach': 1})],
#  ('BAX',
#   'CASP3'): [(Activation(BAX(), CASP3()),
#    {'reach': 232,
#     'sparser': 37,
#     'trips': 1,
#     'medscan': 12}), (Inhibition(BAX(), CASP3()),
#    {'isi': 1,
#     'reach': 84,
#     'sparser': 1,
#     'medscan': 3}), (IncreaseAmount(BAX(), CASP3()),
#    {'isi': 49, 'reach': 13, 'medscan': 1}), (DecreaseAmount(BAX(), CASP3()),
#    {'isi': 2, 'reach': 9})],
#  ('BAX', 'TRADD'): [(DecreaseAmount(BAX(), TRADD()), {'reach': 1})],
#  ('BAX', 'FASLG'): [(Activation(BAX(), FASLG()), {'reach': 2}),
#   (DecreaseAmount(BAX(), FASLG()), {'reach': 1})],
#  ('BAX',
#   'FAS'): [(Activation(BAX(), FAS()),
#    {'reach': 6, 'sparser': 1, 'medscan': 1}), (Inhibition(BAX(), FAS()),
#    {'reach': 2, 'medscan': 1}), (DecreaseAmount(BAX(), FAS()),
#    {'reach': 1}), (IncreaseAmount(BAX(), FAS()), {'reach': 1})],
#  ('BAX', 'TNFRSF1A'): [(Activation(BAX(), TNFRSF1A()), {'reach': 1})],
#  ('BAX', 'TNF'): [(Activation(BAX(), TNF()), {'reach': 8}),
#   (IncreaseAmount(BAX(), TNF()), {'isi': 6}),
#   (DecreaseAmount(BAX(), TNF()), {'reach': 3}),
#   (Inhibition(BAX(), TNF()), {'reach': 3})],
#  ('BAX',
#   'BID'): [(Activation(BAX(), BID()),
#    {'reach': 13, 'sparser': 1, 'medscan': 3}), (Inhibition(BAX(), BID()),
#    {'reach': 3, 'medscan': 1}), (IncreaseAmount(BAX(), BID()), {'isi': 2})],
#  ('BAX', 'apoptosome'): [(Activation(BAX(), apoptosome()), {'medscan': 3}),
#   (Inhibition(BAX(), apoptosome()), {'eidos': 1})],
#  ('BAX',
#   'apoptotic process'): [(Activation(BAX(), apoptotic process()),
#    {'eidos': 25,
#     'reach': 3592,
#     'sparser': 13,
#     'medscan': 144}), (Inhibition(BAX(), apoptotic process()),
#    {'eidos': 2,
#     'reach': 558,
#     'sparser': 21,
#     'trips': 1,
#     'medscan': 20}), (IncreaseAmount(BAX(), apoptotic process()),
#    {'isi': 1})],
#  ('BAX',
#   'AKT'): [(Inhibition(BAX(), AKT()),
#    {'reach': 14, 'sparser': 1, 'medscan': 2}), (Activation(BAX(), AKT()),
#    {'reach': 7}), (Phosphorylation(BAX(), AKT()),
#    {'reach': 5}), (IncreaseAmount(BAX(), AKT()), {'isi': 4}), (Phosphorylation(BAX(), AKT(), D, 1),
#    {'reach': 1}), (Dephosphorylation(BAX(), AKT()), {'reach': 1})],
#  ('BCL2',
#   'BCL2L11'): [(Complex(BCL2(), BCL2L11()),
#    {'hprd': 4,
#     'signor': 3,
#     'reach': 247,
#     'biogrid': 14,
#     'sparser': 222,
#     'trips': 2,
#     'medscan': 19}), (Inhibition(BCL2(), BCL2L11()),
#    {'reach': 57, 'sparser': 6, 'medscan': 3}), (Activation(BCL2(), BCL2L11()),
#    {'reach': 28, 'medscan': 2}), (IncreaseAmount(BCL2(), BCL2L11()),
#    {'isi': 1, 'reach': 12, 'medscan': 1}), (DecreaseAmount(BCL2(), BCL2L11()),
#    {'reach': 8})],
#  ('BCL2',
#   'BCL2L1'): [(Complex(BCL2(), BCL2L1()),
#    {'hprd': 1,
#     'reach': 271,
#     'biogrid': 5,
#     'sparser': 745,
#     'medscan': 3}), (Inhibition(BCL2(), BCL2L1()),
#    {'reach': 58, 'sparser': 4, 'medscan': 3}), (Activation(BCL2(), BCL2L1()),
#    {'reach': 42, 'medscan': 2}), (DecreaseAmount(BCL2(), BCL2L1()),
#    {'reach': 4, 'medscan': 4}), (IncreaseAmount(BCL2(), BCL2L1()),
#    {'reach': 4, 'medscan': 2}), (Phosphorylation(BCL2(), BCL2L1()),
#    {'isi': 1, 'reach': 3})],
#  ('BCL2',
#   'BAX'): [(Inhibition(BCL2(), BAX()),
#    {'signor': 1,
#     'eidos': 3,
#     'reach': 682,
#     'sparser': 46,
#     'medscan': 61}), (Activation(BCL2(), BAX()),
#    {'eidos': 1,
#     'reach': 386,
#     'sparser': 26,
#     'medscan': 10}), (IncreaseAmount(BCL2(), BAX()),
#    {'isi': 93, 'reach': 47}), (DecreaseAmount(BCL2(), BAX()),
#    {'reach': 53,
#     'bel_lc': 1,
#     'medscan': 3}), (Dephosphorylation(BCL2(), BAX()),
#    {'reach': 2, 'sparser': 2}), (Phosphorylation(BCL2(), BAX()),
#    {'isi': 1, 'reach': 1, 'sparser': 1})],
#  ('BCL2', 'BAD'): [(Inhibition(BCL2(), BAD()), {'reach': 15, 'sparser': 2}),
#   (Activation(BCL2(), BAD()), {'reach': 15, 'sparser': 1}),
#   (Phosphorylation(BCL2(), BAD()), {'rlimsp': 1, 'reach': 3, 'sparser': 2}),
#   (DecreaseAmount(BCL2(), BAD()), {'reach': 2}),
#   (Dephosphorylation(BCL2(), BAD()), {'reach': 2}),
#   (IncreaseAmount(BCL2(), BAD()), {'isi': 1})],
#  ('BCL2',
#   'MCL1'): [(Inhibition(BCL2(), MCL1()),
#    {'reach': 37, 'sparser': 4, 'medscan': 3}), (Activation(BCL2(), MCL1()),
#    {'reach': 31, 'medscan': 1}), (IncreaseAmount(BCL2(), MCL1()),
#    {'isi': 2, 'reach': 5, 'medscan': 1}), (Phosphorylation(BCL2(), MCL1()),
#    {'rlimsp': 1, 'reach': 2}), (DecreaseAmount(BCL2(), MCL1()), {'reach': 2})],
#  ('BCL2', 'MAPK14'): [(Phosphorylation(BCL2(), MAPK14()), {'sparser': 1})],
#  ('BCL2', 'FADD'): [(Activation(BCL2(), FADD()), {'reach': 3}),
#   (Inhibition(BCL2(), FADD()), {'reach': 2}),
#   (Phosphorylation(BCL2(), FADD()), {'reach': 1})],
#  ('BCL2',
#   'CYCS'): [(Inhibition(BCL2(), CYCS()),
#    {'signor': 1,
#     'eidos': 1,
#     'reach': 623,
#     'sparser': 5,
#     'medscan': 1}), (Activation(BCL2(), CYCS()),
#    {'reach': 334}), (DecreaseAmount(BCL2(), CYCS()),
#    {'reach': 17}), (IncreaseAmount(BCL2(), CYCS()), {'reach': 12,
#     'medscan': 1})],
#  ('BCL2', 'BBC3'): [(IncreaseAmount(BCL2(), BBC3()), {'reach': 14}),
#   (Inhibition(BCL2(), BBC3()), {'reach': 12, 'sparser': 1}),
#   (Activation(BCL2(), BBC3()), {'reach': 8, 'medscan': 3}),
#   (DecreaseAmount(BCL2(), BBC3()), {'reach': 3})],
#  ('BCL2', 'AKT'): [(Activation(BCL2(), AKT()), {'reach': 52, 'medscan': 2}),
#   (Phosphorylation(BCL2(), AKT()),
#    {'isi': 3, 'rlimsp': 2, 'reach': 14, 'sparser': 4, 'trips': 1}),
#   (Inhibition(BCL2(), AKT()), {'reach': 18, 'medscan': 2}),
#   (IncreaseAmount(BCL2(), AKT()), {'isi': 4, 'reach': 1}),
#   (Dephosphorylation(BCL2(), AKT()), {'reach': 2}),
#   (Phosphorylation(BCL2(), AKT(), S, 473), {'reach': 1})],
#  ('BCL2',
#   'CASP9'): [(Inhibition(BCL2(), CASP9()),
#    {'eidos': 1, 'reach': 96, 'medscan': 5}), (Activation(BCL2(), CASP9()),
#    {'eidos': 1,
#     'reach': 75,
#     'sparser': 6,
#     'medscan': 3}), (IncreaseAmount(BCL2(), CASP9()),
#    {'isi': 10, 'reach': 2}), (DecreaseAmount(BCL2(), CASP9()),
#    {'reach': 9}), (Phosphorylation(BCL2(), CASP9()), {'rlimsp': 2,
#     'reach': 2,
#     'sparser': 1})],
#  ('BCL2',
#   'CASP8'): [(Inhibition(BCL2(), CASP8()),
#    {'reach': 38, 'sparser': 1, 'medscan': 1}), (Activation(BCL2(), CASP8()),
#    {'reach': 14,
#     'sparser': 2,
#     'medscan': 1}), (DecreaseAmount(BCL2(), CASP8()),
#    {'reach': 2})],
#  ('BCL2', 'CASP7'): [(Activation(BCL2(), CASP7()), {'reach': 4, 'sparser': 1}),
#   (Inhibition(BCL2(), CASP7()), {'reach': 4})],
#  ('BCL2',
#   'CASP3'): [(Inhibition(BCL2(), CASP3()),
#    {'eidos': 6,
#     'reach': 361,
#     'sparser': 2,
#     'medscan': 13}), (Activation(BCL2(), CASP3()),
#    {'eidos': 1,
#     'reach': 199,
#     'sparser': 11,
#     'medscan': 6}), (IncreaseAmount(BCL2(), CASP3()),
#    {'isi': 39, 'reach': 22, 'medscan': 5}), (DecreaseAmount(BCL2(), CASP3()),
#    {'isi': 1, 'reach': 24, 'medscan': 2}), (Phosphorylation(BCL2(), CASP3()),
#    {'isi': 1,
#     'rlimsp': 1,
#     'sparser': 3}), (Inhibition(BCL2(), CASP3(), catalytic),
#    {'bel_lc': 2})],
#  ('BCL2', 'FASLG'): [(DecreaseAmount(BCL2(), FASLG()), {'reach': 8}),
#   (Inhibition(BCL2(), FASLG()), {'reach': 5}),
#   (Phosphorylation(BCL2(), FASLG()), {'rlimsp': 1, 'reach': 1, 'sparser': 2}),
#   (Activation(BCL2(), FASLG()), {'reach': 2})],
#  ('BCL2', 'FAS'): [(Inhibition(BCL2(), FAS()), {'reach': 21, 'medscan': 1}),
#   (Activation(BCL2(), FAS()), {'reach': 18}),
#   (IncreaseAmount(BCL2(), FAS()), {'isi': 1, 'reach': 2})],
#  ('BCL2', 'TNF'): [(Inhibition(BCL2(), TNF()), {'reach': 23, 'medscan': 2}),
#   (Activation(BCL2(), TNF()), {'reach': 19}),
#   (IncreaseAmount(BCL2(), TNF()), {'isi': 5, 'reach': 1}),
#   (DecreaseAmount(BCL2(), TNF()), {'reach': 2})],
#  ('BCL2',
#   'BID'): [(Inhibition(BCL2(), BID()),
#    {'reach': 39, 'sparser': 1, 'medscan': 3}), (Activation(BCL2(), BID()),
#    {'reach': 15}), (IncreaseAmount(BCL2(), BID()), {'reach': 2})],
#  ('BCL2', 'apoptosome'): [(Inhibition(BCL2(), apoptosome()), {'medscan': 1}),
#   (Activation(BCL2(), apoptosome()), {'medscan': 1})],
#  ('BCL2',
#   'apoptotic process'): [(Inhibition(BCL2(), apoptotic process()),
#    {'eidos': 203,
#     'reach': 5251,
#     'conib': 6,
#     'sparser': 636,
#     'trips': 15,
#     'medscan': 248}), (Activation(BCL2(), apoptotic process()),
#    {'eidos': 26, 'reach': 2820, 'sparser': 5, 'medscan': 53})],
#  ('BCL2L1',
#   'Envelope small membrane protein'): [(Complex(BCL2L1(), Envelope small membrane protein()),
#    {'vhn': 2})],
#  ('BCL2L1',
#   'BCL2L11'): [(Complex(BCL2L1(), BCL2L11()),
#    {'hprd': 5,
#     'signor': 3,
#     'reach': 131,
#     'biogrid': 14,
#     'sparser': 105,
#     'trips': 2,
#     'medscan': 27}), (Inhibition(BCL2L1(), BCL2L11()),
#    {'reach': 25,
#     'sparser': 3,
#     'medscan': 2}), (Activation(BCL2L1(), BCL2L11()),
#    {'reach': 12, 'medscan': 1}), (DecreaseAmount(BCL2L1(), BCL2L11()),
#    {'reach': 2}), (IncreaseAmount(BCL2L1(), BCL2L11()),
#    {'reach': 1}), (Phosphorylation(BCL2L1(), BCL2L11(), S, 69), {'reach': 1}), (Dephosphorylation(BCL2L1(), BCL2L11(), S, 87),
#    {'reach': 1})],
#  ('BCL2L1',
#   'BCL2'): [(Inhibition(BCL2L1(), BCL2()),
#    {'reach': 48, 'sparser': 6, 'medscan': 1}), (Activation(BCL2L1(), BCL2()),
#    {'reach': 28,
#     'sparser': 1,
#     'medscan': 2}), (IncreaseAmount(BCL2L1(), BCL2()),
#    {'reach': 7, 'medscan': 1}), (DecreaseAmount(BCL2L1(), BCL2()),
#    {'reach': 3, 'medscan': 1}), (Phosphorylation(BCL2L1(), BCL2()),
#    {'reach': 2}), (Dephosphorylation(BCL2L1(), BCL2()),
#    {'reach': 1}), (Ubiquitination(BCL2L1(), BCL2()), {'reach': 1})],
#  ('BCL2L1',
#   'BAX'): [(Inhibition(BCL2L1(), BAX()),
#    {'signor': 1,
#     'eidos': 2,
#     'reach': 192,
#     'sparser': 37,
#     'medscan': 50}), (Activation(BCL2L1(), BAX()),
#    {'reach': 80,
#     'sparser': 6,
#     'pc': 1,
#     'medscan': 5}), (IncreaseAmount(BCL2L1(), BAX()),
#    {'isi': 1, 'reach': 6}), (DecreaseAmount(BCL2L1(), BAX()),
#    {'reach': 3, 'medscan': 2}), (Phosphorylation(BCL2L1(), BAX()),
#    {'sparser': 1})],
#  ('BCL2L1',
#   'BAD'): [(Inhibition(BCL2L1(), BAD()),
#    {'reach': 17, 'sparser': 1}), (Activation(BCL2L1(), BAD()), {'signor': 1,
#     'reach': 6,
#     'sparser': 2}), (Phosphorylation(BCL2L1(), BAD(), S, 75),
#    {'reach': 1}), (IncreaseAmount(BCL2L1(), BAD()), {'isi': 1}), (Dephosphorylation(BCL2L1(), BAD()),
#    {'reach': 1})],
#  ('BCL2L1',
#   'MCL1'): [(Activation(BCL2L1(), MCL1()),
#    {'reach': 10,
#     'medscan': 3}), (Inhibition(BCL2L1(), MCL1()), {'reach': 10}), (Phosphorylation(BCL2L1(), MCL1()),
#    {'sparser': 2}), (DecreaseAmount(BCL2L1(), MCL1()),
#    {'reach': 1}), (IncreaseAmount(BCL2L1(), MCL1()), {'reach': 1})],
#  ('BCL2L1', 'MAPK14'): [(Activation(BCL2L1(), MAPK14()), {'medscan': 1})],
#  ('BCL2L1',
#   'FADD'): [(Inhibition(BCL2L1(), FADD()),
#    {'reach': 4, 'sparser': 2}), (Activation(BCL2L1(), FADD()), {'reach': 2})],
#  ('BCL2L1',
#   'CYCS'): [(Inhibition(BCL2L1(), CYCS()),
#    {'reach': 134, 'sparser': 2, 'medscan': 1}), (Activation(BCL2L1(), CYCS()),
#    {'reach': 44}), (DecreaseAmount(BCL2L1(), CYCS()),
#    {'reach': 4}), (IncreaseAmount(BCL2L1(), CYCS()), {'reach': 2})],
#  ('BCL2L1',
#   'BBC3'): [(Inhibition(BCL2L1(), BBC3()),
#    {'reach': 10, 'sparser': 2, 'medscan': 1}), (Activation(BCL2L1(), BBC3()),
#    {'reach': 4}), (DecreaseAmount(BCL2L1(), BBC3()), {'reach': 1})],
#  ('BCL2L1',
#   'CASP9'): [(Inhibition(BCL2L1(), CASP9()),
#    {'signor': 1, 'reach': 21, 'medscan': 2}), (Activation(BCL2L1(), CASP9()),
#    {'reach': 4, 'sparser': 1, 'medscan': 1})],
#  ('BCL2L1',
#   'CASP8'): [(Inhibition(BCL2L1(), CASP8()),
#    {'reach': 21, 'sparser': 3, 'medscan': 1}), (Activation(BCL2L1(), CASP8()),
#    {'reach': 2})],
#  ('BCL2L1',
#   'CASP3'): [(Inhibition(BCL2L1(), CASP3()),
#    {'eidos': 1,
#     'reach': 70,
#     'sparser': 3,
#     'medscan': 4}), (Activation(BCL2L1(), CASP3()),
#    {'reach': 21, 'medscan': 2}), (DecreaseAmount(BCL2L1(), CASP3()),
#    {'reach': 4}), (IncreaseAmount(BCL2L1(), CASP3()),
#    {'isi': 2, 'reach': 2}), (Phosphorylation(BCL2L1(), CASP3()),
#    {'sparser': 1})],
#  ('BCL2L1',
#   'FAS'): [(Inhibition(BCL2L1(), FAS()),
#    {'reach': 9, 'sparser': 1, 'medscan': 2}), (Activation(BCL2L1(), FAS()),
#    {'reach': 5, 'medscan': 3}), (DecreaseAmount(BCL2L1(), FAS()),
#    {'reach': 2, 'medscan': 1})],
#  ('BCL2L1',
#   'TNF'): [(Inhibition(BCL2L1(), TNF()),
#    {'reach': 10,
#     'sparser': 1,
#     'medscan': 4}), (DecreaseAmount(BCL2L1(), TNF()),
#    {'reach': 2}), (Activation(BCL2L1(), TNF()), {'reach': 1})],
#  ('BCL2L1',
#   'BID'): [(Inhibition(BCL2L1(), BID()),
#    {'eidos': 1,
#     'reach': 13,
#     'sparser': 3,
#     'medscan': 7}), (Activation(BCL2L1(), BID()),
#    {'reach': 8, 'sparser': 1, 'medscan': 1}), (DecreaseAmount(BCL2L1(), BID()),
#    {'medscan': 1})],
#  ('BCL2L1',
#   'apoptotic process'): [(Inhibition(BCL2L1(), apoptotic process()),
#    {'eidos': 31,
#     'reach': 981,
#     'conib': 2,
#     'sparser': 150,
#     'trips': 7,
#     'medscan': 101}), (Activation(BCL2L1(), apoptotic process()),
#    {'eidos': 9, 'reach': 447, 'sparser': 1, 'medscan': 35})],
#  ('BCL2L1', 'AKT'): [(Activation(BCL2L1(), AKT()), {'reach': 7, 'medscan': 1}),
#   (Inhibition(BCL2L1(), AKT()), {'reach': 3, 'medscan': 2}),
#   (Phosphorylation(BCL2L1(), AKT()), {'reach': 1}),
#   (Phosphorylation(BCL2L1(), AKT(), A, 549), {'reach': 1})],
#  ('BCL2L11',
#   'BCL2L1'): [(Inhibition(BCL2L11(), BCL2L1()),
#    {'signor': 3,
#     'eidos': 1,
#     'reach': 22,
#     'sparser': 6,
#     'medscan': 8}), (Activation(BCL2L11(), BCL2L1()),
#    {'reach': 8, 'medscan': 1}), (DecreaseAmount(BCL2L11(), BCL2L1()),
#    {'medscan': 1}), (IncreaseAmount(BCL2L11(), BCL2L1()), {'reach': 1})],
#  ('BCL2L11',
#   'BCL2'): [(Inhibition(BCL2L11(), BCL2()),
#    {'signor': 3,
#     'reach': 72,
#     'sparser': 9,
#     'medscan': 5}), (Activation(BCL2L11(), BCL2()),
#    {'reach': 39,
#     'sparser': 1,
#     'medscan': 2}), (DecreaseAmount(BCL2L11(), BCL2()),
#    {'reach': 4, 'medscan': 1}), (IncreaseAmount(BCL2L11(), BCL2()),
#    {'isi': 1, 'reach': 1, 'medscan': 1}), (Phosphorylation(BCL2L11(), BCL2()),
#    {'reach': 2})],
#  ('BCL2L11',
#   'BAX'): [(Activation(BCL2L11(), BAX()),
#    {'signor': 4,
#     'eidos': 4,
#     'reach': 315,
#     'sparser': 105,
#     'trips': 4,
#     'medscan': 33}), (Inhibition(BCL2L11(), BAX()),
#    {'reach': 27, 'medscan': 6}), (IncreaseAmount(BCL2L11(), BAX()),
#    {'reach': 1})],
#  ('BCL2L11',
#   'BAD'): [(Inhibition(BCL2L11(), BAD()),
#    {'reach': 1,
#     'sparser': 1}), (Activation(BCL2L11(), BAD()), {'sparser': 1})],
#  ('BCL2L11',
#   'MCL1'): [(Inhibition(BCL2L11(), MCL1()),
#    {'reach': 18, 'sparser': 4, 'medscan': 3}), (Activation(BCL2L11(), MCL1()),
#    {'reach': 11, 'medscan': 1}), (IncreaseAmount(BCL2L11(), MCL1()),
#    {'reach': 4, 'medscan': 1}), (DecreaseAmount(BCL2L11(), MCL1()),
#    {'reach': 1, 'medscan': 1})],
#  ('BCL2L11',
#   'CYCS'): [(Activation(BCL2L11(), CYCS()),
#    {'reach': 57,
#     'medscan': 1}), (Inhibition(BCL2L11(), CYCS()), {'reach': 9}), (IncreaseAmount(BCL2L11(), CYCS()),
#    {'reach': 3})],
#  ('BCL2L11',
#   'BBC3'): [(Activation(BCL2L11(), BBC3()),
#    {'reach': 8, 'medscan': 1}), (Inhibition(BCL2L11(), BBC3()), {'reach': 7,
#     'sparser': 1,
#     'medscan': 1}), (IncreaseAmount(BCL2L11(), BBC3()),
#    {'reach': 1}), (DecreaseAmount(BCL2L11(), BBC3()), {'reach': 1})],
#  ('BCL2L11',
#   'CASP9'): [(Activation(BCL2L11(), CASP9()),
#    {'reach': 13, 'sparser': 2, 'medscan': 2}), (Inhibition(BCL2L11(), CASP9()),
#    {'reach': 7})],
#  ('BCL2L11', 'CASP7'): [(Activation(BCL2L11(), CASP7()), {'reach': 1})],
#  ('BCL2L11',
#   'CASP3'): [(Activation(BCL2L11(), CASP3()),
#    {'eidos': 1,
#     'reach': 34,
#     'sparser': 8,
#     'medscan': 5}), (Inhibition(BCL2L11(), CASP3()),
#    {'reach': 18, 'medscan': 1}), (Dephosphorylation(BCL2L11(), CASP3()),
#    {'reach': 1}), (IncreaseAmount(BCL2L11(), CASP3()), {'isi': 1})],
#  ('BCL2L11', 'FASLG'): [(IncreaseAmount(BCL2L11(), FASLG()), {'reach': 1})],
#  ('BCL2L11',
#   'FAS'): [(Activation(BCL2L11(), FAS()), {'reach': 3, 'medscan': 1})],
#  ('BCL2L11', 'TNF'): [(Activation(BCL2L11(), TNF()), {'reach': 4}),
#   (Inhibition(BCL2L11(), TNF()), {'reach': 1, 'medscan': 1})],
#  ('BCL2L11',
#   'BID'): [(Activation(BCL2L11(), BID()),
#    {'reach': 2,
#     'sparser': 1}), (Inhibition(BCL2L11(), BID()), {'reach': 3}), (IncreaseAmount(BCL2L11(), BID()),
#    {'isi': 1})],
#  ('BCL2L11',
#   'apoptotic process'): [(Activation(BCL2L11(), apoptotic process()),
#    {'eidos': 25,
#     'reach': 1151,
#     'conib': 1,
#     'sparser': 6,
#     'medscan': 62}), (Inhibition(BCL2L11(), apoptotic process()),
#    {'eidos': 4, 'reach': 251, 'sparser': 8, 'medscan': 14})],
#  ('BCL2L11',
#   'AKT'): [(Inhibition(BCL2L11(), AKT()),
#    {'reach': 5,
#     'medscan': 1}), (Phosphorylation(BCL2L11(), AKT()), {'reach': 5,
#     'sparser': 1}), (Activation(BCL2L11(), AKT()),
#    {'reach': 5}), (Dephosphorylation(BCL2L11(), AKT()), {'reach': 5}), (IncreaseAmount(BCL2L11(), AKT()),
#    {'isi': 2}), (Dephosphorylation(BCL2L11(), AKT(), S, 473), {'reach': 1})],
#  ('BID', 'FADD'): [(Complex(BID(), FADD()), {'biogrid': 2, 'sparser': 2})],
#  ('BID',
#   'CYCS'): [(Activation(BID(), CYCS()),
#    {'signor': 1,
#     'eidos': 1,
#     'reach': 225,
#     'sparser': 1,
#     'medscan': 2}), (Inhibition(BID(), CYCS()),
#    {'reach': 11}), (IncreaseAmount(BID(), CYCS()),
#    {'reach': 7}), (Complex(BID(), CYCS()), {'sparser': 6}), (DecreaseAmount(BID(), CYCS()),
#    {'reach': 1})],
#  ('BID', 'BBC3'): [(Complex(BID(), BBC3()), {'reach': 1, 'sparser': 5}),
#   (Inhibition(BID(), BBC3()), {'reach': 1, 'sparser': 1}),
#   (Activation(BID(), BBC3()), {'reach': 1})],
#  ('BID',
#   'CASP9'): [(Activation(BID(), CASP9()),
#    {'reach': 32, 'sparser': 12, 'medscan': 4}), (Complex(BID(), CASP9()),
#    {'reach': 2, 'sparser': 1, 'medscan': 1}), (Inhibition(BID(), CASP9()),
#    {'reach': 3}), (DecreaseAmount(BID(), CASP9()), {'medscan': 1})],
#  ('BID',
#   'CASP8'): [(Activation(BID(), CASP8()),
#    {'reach': 41, 'sparser': 4, 'medscan': 1}), (Complex(BID(), CASP8()),
#    {'hprd': 5,
#     'reach': 8,
#     'biogrid': 2,
#     'sparser': 30}), (Inhibition(BID(), CASP8()),
#    {'reach': 3, 'medscan': 1}), (IncreaseAmount(BID(), CASP8()),
#    {'reach': 1})],
#  ('BID', 'CASP7'): [(Activation(BID(), CASP7()), {'reach': 2, 'sparser': 1})],
#  ('BID',
#   'CASP3'): [(Activation(BID(), CASP3()),
#    {'reach': 33, 'sparser': 4, 'medscan': 1}), (Inhibition(BID(), CASP3()),
#    {'reach': 6, 'medscan': 1}), (Complex(BID(), CASP3()),
#    {'hprd': 1, 'reach': 1, 'biogrid': 2, 'sparser': 2})],
#  ('BID', 'FASLG'): [(Activation(BID(), FASLG()), {'reach': 4, 'medscan': 1}),
#   (Complex(BID(), FASLG()), {'reach': 1, 'biogrid': 2}),
#   (IncreaseAmount(BID(), FASLG()), {'isi': 1})],
#  ('BID', 'FAS'): [(Activation(BID(), FAS()), {'reach': 8, 'medscan': 1}),
#   (Complex(BID(), FAS()), {'reach': 1, 'biogrid': 2, 'sparser': 2}),
#   (Inhibition(BID(), FAS()), {'reach': 3, 'medscan': 1}),
#   (IncreaseAmount(BID(), FAS()), {'isi': 1})],
#  ('BID', 'TNFRSF1A'): [(Complex(BID(), TNFRSF1A()), {'biogrid': 1})],
#  ('BID', 'TNF'): [(Inhibition(BID(), TNF()), {'reach': 2, 'medscan': 1}),
#   (Complex(BID(), TNF()), {'reach': 1, 'sparser': 1}),
#   (Activation(BID(), TNF()), {'reach': 1}),
#   (IncreaseAmount(BID(), TNF()), {'reach': 1})],
#  ('BID', 'apoptosome'): [(Activation(BID(), apoptosome()), {'medscan': 2})],
#  ('BID',
#   'apoptotic process'): [(Activation(BID(), apoptotic process()),
#    {'eidos': 9,
#     'reach': 443,
#     'sparser': 3,
#     'medscan': 28}), (Inhibition(BID(), apoptotic process()),
#    {'reach': 52, 'sparser': 3, 'trips': 1, 'medscan': 5})],
#  ('BID', 'AKT'): [(Inhibition(BID(), AKT()), {'reach': 4})],
#  ('BID', 'BCL2L11'): [(Complex(BID(), BCL2L11()), {'reach': 8, 'sparser': 16}),
# ...
#    {'reach': 7}), (Complex(CASP8(), BAX()),
#    {'reach': 2,
#     'biogrid': 1,
#     'sparser': 1,
#     'medscan': 1}), (Inhibition(CASP8(), BAX()),
#    {'reach': 3, 'medscan': 1}), (DecreaseAmount(CASP8(), BAX()),
#    {'reach': 3})],
#  ('CASP8', 'BAD'): [(Inhibition(CASP8(), BAD()), {'reach': 1}),
#   (Activation(CASP8(), BAD()), {'reach': 1})],
#  ('CASP8', 'MCL1'): [(Activation(CASP8(), MCL1()), {'reach': 4}),
#   (Inhibition(CASP8(), MCL1()), {'reach': 2, 'medscan': 1}),
#   (Complex(CASP8(), MCL1()), {'sparser': 1}),
#   (DecreaseAmount(CASP8(), MCL1()), {'reach': 1})],
#  ('CASP8', 'MAPK14'): [(Complex(CASP8(), MAPK14()), {'medscan': 1})],
#  ('CASP8',
#   'FADD'): [(Complex(CASP8(), FADD()),
#    {'isi': 1,
#     'hprd': 5,
#     'signor': 1,
#     'reach': 334,
#     'biogrid': 35,
#     'sparser': 316,
#     'trips': 5,
#     'medscan': 32}), (Activation(CASP8(), FADD()),
#    {'isi': 1,
#     'reach': 12,
#     'sparser': 4,
#     'medscan': 3}), (Inhibition(CASP8(), FADD()),
#    {'reach': 4, 'medscan': 1}), (DecreaseAmount(CASP8(), FADD()),
#    {'reach': 3}), (IncreaseAmount(CASP8(), FADD()), {'isi': 1})],
#  ('CASP8', 'CYCS'): [(Activation(CASP8(), CYCS()), {'signor': 1, 'reach': 58}),
#   (Complex(CASP8(), CYCS()), {'sparser': 4}),
#   (Inhibition(CASP8(), CYCS()), {'reach': 3}),
#   (IncreaseAmount(CASP8(), CYCS()), {'reach': 2}),
#   (DecreaseAmount(CASP8(), CYCS()), {'reach': 1})],
#  ('CASP8', 'BBC3'): [(Activation(CASP8(), BBC3()), {'reach': 3})],
#  ('CASP8',
#   'CASP9'): [(Activation(CASP8(), CASP9()),
#    {'signor': 1,
#     'eidos': 6,
#     'reach': 142,
#     'sparser': 27,
#     'medscan': 10}), (Complex(CASP8(), CASP9()),
#    {'reach': 9, 'biogrid': 2, 'sparser': 39}), (Inhibition(CASP8(), CASP9()),
#    {'reach': 16,
#     'sparser': 1,
#     'medscan': 4}), (DecreaseAmount(CASP8(), CASP9()),
#    {'medscan': 3}), (IncreaseAmount(CASP8(), CASP9()),
#    {'isi': 1, 'reach': 1})],
#  ('CASP9',
#   'BCL2L11'): [(Complex(CASP9(), BCL2L11()),
#    {'reach': 1,
#     'sparser': 1}), (DecreaseAmount(CASP9(), BCL2L11()), {'reach': 1}), (Phosphorylation(CASP9(), BCL2L11()),
#    {'sparser': 1})],
#  ('CASP9',
#   'BCL2L1'): [(Complex(CASP9(), BCL2L1()),
#    {'hprd': 1,
#     'signor': 1,
#     'reach': 1,
#     'biogrid': 2,
#     'sparser': 7,
#     'trips': 2,
#     'medscan': 1}), (Inhibition(CASP9(), BCL2L1()),
#    {'reach': 6, 'medscan': 3}), (Activation(CASP9(), BCL2L1()),
#    {'reach': 3,
#     'sparser': 1,
#     'medscan': 1}), (IncreaseAmount(CASP9(), BCL2L1()),
#    {'reach': 1})],
#  ('CASP9',
#   'BCL2'): [(Inhibition(CASP9(), BCL2()),
#    {'eidos': 2, 'reach': 15, 'medscan': 8}), (Activation(CASP9(), BCL2()),
#    {'reach': 21,
#     'sparser': 2,
#     'medscan': 1}), (IncreaseAmount(CASP9(), BCL2()),
#    {'isi': 10, 'reach': 10}), (DecreaseAmount(CASP9(), BCL2()),
#    {'reach': 17}), (Complex(CASP9(), BCL2()), {'reach': 1, 'sparser': 4})],
#  ('CASP9', 'BAX'): [(IncreaseAmount(CASP9(), BAX()), {'isi': 6, 'reach': 7}),
#   (Activation(CASP9(), BAX()), {'reach': 11, 'sparser': 1, 'medscan': 1}),
#   (Complex(CASP9(), BAX()), {'reach': 4, 'biogrid': 1, 'sparser': 4}),
#   (Inhibition(CASP9(), BAX()), {'reach': 6, 'medscan': 2}),
#   (DecreaseAmount(CASP9(), BAX()), {'reach': 3}),
#   (Dephosphorylation(CASP9(), BAX()), {'reach': 1})],
#  ('CASP9',
#   'BAD'): [(Phosphorylation(CASP9(), BAD()),
#    {'reach': 1,
#     'sparser': 2}), (DecreaseAmount(CASP9(), BAD()), {'reach': 1}), (Activation(CASP9(), BAD()),
#    {'reach': 1}), (IncreaseAmount(CASP9(), BAD()), {'reach': 1})],
#  ('CASP9', 'MCL1'): [(Inhibition(CASP9(), MCL1()), {'reach': 1, 'medscan': 3}),
#   (Activation(CASP9(), MCL1()), {'reach': 2}),
#   (DecreaseAmount(CASP9(), MCL1()), {'reach': 1})],
#  ('CASP9', 'MAPK14'): [(Phosphorylation(CASP9(), MAPK14()), {'medscan': 1}),
#   (Activation(CASP9(), MAPK14()), {'medscan': 1})],
#  ('CASP9', 'FADD'): [(Activation(CASP9(), FADD()), {'reach': 1}),
#   (Inhibition(CASP9(), FADD()), {'medscan': 1})],
#  ('CASP9',
#   'CYCS'): [(Complex(CASP9(), CYCS()),
#    {'hprd': 1,
#     'signor': 1,
#     'reach': 127,
#     'biogrid': 1,
#     'sparser': 32,
#     'trips': 1,
#     'medscan': 12}), (Activation(CASP9(), CYCS()),
#    {'reach': 24, 'sparser': 1}), (Inhibition(CASP9(), CYCS()),
#    {'reach': 10}), (IncreaseAmount(CASP9(), CYCS()),
#    {'reach': 4}), (DecreaseAmount(CASP9(), CYCS()), {'reach': 2})],
#  ('CASP9', 'BBC3'): [(Activation(CASP9(), BBC3()), {'reach': 5, 'medscan': 2}),
#   (IncreaseAmount(CASP9(), BBC3()), {'reach': 2}),
#   (DecreaseAmount(CASP9(), BBC3()), {'reach': 2}),
#   (Complex(CASP9(), BBC3()), {'reach': 1, 'sparser': 1})],
#  ('CASP9',
#   'CASP8'): [(Activation(CASP9(), CASP8()),
#    {'eidos': 2,
#     'reach': 62,
#     'sparser': 12,
#     'medscan': 3}), (Inhibition(CASP9(), CASP8()),
#    {'reach': 10, 'medscan': 2}), (DecreaseAmount(CASP9(), CASP8()),
#    {'reach': 1, 'medscan': 2}), (IncreaseAmount(CASP9(), CASP8()),
#    {'isi': 2})],
#  ('CASP9',
#   'CASP7'): [(Activation(CASP9(), CASP7()),
#    {'eidos': 4,
#     'reach': 51,
#     'sparser': 41,
#     'medscan': 7}), (DecreaseAmount(CASP9(), CASP7()),
#    {'reach': 1, 'medscan': 1}), (Inhibition(CASP9(), CASP7()),
#    {'reach': 2}), (IncreaseAmount(CASP9(), CASP7()), {'reach': 1,
#     'conib': 1})],
#  ('CASP9',
#   'CASP3'): [(Activation(CASP9(), CASP3()),
#    {'signor': 2,
#     'eidos': 26,
#     'reach': 813,
#     'sparser': 515,
#     'trips': 1,
#     'medscan': 38}), (Inhibition(CASP9(), CASP3()),
#    {'eidos': 2, 'reach': 34, 'medscan': 4}), (IncreaseAmount(CASP9(), CASP3()),
#    {'isi': 10, 'reach': 8, 'conib': 1}), (DecreaseAmount(CASP9(), CASP3()),
#    {'reach': 1, 'medscan': 2}), (Dephosphorylation(CASP9(), CASP3()),
#    {'sparser': 1})],
#  ('CASP9', 'FASLG'): [(Activation(CASP9(), FASLG()), {'reach': 4}),
#   (IncreaseAmount(CASP9(), FASLG()), {'reach': 1, 'medscan': 1})],
#  ('CASP9', 'FAS'): [(Activation(CASP9(), FAS()), {'reach': 3}),
#   (Inhibition(CASP9(), FAS()), {'reach': 2, 'sparser': 1}),
#   (IncreaseAmount(CASP9(), FAS()), {'reach': 1, 'medscan': 1})],
#  ('CASP9', 'TNFRSF1A'): [(DecreaseAmount(CASP9(), TNFRSF1A()), {'reach': 1}),
#   (Activation(CASP9(), TNFRSF1A()), {'reach': 1})],
#  ('CASP9', 'TNF'): [(Activation(CASP9(), TNF()), {'reach': 2}),
#   (IncreaseAmount(CASP9(), TNF()), {'isi': 1})],
#  ('CASP9',
#   'BID'): [(Activation(CASP9(), BID()),
#    {'reach': 10, 'sparser': 1, 'medscan': 1}), (Inhibition(CASP9(), BID()),
#    {'reach': 3})],
#  ('CASP9',
#   'apoptosome'): [(Activation(CASP9(), apoptosome()),
#    {'eidos': 1, 'medscan': 2})],
#  ('CASP9',
#   'apoptotic process'): [(Activation(CASP9(), apoptotic process()),
#    {'eidos': 29,
#     'reach': 775,
#     'sparser': 2,
#     'medscan': 39}), (Inhibition(CASP9(), apoptotic process()),
#    {'eidos': 3,
#     'reach': 145,
#     'sparser': 34,
#     'trips': 1,
#     'medscan': 18}), (IncreaseAmount(CASP9(), apoptotic process()),
#    {'isi': 1})],
#  ('CASP9', 'AKT'): [(Activation(CASP9(), AKT()), {'reach': 18}),
#   (Inhibition(CASP9(), AKT()), {'reach': 8}),
#   (Phosphorylation(CASP9(), AKT()), {'reach': 3}),
#   (IncreaseAmount(CASP9(), AKT()), {'reach': 1})],
#  ('AKT',
#   'MCL1'): [(Activation(AKT(), MCL1()),
#    {'reach': 42, 'sparser': 2, 'medscan': 3}), (Complex(AKT(), MCL1()),
#    {'reach': 18, 'sparser': 14}), (Inhibition(AKT(), MCL1()),
#    {'reach': 20, 'sparser': 1, 'medscan': 8}), (IncreaseAmount(AKT(), MCL1()),
#    {'reach': 23, 'medscan': 3}), (DecreaseAmount(AKT(), MCL1()),
#    {'reach': 12, 'medscan': 1}), (Phosphorylation(AKT(), MCL1()),
#    {'reach': 8, 'sparser': 2}), (Phosphorylation(AKT(), MCL1(), S, 159),
#    {'reach': 2, 'sparser': 1}), (Ubiquitination(AKT(), MCL1()),
#    {'reach': 2}), (Deubiquitination(AKT(), MCL1()), {'reach': 1})],
#  ('AKT', 'CYCS'): [(Inhibition(AKT(), CYCS()), {'reach': 51}),
#   (Activation(AKT(), CYCS()), {'reach': 14}),
#   (Complex(AKT(), CYCS()), {'sparser': 1}),
#   (IncreaseAmount(AKT(), CYCS()), {'reach': 1})],
#  ('AKT',
#   'MAPK14'): [(Inhibition(AKT(), MAPK14()),
#    {'signor': 1,
#     'medscan': 1}), (Activation(AKT(), MAPK14()), {'medscan': 1}), (Complex(AKT(), MAPK14()),
#    {'medscan': 1}), (Phosphorylation(AKT(), MAPK14()), {'rlimsp': 1})],
#  ('AKT',
#   'BBC3'): [(Inhibition(AKT(), BBC3()),
#    {'reach': 20, 'sparser': 1, 'medscan': 2}), (DecreaseAmount(AKT(), BBC3()),
#    {'reach': 9}), (IncreaseAmount(AKT(), BBC3()),
#    {'reach': 8}), (Activation(AKT(), BBC3()), {'reach': 4,
#     'sparser': 1,
#     'medscan': 1}), (Phosphorylation(AKT(), BBC3()), {'reach': 1})],
#  ('AKT',
#   'CASP9'): [(Phosphorylation(AKT(), CASP9()),
#    {'rlimsp': 7,
#     'reach': 64,
#     'sparser': 52,
#     'medscan': 2}), (Inhibition(AKT(), CASP9()),
#    {'signor': 3,
#     'eidos': 1,
#     'reach': 68,
#     'sparser': 19,
#     'medscan': 10}), (Phosphorylation(AKT(), CASP9(), S, 196),
#    {'signor': 3,
#     'reach': 15,
#     'pe': 1,
#     'sparser': 14,
#     'trips': 1,
#     'medscan': 1}), (Activation(AKT(), CASP9()),
#    {'reach': 28, 'medscan': 5}), (Dephosphorylation(AKT(), CASP9()),
#    {'reach': 9}), (DecreaseAmount(AKT(), CASP9()),
#    {'reach': 7, 'medscan': 2}), (IncreaseAmount(AKT(), CASP9()),
#    {'reach': 4}), (Complex(AKT(), CASP9()),
#    {'sparser': 2}), (Ubiquitination(AKT(), CASP9()), {'reach': 1}), (Dephosphorylation(AKT(), CASP9(), S, 196),
#    {'reach': 1}), (Inhibition(AKT(), CASP9(), catalytic), {'bel_lc': 1})],
#  ('AKT', 'CASP8'): [(Inhibition(AKT(), CASP8()), {'reach': 11, 'medscan': 2}),
#   (Activation(AKT(), CASP8()), {'eidos': 1, 'reach': 3, 'medscan': 1}),
#   (IncreaseAmount(AKT(), CASP8()), {'reach': 2}),
#   (Phosphorylation(AKT(), CASP8()), {'reach': 2})],
#  ('AKT', 'CASP7'): [(Inhibition(AKT(), CASP7()), {'reach': 3}),
#   (Activation(AKT(), CASP7()), {'reach': 1})],
#  ('AKT',
#   'CASP3'): [(Inhibition(AKT(), CASP3()),
#    {'reach': 128, 'sparser': 3, 'medscan': 7}), (Activation(AKT(), CASP3()),
#    {'reach': 66,
#     'sparser': 5,
#     'medscan': 5}), (Phosphorylation(AKT(), CASP3()),
#    {'isi': 3,
#     'rlimsp': 1,
#     'reach': 12,
#     'sparser': 2}), (IncreaseAmount(AKT(), CASP3()),
#    {'isi': 2, 'reach': 13}), (Complex(AKT(), CASP3()),
#    {'sparser': 12, 'medscan': 1}), (DecreaseAmount(AKT(), CASP3()),
#    {'reach': 10, 'medscan': 1}), (Dephosphorylation(AKT(), CASP3()),
#    {'reach': 1})],
#  ('AKT',
#   'BCL2L11'): [(DecreaseAmount(AKT(), BCL2L11()),
#    {'reach': 34, 'medscan': 4}), (Inhibition(AKT(), BCL2L11()),
#    {'signor': 1,
#     'reach': 34,
#     'sparser': 1}), (Phosphorylation(AKT(), BCL2L11()),
#    {'reach': 19, 'sparser': 10, 'medscan': 2}), (Activation(AKT(), BCL2L11()),
#    {'reach': 17,
#     'sparser': 2,
#     'medscan': 1}), (IncreaseAmount(AKT(), BCL2L11()),
#    {'reach': 9, 'medscan': 1}), (Phosphorylation(AKT(), BCL2L11(), S, 87),
#    {'signor': 1,
#     'reach': 3,
#     'sparser': 2,
#     'medscan': 2}), (Complex(AKT(), BCL2L11()),
#    {'sparser': 2}), (Dephosphorylation(AKT(), BCL2L11()),
#    {'reach': 2}), (Phosphorylation(AKT(), BCL2L11(), S, 113), {'reach': 1}), (Phosphorylation(AKT(), BCL2L11(), S, 69),
#    {'reach': 1})],
#  ('AKT',
#   'BCL2L1'): [(Activation(AKT(), BCL2L1()),
#    {'reach': 34,
#     'sparser': 3,
#     'medscan': 4}), (IncreaseAmount(AKT(), BCL2L1()),
#    {'reach': 24, 'bel_lc': 1}), (Inhibition(AKT(), BCL2L1()),
#    {'reach': 8, 'medscan': 2}), (Phosphorylation(AKT(), BCL2L1()),
#    {'reach': 7, 'sparser': 1}), (Complex(AKT(), BCL2L1()),
#    {'reach': 2, 'sparser': 4}), (DecreaseAmount(AKT(), BCL2L1()),
#    {'reach': 5, 'medscan': 1}), (Phosphorylation(AKT(), BCL2L1(), Y, 15),
#    {'reach': 1})],
#  ('AKT', 'TRADD'): [(DecreaseAmount(AKT(), TRADD()), {'medscan': 1})],
#  ('AKT', 'FASLG'): [(DecreaseAmount(AKT(), FASLG()), {'reach': 17}),
#   (Inhibition(AKT(), FASLG()), {'reach': 9, 'sparser': 1, 'medscan': 1}),
#   (Activation(AKT(), FASLG()), {'reach': 6, 'medscan': 1}),
#   (IncreaseAmount(AKT(), FASLG()), {'reach': 3}),
#   (Complex(AKT(), FASLG()), {'sparser': 1}),
#   (Phosphorylation(AKT(), FASLG()), {'rlimsp': 1})],
#  ('AKT',
#   'FAS'): [(Inhibition(AKT(), FAS()),
#    {'signor': 1, 'reach': 14, 'medscan': 2}), (Activation(AKT(), FAS()),
#    {'reach': 16}), (IncreaseAmount(AKT(), FAS()),
#    {'reach': 7, 'medscan': 2}), (DecreaseAmount(AKT(), FAS()),
#    {'reach': 6}), (Phosphorylation(AKT(), FAS()), {'reach': 1,
#     'sparser': 1}), (Complex(AKT(), FAS()), {'reach': 1, 'sparser': 1})],
#  ('AKT',
#   'BCL2'): [(Activation(AKT(), BCL2()),
#    {'eidos': 3,
#     'reach': 120,
#     'sparser': 12,
#     'medscan': 10}), (IncreaseAmount(AKT(), BCL2()),
#    {'isi': 4, 'reach': 115, 'medscan': 3}), (Phosphorylation(AKT(), BCL2()),
#    {'isi': 2,
#     'rlimsp': 2,
#     'reach': 48,
#     'sparser': 9}), (Inhibition(AKT(), BCL2()),
#    {'eidos': 1,
#     'reach': 52,
#     'sparser': 2,
#     'medscan': 4}), (DecreaseAmount(AKT(), BCL2()),
#    {'reach': 33, 'medscan': 1}), (Complex(AKT(), BCL2()),
#    {'isi': 1, 'reach': 4, 'sparser': 14}), (Dephosphorylation(AKT(), BCL2()),
#    {'reach': 11}), (Phosphorylation(AKT(), BCL2(), S, 70), {'sparser': 1})],
#  ('AKT',
#   'TNF'): [(Activation(AKT(), TNF()),
#    {'eidos': 1,
#     'reach': 54,
#     'sparser': 2,
#     'medscan': 5}), (Inhibition(AKT(), TNF()),
#    {'reach': 24, 'medscan': 2}), (IncreaseAmount(AKT(), TNF()),
#    {'isi': 1, 'reach': 16}), (Phosphorylation(AKT(), TNF()),
#    {'rlimsp': 3, 'reach': 1, 'sparser': 6}), (Complex(AKT(), TNF()),
#    {'reach': 3, 'sparser': 3}), (DecreaseAmount(AKT(), TNF()), {'reach': 4})],
#  ('AKT', 'FADD'): [(Inhibition(AKT(), FADD()), {'reach': 3}),
#   (IncreaseAmount(AKT(), FADD()), {'reach': 1})],
#  ('AKT',
#   'BAX'): [(Phosphorylation(AKT(), BAX()),
#    {'rlimsp': 5,
#     'reach': 45,
#     'sparser': 35,
#     'medscan': 2}), (Inhibition(AKT(), BAX()),
#    {'signor': 1,
#     'reach': 63,
#     'sparser': 10,
#     'medscan': 10}), (Activation(AKT(), BAX()),
#    {'signor': 1,
#     'reach': 43,
#     'sparser': 1,
#     'medscan': 4}), (Phosphorylation(AKT(), BAX(), S, 184),
#    {'rlimsp': 4,
#     'signor': 2,
#     'reach': 20,
#     'sparser': 16,
#     'medscan': 1}), (DecreaseAmount(AKT(), BAX()),
#    {'reach': 29, 'medscan': 2}), (IncreaseAmount(AKT(), BAX()),
#    {'isi': 5, 'reach': 17}), (Complex(AKT(), BAX()),
#    {'reach': 4,
#     'sparser': 6,
#     'medscan': 1}), (Dephosphorylation(AKT(), BAX(), S, 184),
#    {'reach': 2}), (Dephosphorylation(AKT(), BAX()), {'reach': 2})],
#  ('AKT',
#   'BAD'): [(Phosphorylation(AKT(), BAD()),
#    {'rlimsp': 14,
#     'reach': 269,
#     'sparser': 240,
#     'bel_lc': 1,
#     'trips': 2,
#     'medscan': 2}), (Phosphorylation(AKT(), BAD(), S, 99),
#    {'rlimsp': 6,
#     'signor': 2,
#     'reach': 121,
#     'pe': 1,
#     'sparser': 87}), (Inhibition(AKT(), BAD()),
#    {'signor': 4,
#     'reach': 87,
#     'sparser': 57,
#     'trips': 1}), (Activation(AKT(), BAD()),
#    {'reach': 42, 'sparser': 4}), (Complex(AKT(), BAD()),
#    {'reach': 6, 'conib': 1, 'sparser': 36}), (Dephosphorylation(AKT(), BAD()),
#    {'reach': 34, 'sparser': 1}), (Phosphorylation(AKT(), BAD(), S, 75),
#    {'rlimsp': 3,
#     'signor': 1,
#     'reach': 20,
#     'sparser': 4}), (Phosphorylation(AKT(), BAD(), S, 118),
#    {'signor': 1, 'reach': 7, 'sparser': 3}), (Phosphorylation(AKT(), BAD(), S),
#    {'reach': 7, 'sparser': 1, 'bel_lc': 1}), (DecreaseAmount(AKT(), BAD()),
#    {'reach': 6}), (Dephosphorylation(AKT(), BAD(), S, 99),
#    {'reach': 4}), (IncreaseAmount(AKT(), BAD()), {'reach': 2}), (Phosphorylation(AKT(), BAD(), T),
#    {'reach': 2}), (Inhibition(AKT(), BAD(), catalytic),
#    {'bel_lc': 1}), (Phosphorylation(AKT(), BAD(), 136), {'reach': 1}), (Ubiquitination(AKT(), BAD()),
#    {'reach': 1}), (Dephosphorylation(AKT(), BAD(), S, 75), {'reach': 1})],
#  ('AKT',
#   'BID'): [(Inhibition(AKT(), BID()),
#    {'reach': 13, 'sparser': 1, 'medscan': 4}), (Activation(AKT(), BID()),
#    {'reach': 11}), (DecreaseAmount(AKT(), BID()),
#    {'reach': 5}), (IncreaseAmount(AKT(), BID()), {'reach': 4}), (Phosphorylation(AKT(), BID()),
#    {'rlimsp': 1, 'reach': 1}), (Complex(AKT(), BID()), {'sparser': 1})],
#  ('AKT',
#   'apoptotic process'): [(Inhibition(AKT(), apoptotic process()),
#    {'eidos': 30,
#     'reach': 2271,
#     'sparser': 163,
#     'trips': 1,
#     'medscan': 105}), (Activation(AKT(), apoptotic process()),
#    {'eidos': 4, 'reach': 1163, 'sparser': 1, 'medscan': 53})],
#  ('Membrane protein',
#   'Protein 3a'): [(Complex(Membrane protein(), Protein 3a()), {'vhn': 2})]}

# %%
print('This data structure also allows us to tell that there are %s agent pairs in our statement set which is indicative of the size of the Boolean network we would generate.'
      % len(stmts_by_agent_pair))
# Out:
# This data structure also allows us to tell that there are 401 agent pairs in our statement set which is indicative of the size of the Boolean network we would generate.

# %% [markdown]
# Let's look at a specific agent pair example now of BBC3 and BCL2L1:

# %%
stmts_by_agent_pair[('BBC3', 'BCL2L1')]
# Out:
# [(Complex(BBC3(), BCL2L1()),
#   {'hprd': 3,
#    'signor': 1,
#    'reach': 61,
#    'biogrid': 5,
#    'sparser': 49,
#    'trips': 2,
#    'medscan': 15}),
#  (Inhibition(BBC3(), BCL2L1()),
#   {'signor': 1, 'reach': 8, 'sparser': 4, 'medscan': 4}),
#  (Activation(BBC3(), BCL2L1()), {'reach': 8, 'medscan': 5})]

# %% [markdown]
# What we see is the following:
# - `Complex`: many evidences including from curated databases and text mining that BBC3 and BCL2L1 bind to form a complex so this is pretty reliably true.
# - `Inhibition`: some text mining evidence, and from a curated pathway database (SIGNOR) that BBC3 inhibits BCL2L1.
# - `Activation`: interestingly, there is also some evidence that BBC3 activates BCL2L1
#
# How about we look up the evidence supporting the Activation statement? We can do this using the hash of the statement through the following link:

# %%
print('http://db.indra.bio/statements/from_hash/%s?format=html' %stmts_by_agent_pair[('BBC3', 'BCL2L1')][2][0].get_hash())
# Out:
# http://db.indra.bio/statements/from_hash/-5075052916332136?format=html

# %% [markdown]
# Here we see that these sentences are all misunderstood by the reading systems, and we can actually curate some of the evidences to mark them as incorrect. This will allow us to systematically filter them out. We can now fetch the body of curations collected in the INDRA DB and apply a filter to determine which statements can be thrown away as incorrect.

# %%
from indra.sources import indra_db_rest
from indra.tools import assemble_corpus as ac

# %%
curations = indra_db_rest.get_curations()
# Out:
# INFO: [2022-03-31 19:53:39] indra.sources.indra_db_rest.util - query: https://db.indra.bio/dev/curation/list
# INFO: [2022-03-31 19:53:39] indra.sources.indra_db_rest.util - params: {'api_key': '[api-key]'}
# INFO: [2022-03-31 19:53:39] indra.sources.indra_db_rest.util - data: None

# %%
stmts = ac.filter_by_curation(stmts, curations)
# Out:
# INFO: [2022-03-31 19:53:44] indra.tools.assemble_corpus - Filtering 1408 statements with any incorrect curations...
# INFO: [2022-03-31 19:53:44] indra.tools.assemble_corpus - 1400 statements after filter...

# %% [markdown]
# As we see above, by browsing the evidences and curating statements, we can systematically eliminate incorrect extractions if necessary.
#
# We can also apply some other heuristics for filtering statements if necessary. We can filter them by for instance the belief score, or more explicit criteria. For example, we could filter out
# - any statement that only has evidences from a single text mining system
# - is a Complex and only has evidence from Sparser (which tends to produce spurious complexes and if there is no support from other systems these are often incorrect)

# %%
from indra.sources import SOURCE_INFO
readers = {k for k, v in SOURCE_INFO.items() if v['type'] == 'reader'}

stmts = [stmt for stmt in stmts
         if not (
             len(source_counts_by_statement_hash[stmt.get_hash()]) == 1
             and set(source_counts_by_statement_hash[stmt.get_hash()]) < readers
            )
        ]
stmts = [stmt for stmt in stmts
         if not (isinstance(stmt, Complex) and
                 set(source_counts_by_statement_hash[stmt.get_hash()]) == {'sparser'}
                )
        ]

# %%
print('We are now left with %d statements' % len(stmts))
# Out:
# We are now left with 712 statements

# %% [markdown]
# Let's now get back to the issue of conflicting polarities, looking at a second example:

# %%
stmts_by_agent_pair = get_stmts_by_agent_pair(stmts, source_counts_by_statement_hash)

# %%
stmts_by_agent_pair[('FAS','CASP8')]
# Out:
# [(Activation(FAS(), CASP8()),
#   {'eidos': 3, 'reach': 334, 'sparser': 91, 'trips': 3, 'medscan': 35}),
#  (Complex(FAS(), CASP8()),
#   {'hprd': 2,
#    'reach': 37,
#    'biogrid': 7,
#    'sparser': 37,
#    'trips': 2,
#    'medscan': 20}),
#  (Inhibition(FAS(), CASP8()), {'reach': 29, 'medscan': 7}),
#  (IncreaseAmount(FAS(), CASP8()), {'isi': 1, 'reach': 8}),
#  (Activation(FAS(), CASP8(), catalytic), {'bel_lc': 4}),
#  (DecreaseAmount(FAS(), CASP8()), {'reach': 1, 'medscan': 1})]

# %% [markdown]
# In this case we see that Activation has significantly more evidence than the opposite Inhibition.

# %% [markdown]
# ### Resolving to a consensus polarity
# In general, a good heuristic could be to determine polarity of regulation as positive or negative if there is large difference between the evidences for each polarity. Let's attempt to use a simple heuristic to assign a "polarity score" to each agent pair as follows. We consider Activation and IncreaseAmount as full positive regulation, and Inhibition and DecreaseAmount as full negative regulation. Since modifications don't usually have a well determined effect on activity (phosphorylation can be both activating and inhibiting), we take them into account but with a lower weight, say 0.5. We don't score Complexes and other statement types with undetermined polarity.

# %%
from indra.statements import *

def polarity_score(stmt_tuples):
    score = 0
    total_evidence = 0
    for stmt, source_counts in stmt_tuples:
        ev_count = sum(source_counts.values())
        if isinstance(stmt, (Activation, IncreaseAmount)):
            score += ev_count
        elif isinstance(stmt, (Inhibition, DecreaseAmount)):
            score -= ev_count
        elif isinstance(stmt, Phosphorylation):
            score += 0.5*ev_count
        elif isinstance(stmt, Dephosphorylation):
            score -= 0.5*ev_count
        total_evidence += ev_count
    return score/total_evidence

# %%
polarity_scores = {agent_pair: polarity_score(stmt_tuples)
                   for agent_pair, stmt_tuples in stmts_by_agent_pair.items()}

# %% [markdown]
# We can now print the polarity scores in ranked order from "very positive" to "very negative".

# %%
for agent_pair, score in sorted(polarity_scores.items(), key=lambda x: x[1], reverse=True):
    print(agent_pair[0], agent_pair[1], score)
# Out:
# BBC3 CASP9 1.0
# BBC3 CASP3 1.0
# BBC3 BID 1.0
# CYCS AKT 1.0
# CYCS CASP7 1.0
# CYCS FAS 1.0
# CYCS apoptosome 1.0
# apoptotic process CYCS 1.0
# apoptotic process FASLG 1.0
# apoptotic process TNF 1.0
# FADD CASP9 1.0
# FADD TRADD 1.0
# FADD TNFRSF1A 1.0
# apoptosome CASP9 1.0
# apoptosome CASP3 1.0
# apoptosome apoptotic process 1.0
# MAPK14 BAX 1.0
# MCL1 AKT 1.0
# BAD CASP9 1.0
# BAD CASP3 1.0
# BAX BBC3 1.0
# BAX CASP8 1.0
# BAX CASP7 1.0
# BCL2 CASP7 1.0
# BCL2L1 MCL1 1.0
# BCL2L11 CYCS 1.0
# BCL2L11 CASP9 1.0
# BCL2L11 FAS 1.0
# BCL2L11 BID 1.0
# BID CYCS 1.0
# BID CASP7 1.0
# TNF BCL2L11 1.0
# TNF CASP7 1.0
# TNF CYCS 1.0
# TNF BBC3 1.0
# TNFRSF1A MAPK14 1.0
# TNFRSF1A CASP3 1.0
# FAS BAX 1.0
# FAS CYCS 1.0
# FAS CASP7 1.0
# FASLG BCL2L1 1.0
# FASLG CASP9 1.0
# FASLG TNFRSF1A 1.0
# FASLG TNF 1.0
# FASLG BID 1.0
# TRADD CASP3 1.0
# CASP3 BCL2L11 1.0
# CASP3 BAD 1.0
# CASP3 FADD 1.0
# CASP3 BBC3 1.0
# CASP3 TNF 1.0
# CASP3 BID 1.0
# CASP7 CASP3 1.0
# CASP8 CASP7 1.0
# CASP8 FASLG 1.0
# CASP8 CYCS 1.0
# CASP9 BCL2 1.0
# CASP9 FASLG 1.0
# CASP9 BID 1.0
# CASP9 apoptosome 1.0
# FASLG CASP3 0.9758064516129032
# CASP9 CASP7 0.9626168224299065
# TNF MAPK14 0.952054794520548
# TNF CASP8 0.946218487394958
# CASP9 CASP3 0.940974605353466
# CYCS CASP9 0.9349593495934959
# CASP8 CASP3 0.9315525876460768
# BID CASP9 0.9230769230769231
# CYCS CASP3 0.9059350503919373
# CASP8 BID 0.8983833718244804
# FAS apoptotic process 0.8810128009924999
# BCL2L11 BAX 0.8674698795180723
# FASLG apoptotic process 0.8672032193158954
# CASP3 CASP8 0.852760736196319
# TNF apoptotic process 0.8324873096446701
# TNF FADD 0.8235294117647058
# FASLG CASP8 0.8222222222222222
# CYCS apoptotic process 0.8184300341296928
# FAS AKT 0.8157894736842105
# FADD CASP8 0.8151815181518152
# FASLG FAS 0.802013422818792
# TNFRSF1A CASP8 0.7954545454545454
# TNF CASP3 0.7906976744186046
# TNF FAS 0.7787356321839081
# CASP9 BBC3 0.7777777777777778
# BID apoptotic process 0.7757352941176471
# CASP8 BAX 0.7678571428571429
# TNFRSF1A apoptotic process 0.7662337662337663
# TNF CASP9 0.7619047619047619
# BAX CYCS 0.7577045696068013
# TNF BAX 0.7575757575757576
# CASP3 FASLG 0.75
# TNF AKT 0.7434402332361516
# FAS TNF 0.7333333333333333
# FAS CASP9 0.7272727272727273
# BAX apoptotic process 0.7248628884826326
# CASP3 apoptotic process 0.7248596222562532
# CASP8 apoptotic process 0.7161862527716186
# FAS TNFRSF1A 0.7142857142857143
# FAS CASP8 0.7090032154340836
# BBC3 apoptotic process 0.705186533212011
# TNF BID 0.7037037037037037
# CASP3 FAS 0.6875
# CASP9 CASP8 0.6808510638297872
# CASP7 apoptotic process 0.6756756756756757
# TRADD apoptotic process 0.674074074074074
# CYCS BAD 0.6666666666666666
# FAS CASP3 0.6586345381526104
# CASP8 CASP9 0.6447876447876448
# FAS BCL2L1 0.6363636363636364
# BCL2L11 apoptotic process 0.6360052562417872
# BBC3 BAX 0.6354916067146283
# BID FASLG 0.625
# BAX BID 0.6190476190476191
# TRADD TNFRSF1A 0.6190476190476191
# CASP9 apoptotic process 0.615678776290631
# FADD apoptotic process 0.6124721603563474
# CASP8 TNF 0.6086956521739131
# BID CASP3 0.6078431372549019
# FADD CASP3 0.6
# BID BAX 0.5930851063829787
# CASP8 FAS 0.582089552238806
# apoptotic process CASP8 0.5806451612903226
# FADD FAS 0.5714285714285714
# apoptotic process CASP3 0.5703703703703704
# AKT BCL2L1 0.5625
# BAD BAX 0.5544554455445545
# BAX CASP3 0.550561797752809
# BAX CASP9 0.5491329479768786
# TNFRSF1A TNF 0.5013262599469496
# BCL2 FASLG 0.5
# CASP9 BAD 0.5
# BAD apoptotic process 0.4952919020715631
# BCL2 AKT 0.49514563106796117
# FAS BID 0.48717948717948717
# TRADD CASP8 0.4852941176470588
# CASP3 CYCS 0.48514851485148514
# AKT TNF 0.4793388429752066
# AKT BCL2 0.4647727272727273
# MAPK14 apoptotic process 0.4594594594594595
# BAX FAS 0.45454545454545453
# CYCS BAX 0.45161290322580644
# BID CASP8 0.4421052631578947
# BCL2L11 CASP3 0.43283582089552236
# CASP3 BAX 0.43162393162393164
# CASP9 BAX 0.4186046511627907
# MAPK14 BCL2L1 0.4166666666666667
# TNF TRADD 0.4057971014492754
# FAS BCL2L11 0.4
# FASLG FADD 0.4
# FASLG AKT 0.391304347826087
# FADD BID 0.38461538461538464
# MAPK14 CASP3 0.36666666666666664
# MAPK14 AKT 0.3333333333333333
# CASP8 TNFRSF1A 0.3333333333333333
# CASP3 BCL2L1 0.3142857142857143
# TNF FASLG 0.3092369477911647
# CASP3 CASP9 0.3002832861189802
# BID FAS 0.2777777777777778
# CASP7 CASP8 0.2727272727272727
# CASP8 BCL2 0.2608695652173913
# AKT BAD 0.25773195876288657
# TNF BAD 0.25
# TNF TNFRSF1A 0.24307692307692308
# CASP3 CASP7 0.24096385542168675
# TNF BCL2 0.23711340206185566
# AKT MCL1 0.234375
# BCL2L1 AKT 0.23076923076923078
# TNFRSF1A FAS 0.17647058823529413
# BID BAD 0.16
# BAX MCL1 0.15384615384615385
# MAPK14 TNF 0.14285714285714285
# CASP9 CYCS 0.125
# BBC3 BCL2L11 0.11428571428571428
# BAX BCL2L11 0.09130434782608696
# FAS FADD 0.07685512367491167
# CASP3 AKT 0.06944444444444445
# AKT BAX 0.06422018348623854
# TNFRSF1A TRADD 0.057692307692307696
# MAPK14 BCL2 0.05555555555555555
# BCL2 BAD 0.05128205128205128
# CASP3 MCL1 0.04
# TRADD FADD 0.037914691943127965
# TNF BCL2L1 0.03225806451612903
# TNFRSF1A FADD 0.021739130434782608
# CASP8 FADD 0.01989389920424403
# BAD AKT 0.017857142857142856
# FAS FASLG 0.016781609195402298
# CASP3 BCL2 0.007177033492822967
# AKT CASP9 0.006578947368421052
# BBC3 BAD 0.0
# CYCS MCL1 0.0
# MCL1 BAD 0.0
# BAD BCL2L11 0.0
# BAX BAD 0.0
# BCL2L1 Envelope small membrane protein 0.0
# BCL2L11 BBC3 0.0
# BID FADD 0.0
# BID TNFRSF1A 0.0
# BID BCL2L11 0.0
# TNFRSF1A CASP7 0.0
# TNFRSF1A FASLG 0.0
# FAS TRADD 0.0
# CASP3 MAPK14 0.0
# CASP7 BAX 0.0
# CASP7 CASP9 0.0
# CASP9 BCL2L11 0.0
# Membrane protein Protein 3a 0.0
# BBC3 MCL1 -0.012121212121212121
# BCL2 CASP9 -0.012254901960784314
# BCL2 BCL2L1 -0.018229166666666668
# MCL1 BCL2L1 -0.02262443438914027
# BCL2 MCL1 -0.028735632183908046
# BID BCL2 -0.03289473684210526
# BAX BCL2L1 -0.03296703296703297
# BCL2 BCL2L11 -0.03542673107890499
# BID MCL1 -0.04285714285714286
# BID BCL2L1 -0.045871559633027525
# BCL2L1 BCL2L11 -0.051515151515151514
# BAX BCL2 -0.05553359683794466
# MCL1 BCL2L11 -0.06951871657754011
# CYCS BCL2 -0.06976744186046512
# BCL2 BBC3 -0.08333333333333333
# MCL1 BCL2 -0.09210526315789473
# MAPK14 CASP8 -0.1
# BBC3 BCL2L1 -0.1111111111111111
# BAD BCL2 -0.1181592039800995
# BBC3 BCL2 -0.12236286919831224
# BAD BCL2L1 -0.1242603550295858
# CASP9 BCL2L1 -0.13793103448275862
# FAS BCL2 -0.16279069767441862
# BAD MCL1 -0.16666666666666666
# AKT BCL2L11 -0.17132867132867133
# BCL2 CASP3 -0.17954220314735336
# AKT CASP3 -0.18992248062015504
# MCL1 BBC3 -0.2
# CASP9 FAS -0.2
# BCL2 BAX -0.20246478873239437
# BCL2L1 BCL2 -0.20408163265306123
# AKT FASLG -0.2222222222222222
# BCL2L11 MCL1 -0.22727272727272727
# MCL1 apoptotic process -0.2300469483568075
# AKT FAS -0.23333333333333334
# CYCS BCL2L1 -0.2413793103448276
# BCL2L11 AKT -0.25
# BID BBC3 -0.25
# CASP8 BCL2L1 -0.25
# MCL1 CASP3 -0.2558139534883721
# MCL1 BAX -0.284
# BCL2L1 FAS -0.30434782608695654
# BCL2L1 BAD -0.3333333333333333
# BCL2L11 BCL2 -0.35251798561151076
# AKT apoptotic process -0.35584278554471116
# BCL2 apoptotic process -0.3729893123178236
# BCL2 CASP8 -0.40350877192982454
# BCL2L1 BID -0.4117647058823529
# BCL2L1 apoptotic process -0.4421768707482993
# AKT CASP8 -0.4444444444444444
# BCL2L1 CASP3 -0.4857142857142857
# BCL2L1 BAX -0.48704663212435234
# AKT BBC3 -0.5862068965517241
# BCL2L1 CASP9 -0.6
# BID TNF -0.6
# BCL2 TNF -0.6129032258064516
# BCL2L11 BCL2L1 -0.6326530612244898
# BCL2 FAS -0.76
# AKT BID -0.85
# BCL2 CYCS -0.9596273291925466
# apoptotic process BCL2 -1.0
# FADD BCL2 -1.0
# MCL1 CASP9 -1.0
# MCL1 CASP8 -1.0
# MCL1 BID -1.0
# BAX AKT -1.0
# BCL2 BID -1.0
# BCL2L1 FADD -1.0
# BCL2L1 CYCS -1.0
# BCL2L1 BBC3 -1.0
# BCL2L1 CASP8 -1.0
# BCL2L1 TNF -1.0
# BCL2L11 BAD -1.0
# BCL2L11 TNF -1.0
# FASLG BCL2 -1.0
# CASP7 BCL2 -1.0
# CASP8 MCL1 -1.0
# CASP9 MCL1 -1.0
# AKT MAPK14 -1.0

# %% [markdown]
# This score could be the basis of filtering or parameterization for constructing the Boolean model. For simplicity, let's apply the heuristic that we take all polarity scores >= 0 as positive and all < 0 as negative to create the following SIF dump for Boolean modeling.

# %%
for agent_pair, score in sorted(polarity_scores.items(), key=lambda x: x[1], reverse=True):
    print('%s,%s,%s' % (agent_pair[0], (1 if score >= 0 else -1), agent_pair[1]))
# Out:
# BBC3,1,CASP9
# BBC3,1,CASP3
# BBC3,1,BID
# CYCS,1,AKT
# CYCS,1,CASP7
# CYCS,1,FAS
# CYCS,1,apoptosome
# apoptotic process,1,CYCS
# apoptotic process,1,FASLG
# apoptotic process,1,TNF
# FADD,1,CASP9
# FADD,1,TRADD
# FADD,1,TNFRSF1A
# apoptosome,1,CASP9
# apoptosome,1,CASP3
# apoptosome,1,apoptotic process
# MAPK14,1,BAX
# MCL1,1,AKT
# BAD,1,CASP9
# BAD,1,CASP3
# BAX,1,BBC3
# BAX,1,CASP8
# BAX,1,CASP7
# BCL2,1,CASP7
# BCL2L1,1,MCL1
# BCL2L11,1,CYCS
# BCL2L11,1,CASP9
# BCL2L11,1,FAS
# BCL2L11,1,BID
# BID,1,CYCS
# BID,1,CASP7
# TNF,1,BCL2L11
# TNF,1,CASP7
# TNF,1,CYCS
# TNF,1,BBC3
# TNFRSF1A,1,MAPK14
# TNFRSF1A,1,CASP3
# FAS,1,BAX
# FAS,1,CYCS
# FAS,1,CASP7
# FASLG,1,BCL2L1
# FASLG,1,CASP9
# FASLG,1,TNFRSF1A
# FASLG,1,TNF
# FASLG,1,BID
# TRADD,1,CASP3
# CASP3,1,BCL2L11
# CASP3,1,BAD
# CASP3,1,FADD
# CASP3,1,BBC3
# CASP3,1,TNF
# CASP3,1,BID
# CASP7,1,CASP3
# CASP8,1,CASP7
# CASP8,1,FASLG
# CASP8,1,CYCS
# CASP9,1,BCL2
# CASP9,1,FASLG
# CASP9,1,BID
# CASP9,1,apoptosome
# FASLG,1,CASP3
# CASP9,1,CASP7
# TNF,1,MAPK14
# TNF,1,CASP8
# CASP9,1,CASP3
# CYCS,1,CASP9
# CASP8,1,CASP3
# BID,1,CASP9
# CYCS,1,CASP3
# CASP8,1,BID
# FAS,1,apoptotic process
# BCL2L11,1,BAX
# FASLG,1,apoptotic process
# CASP3,1,CASP8
# TNF,1,apoptotic process
# TNF,1,FADD
# FASLG,1,CASP8
# CYCS,1,apoptotic process
# FAS,1,AKT
# FADD,1,CASP8
# FASLG,1,FAS
# TNFRSF1A,1,CASP8
# TNF,1,CASP3
# TNF,1,FAS
# CASP9,1,BBC3
# BID,1,apoptotic process
# CASP8,1,BAX
# TNFRSF1A,1,apoptotic process
# TNF,1,CASP9
# BAX,1,CYCS
# TNF,1,BAX
# CASP3,1,FASLG
# TNF,1,AKT
# FAS,1,TNF
# FAS,1,CASP9
# BAX,1,apoptotic process
# CASP3,1,apoptotic process
# CASP8,1,apoptotic process
# FAS,1,TNFRSF1A
# FAS,1,CASP8
# BBC3,1,apoptotic process
# TNF,1,BID
# CASP3,1,FAS
# CASP9,1,CASP8
# CASP7,1,apoptotic process
# TRADD,1,apoptotic process
# CYCS,1,BAD
# FAS,1,CASP3
# CASP8,1,CASP9
# FAS,1,BCL2L1
# BCL2L11,1,apoptotic process
# BBC3,1,BAX
# BID,1,FASLG
# BAX,1,BID
# TRADD,1,TNFRSF1A
# CASP9,1,apoptotic process
# FADD,1,apoptotic process
# CASP8,1,TNF
# BID,1,CASP3
# FADD,1,CASP3
# BID,1,BAX
# CASP8,1,FAS
# apoptotic process,1,CASP8
# FADD,1,FAS
# apoptotic process,1,CASP3
# AKT,1,BCL2L1
# BAD,1,BAX
# BAX,1,CASP3
# BAX,1,CASP9
# TNFRSF1A,1,TNF
# BCL2,1,FASLG
# CASP9,1,BAD
# BAD,1,apoptotic process
# BCL2,1,AKT
# FAS,1,BID
# TRADD,1,CASP8
# CASP3,1,CYCS
# AKT,1,TNF
# AKT,1,BCL2
# MAPK14,1,apoptotic process
# BAX,1,FAS
# CYCS,1,BAX
# BID,1,CASP8
# BCL2L11,1,CASP3
# CASP3,1,BAX
# CASP9,1,BAX
# MAPK14,1,BCL2L1
# TNF,1,TRADD
# FAS,1,BCL2L11
# FASLG,1,FADD
# FASLG,1,AKT
# FADD,1,BID
# MAPK14,1,CASP3
# MAPK14,1,AKT
# CASP8,1,TNFRSF1A
# CASP3,1,BCL2L1
# TNF,1,FASLG
# CASP3,1,CASP9
# BID,1,FAS
# CASP7,1,CASP8
# CASP8,1,BCL2
# AKT,1,BAD
# TNF,1,BAD
# TNF,1,TNFRSF1A
# CASP3,1,CASP7
# TNF,1,BCL2
# AKT,1,MCL1
# BCL2L1,1,AKT
# TNFRSF1A,1,FAS
# BID,1,BAD
# BAX,1,MCL1
# MAPK14,1,TNF
# CASP9,1,CYCS
# BBC3,1,BCL2L11
# BAX,1,BCL2L11
# FAS,1,FADD
# CASP3,1,AKT
# AKT,1,BAX
# TNFRSF1A,1,TRADD
# MAPK14,1,BCL2
# BCL2,1,BAD
# CASP3,1,MCL1
# TRADD,1,FADD
# TNF,1,BCL2L1
# TNFRSF1A,1,FADD
# CASP8,1,FADD
# BAD,1,AKT
# FAS,1,FASLG
# CASP3,1,BCL2
# AKT,1,CASP9
# BBC3,1,BAD
# CYCS,1,MCL1
# MCL1,1,BAD
# BAD,1,BCL2L11
# BAX,1,BAD
# BCL2L1,1,Envelope small membrane protein
# BCL2L11,1,BBC3
# BID,1,FADD
# BID,1,TNFRSF1A
# BID,1,BCL2L11
# TNFRSF1A,1,CASP7
# TNFRSF1A,1,FASLG
# FAS,1,TRADD
# CASP3,1,MAPK14
# CASP7,1,BAX
# CASP7,1,CASP9
# CASP9,1,BCL2L11
# Membrane protein,1,Protein 3a
# BBC3,-1,MCL1
# BCL2,-1,CASP9
# BCL2,-1,BCL2L1
# MCL1,-1,BCL2L1
# BCL2,-1,MCL1
# BID,-1,BCL2
# BAX,-1,BCL2L1
# BCL2,-1,BCL2L11
# BID,-1,MCL1
# BID,-1,BCL2L1
# BCL2L1,-1,BCL2L11
# BAX,-1,BCL2
# MCL1,-1,BCL2L11
# CYCS,-1,BCL2
# BCL2,-1,BBC3
# MCL1,-1,BCL2
# MAPK14,-1,CASP8
# BBC3,-1,BCL2L1
# BAD,-1,BCL2
# BBC3,-1,BCL2
# BAD,-1,BCL2L1
# CASP9,-1,BCL2L1
# FAS,-1,BCL2
# BAD,-1,MCL1
# AKT,-1,BCL2L11
# BCL2,-1,CASP3
# AKT,-1,CASP3
# MCL1,-1,BBC3
# CASP9,-1,FAS
# BCL2,-1,BAX
# BCL2L1,-1,BCL2
# AKT,-1,FASLG
# BCL2L11,-1,MCL1
# MCL1,-1,apoptotic process
# AKT,-1,FAS
# CYCS,-1,BCL2L1
# BCL2L11,-1,AKT
# BID,-1,BBC3
# CASP8,-1,BCL2L1
# MCL1,-1,CASP3
# MCL1,-1,BAX
# BCL2L1,-1,FAS
# BCL2L1,-1,BAD
# BCL2L11,-1,BCL2
# AKT,-1,apoptotic process
# BCL2,-1,apoptotic process
# BCL2,-1,CASP8
# BCL2L1,-1,BID
# BCL2L1,-1,apoptotic process
# AKT,-1,CASP8
# BCL2L1,-1,CASP3
# BCL2L1,-1,BAX
# AKT,-1,BBC3
# BCL2L1,-1,CASP9
# BID,-1,TNF
# BCL2,-1,TNF
# BCL2L11,-1,BCL2L1
# BCL2,-1,FAS
# AKT,-1,BID
# BCL2,-1,CYCS
# apoptotic process,-1,BCL2
# FADD,-1,BCL2
# MCL1,-1,CASP9
# MCL1,-1,CASP8
# MCL1,-1,BID
# BAX,-1,AKT
# BCL2,-1,BID
# BCL2L1,-1,FADD
# BCL2L1,-1,CYCS
# BCL2L1,-1,BBC3
# BCL2L1,-1,CASP8
# BCL2L1,-1,TNF
# BCL2L11,-1,BAD
# BCL2L11,-1,TNF
# FASLG,-1,BCL2
# CASP7,-1,BCL2
# CASP8,-1,MCL1
# CASP9,-1,MCL1
# AKT,-1,MAPK14

# %% [markdown]
# The above could be the prior network structure for a Boolean model.
