# %%
"""Find paths explaining connections between phenotypes and their nearest genes.

METSIM Metabolomics PheWeb
https://pheweb.org/metsim-metab/
"""

import pandas as pd

import gilda
from indra.databases import hgnc_client
import bioregistry

URL = "https://pheweb.org/metsim-metab/download/phenotypes.tsv"

COLUMNS = {
    "chrom": "chromosome",
    "pos": "position",
    "ref": "reference_allele",
    "alt": "alternative_allele",
    "rsids": "dbsnp_ids",  # comma separated
    "nearest_genes": "nearest_gene_symbols",  # comma separated
    "pval": "p_value",
    "num_peaks": "number_peaks",
    "phenocode": "identifier",  # this is the primary identifier, e.g., C100001054
    "category": "category",
    "phenostring": "label",  # this is the label for the entry, e.g., butyrylcarnitine (C4)
}

NOTED_MISSING = set()

def _norm_genes(symbols):
    rv = []
    for symbol in symbols:
        hgnc_id = hgnc_client.get_current_hgnc_id(symbol)
        if hgnc_id is None:
            if symbol not in NOTED_MISSING:
                print(f"could not look up HGNC id for {symbol}")
                NOTED_MISSING.add(symbol)
            continue
        rv.append(hgnc_id)
    return rv

df = pd.read_csv(URL, sep="\t").rename(columns=COLUMNS)
df = df[df.category != "Uncharacterized"]
df = df[["identifier", "label", "category", "dbsnp_ids", "nearest_gene_symbols"]]
for column in "dbsnp_ids", "nearest_gene_symbols":
    df[column] = df[column].map(lambda s: s.split(",") if pd.notna(s) else [])
df["nearest_gene_ids"] = df["nearest_gene_symbols"].map(_norm_genes)
del df["nearest_gene_symbols"]
df.head()
# Out:
# could not look up HGNC id for AC068946.1
# could not look up HGNC id for AC007326.4
# could not look up HGNC id for AC008012.1
# could not look up HGNC id for AP000356.5
# could not look up HGNC id for AL360181.3
# could not look up HGNC id for AL022238.3
# could not look up HGNC id for AC020765.6
# could not look up HGNC id for AC097104.1
# could not look up HGNC id for AC004832.3
# could not look up HGNC id for AL583836.1
# could not look up HGNC id for AC008537.1
# could not look up HGNC id for AL355312.5
# could not look up HGNC id for AL355315.1
# could not look up HGNC id for AC027644.4
# could not look up HGNC id for FO393400.1
# could not look up HGNC id for AC069288.1
# could not look up HGNC id for AC008695.1
# could not look up HGNC id for AC007375.2
# could not look up HGNC id for AL162596.1
# could not look up HGNC id for AC010197.2
#    identifier                                       label     category  \
# 0  C100001054                       butyrylcarnitine (C4)        Lipid
# 1  C100001104                            N-acetyltyrosine   Amino_Acid
# 2  C100001253                           N-acetylglutamine   Amino_Acid
# 3  C100001266                            N-acetylarginine   Amino_Acid
# 4  C100001402  5-acetylamino-6-formylamino-3-methyluracil  Xenobiotics
#
#                     dbsnp_ids nearest_gene_ids
# 0                 [rs2066938]          [16488]
# 1                 [rs6546861]            [428]
# 2                [rs10207220]            [428]
# 3  [rs142350660, rs376360741]            [428]
# 4                [rs34370554]           [7646]

# %%
def ground(t):
    t = t.rstrip("*")
    for i in range(5):
        t = t.removesuffix(f" ({i})")

    # could do additional string processing for examples like:
    #  - (14 or 15)-methylpalmitate (a17:0 or i17:0)
    
    x = gilda.ground(t)
    if x:
        term = x[0].term
        return term.db, term.id, term.entry_name
    
    if t.endswith("ate"):
        new_t = t[:-len("ate")] + "ic acid"
        x = gilda.ground(new_t)
        if x:
            term = x[0].term
            return term.db, term.id, term.entry_name
        
    if t.endswith(" sulfate"):
        new_t = t.removesuffix(" sulfate")
        x = gilda.ground(new_t)
        if x:
            term = x[0].term
            return term.db, term.id, term.entry_name

    return None

df["grounding"] = df.label.map(ground)
grounding_idx = df["grounding"].notna()
print(f"successfully grounded {grounding_idx.sum()} rows")
grounded_df = df[grounding_idx]
grounded_df.head()
# Out:
# successfully grounded 597 rows
#    identifier                                       label     category  \
# 1  C100001104                            N-acetyltyrosine   Amino_Acid
# 2  C100001253                           N-acetylglutamine   Amino_Acid
# 4  C100001402  5-acetylamino-6-formylamino-3-methyluracil  Xenobiotics
# 5  C100001466                            3-methylcytidine   Nucleotide
# 6  C100001577                          N-acetylcitrulline   Amino_Acid
#
#       dbsnp_ids nearest_gene_ids  \
# 1   [rs6546861]            [428]
# 2  [rs10207220]            [428]
# 4  [rs34370554]           [7646]
# 5  [rs17385861]          [29253]
# 6  [rs10168931]          [18069]
#
#                                            grounding
# 1             (CHEBI, CHEBI:68561, N-acetyltyrosine)
# 2                      (MESH, C032007, aceglutamide)
# 4  (MESH, C036692, 5-acetylamino-6-formylamino-3-...
# 5             (CHEBI, CHEBI:20129, 3-methylcytidine)
# 6           (CHEBI, CHEBI:49006, N-acetylcitrulline)

# %%
for label in sorted(df[~grounding_idx].label):
    print(label)
# Out:
# (14 or 15)-methylpalmitate (a17:0 or i17:0)
# (16 or 17)-methylstearate (a19:0 or i19:0)
# (2 or 3)-decenoate (10:1n7 or n8)
# (2,4 or 2,5)-dimethylphenol sulfate
# (N(1) + N(8))-acetylspermidine
# (S)-3-hydroxybutyrylcarnitine
# (S)-a-amino-omega-caprolactam
# 1,2-dilinoleoyl-GPC (18:2/18:2)
# 1,2-dipalmitoyl-GPC (16:0/16:0)
# 1,2-distearoyl-GPC (18:0/18:0)
# 1,5-anhydroglucitol (1,5-AG)
# 1-(1-enyl-oleoyl)-2-docosahexaenoyl-GPE (P-18:1/22:6)*
# 1-(1-enyl-oleoyl)-GPE (P-18:1)*
# 1-(1-enyl-palmitoyl)-2-oleoyl-GPC (P-16:0/18:1)*
# 1-(1-enyl-palmitoyl)-2-oleoyl-GPE (P-16:0/18:1)*
# 1-(1-enyl-palmitoyl)-GPC (P-16:0)*
# 1-(1-enyl-stearoyl)-2-arachidonoyl-GPC (P-18:0/20:4)
# 1-(1-enyl-stearoyl)-2-arachidonoyl-GPE (P-18:0/20:4)*
# 1-(1-enyl-stearoyl)-2-docosahexaenoyl-GPE (P-18:0/22:6)*
# 1-(1-enyl-stearoyl)-2-oleoyl-GPE (P-18:0/18:1)
# 1-arachidonoyl-GPC (20:4n6)*
# 1-arachidonoyl-GPE (20:4n6)*
# 1-arachidonylglycerol (20:4)
# 1-carboxyethylisoleucine
# 1-carboxyethylleucine
# 1-carboxyethylphenylalanine
# 1-carboxyethyltyrosine
# 1-carboxyethylvaline
# 1-dihomo-linolenoyl-GPC (20:3n3 or 6)*
# 1-dihomo-linolenoyl-GPE (20:3n3 or 6)*
# 1-dihomo-linolenylglycerol (20:3)
# 1-dihomo-linoleoylglycerol (20:2)
# 1-docosahexaenoyl-GPC (22:6)*
# 1-docosahexaenoylglycerol (22:6)
# 1-erucoyl-GPC (22:1)*
# 1-linolenoyl-GPE (18:3)*
# 1-linolenoylglycerol (18:3)
# 1-linoleoyl-2-docosapentaenyol-GPC (18:2/22:5n3)*
# 1-linoleoyl-2-linolenoyl-GPC (18:2/18:3)*
# 1-linoleoyl-GPG (18:2)*
# 1-linoleoylglycerol (18:2)
# 1-margaroyl-2-docosahexaenoyl-GPC (17:0/22:6)*
# 1-margaroyl-2-oleoyl-GPC (17:0/18:1)*
# 1-margaroyl-GPE (17:0)*
# 1-meadoyl-GPC (20:3n9)*
# 1-myristoyl-2-arachidonoyl-GPC (14:0/20:4)*
# 1-myristoyl-2-docosahexaenoyl-GPC (14:0/22:6)*
# 1-myristoyl-2-eicosapentaenoyl-GPC (14:0/20:5)*
# 1-myristoyl-2-linoleoyl-GPC (14:0/18:2)*
# 1-myristoyl-GPC (14:0)
# 1-myristoylglycerol (14:0)
# 1-nonadecenoyl-GPC (19:1)*
# 1-oleoyl-2-arachidonoyl-GPE (18:1/20:4)*
# 1-oleoyl-2-docosahexaenoyl-GPE (18:1/22:6)*
# 1-oleoyl-2-docosapentaenoyl-GPC (18:1/22:5n3)*
# 1-oleoyl-2-eicosapentaenoyl-GPC (18:1/20:5)*
# 1-oleoyl-GPC (18:1)
# 1-oleoyl-GPE (18:1)
# 1-oleoyl-GPG (18:1)*
# 1-oleoyl-GPS (18:1)
# 1-oleoylglycerol (18:1)
# 1-palmitoleoyl-2-linolenoyl-GPC (16:1/18:3)*
# 1-palmitoleoyl-2-linoleoyl-GPC (16:1/18:2)*
# 1-palmitoleoyl-GPC (16:1)*
# 1-palmitoleoyl-GPE (16:1)*
# 1-palmitoleoyl-GPI (16:1)*
# 1-palmitoleoylglycerol (16:1)*
# 1-palmitoyl-2-adrenoyl-GPC (16:0/22:4)*
# 1-palmitoyl-2-alpha-linolenoyl-GPC (16:0/18:3n3)*
# 1-palmitoyl-2-arachidonoyl-GPC (16:0/20:4n6)
# 1-palmitoyl-2-dihomo-linolenoyl-GPC (16:0/20:3n3 or 6)*
# 1-palmitoyl-2-oleoyl-GPE (16:0/18:1)
# 1-palmitoyl-2-palmitoleoyl-GPE (16:0/16:1)*
# 1-palmitoyl-2-pentadecanoyl-GPC (16:0/15:0)*
# 1-palmitoyl-GPG (16:0)*
# 1-palmitoylglycerol (16:0)
# 1-palmityl-2-arachidonoyl-GPC (O-16:0/20:4)*
# 1-palmityl-2-palmitoyl-GPC (O-16:0/16:0)*
# 1-palmityl-GPC (O-16:0)
# 1-palmityl-GPE (O-16:0)*
# 1-pentadecanoyl-2-arachidonoyl-GPC (15:0/20:4)*
# 1-pentadecanoyl-2-docosahexaenoyl-GPC (15:0/22:6)*
# 1-pentadecanoyl-GPC (15:0)*
# 1-ribosyl-imidazoleacetate*
# 1-stearoyl-2-adrenoyl-GPC (18:0/22:4)*
# 1-stearoyl-2-arachidonoyl-GPS (18:0/20:4)
# 1-stearoyl-2-dihomo-linolenoyl-GPC (18:0/20:3n3 or 6)*
# 1-stearoyl-2-docosapentaenoyl-GPC (18:0/22:5n3)*
# 1-stearoyl-2-docosapentaenoyl-GPC (18:0/22:5n6)*
# 1-stearoyl-2-linoleoyl-GPE (18:0/18:2)*
# 1-stearoyl-2-linoleoyl-GPI (18:0/18:2)
# 1-stearoyl-2-oleoyl-GPI (18:0/18:1)*
# 1-stearoyl-2-oleoyl-GPS (18:0/18:1)
# 1-stearoyl-GPC (18:0)
# 1-stearoyl-GPE (18:0)
# 1-stearoyl-GPG (18:0)
# 1-stearoyl-GPI (18:0)
# 1-stearoyl-GPS (18:0)*
# 10-heptadecenoate (17:1n7)
# 10-nonadecenoate (19:1n9)
# 10-undecenoate (11:1n1)
# 11-ketoetiocholanolone glucuronide
# 11beta-hydroxyandrosterone glucuronide
# 13-HODE + 9-HODE
# 17alpha-hydroxypregnanolone glucuronide
# 17alpha-hydroxypregnenolone 3-sulfate
# 2,3-dihydroxy-5-methylthio-4-pentenoate (DMTPA)*
# 2-arachidonoyl-GPC (20:4)*
# 2-arachidonoyl-GPE (20:4)*
# 2-arachidonoylglycerol (20:4)
# 2-docosahexaenoyl-GPE (22:6)*
# 2-hydroxybutyrate/2-hydroxyisobutyrate
# 2-hydroxyhippurate (salicylurate)
# 2-ketocaprylate
# 2-linoleoyl-GPC (18:2)*
# 2-linoleoyl-GPE (18:2)*
# 2-linoleoylglycerol (18:2)
# 2-methoxyhydroquinone glucuronide (2)
# 2-methylbutyrylcarnitine (C5)
# 2-methylcitrate/homocitrate
# 2-methylmalonylcarnitine (C4-DC)
# 2-myristoyl-GPC (14:0)*
# 2-oleoyl-GPC (18:1)*
# 2-oleoyl-GPE (18:1)*
# 2-oleoylglycerol (18:1)
# 2-palmitoleoylglycerol (16:1)*
# 2-palmitoyl-GPC (16:0)*
# 2-palmitoylglycerol (16:0)
# 2-stearoyl-GPI (18:0)*
# 2R,3R-dihydroxybutyrate
# 2S,3R-dihydroxybutyrate
# 3,4-methyleneheptanoate
# 3,5-dichloro-2,6-dihydroxybenzoic acid
# 3-(methylthio)acetaminophen sulfate*
# 3-acetylphenol sulfate
# 3-bromo-5-chloro-2,6-dihydroxybenzoic acid*
# 3-carboxy-4-methyl-5-pentyl-2-furanpropionate (3-CMPFP)**
# 3-carboxy-4-methyl-5-propyl-2-furanpropanoate (CMPF)
# 3-decenoylcarnitine
# 3-ethylphenylsulfate
# 3-hydroxy-2-methylpyridine sulfate
# 3-hydroxybutyrate (BHBA)
# 3-hydroxybutyroylglycine**
# 3-hydroxyhexanoylcarnitine (1)
# 3-hydroxyhexanoylcarnitine (2)
# 3-hydroxyoleate*
# 3-hydroxypyridine glucuronide
# 3-indoleglyoxylic acid
# 3-methyl catechol sulfate (1)
# 3-methyl catechol sulfate (2)
# 3-phenylpropionate (hydrocinnamate)
# 4-acetamidophenylglucuronide
# 4-acetylcatechol sulfate (1)
# 4-acetylcatechol sulfate (2)
# 4-ethylphenylsulfate
# 4-hydroxyglutamate
# 4-hydroxyphenylacetylglutamine
# 4-methylhexanoylglutamine
# 5-(galactosylhydroxy)-L-lysine
# 5-dodecenoate (12:1n7)
# 5-dodecenoylcarnitine (C12:1)
# 5-hydroxy-2-methylpyridine sulfate
# 5-hydroxyindole glucuronide
# 5-hydroxymethyl-2-furoylcarnitine*
# 5-methylthioadenosine (MTA)
# 5-methyluridine (ribothymidine)
# 5alpha-androstan-3alpha,17alpha-diol monosulfate
# 5alpha-androstan-3alpha,17beta-diol 17-glucuronide
# 5alpha-androstan-3beta,17beta-diol monosulfate (1)
# 5alpha-androstan-3beta,17beta-diol monosulfate (2)
# 5alpha-pregnan-3beta,20alpha-diol monosulfate (2)
# 5alpha-pregnan-3beta,20beta-diol monosulfate (1)
# 5alpha-pregnan-diol disulfate
# 7-alpha-hydroxy-3-oxo-4-cholestenoate (7-Hoca)
# GlcNAc sulfate conjugate of C21H34O2 steroid**
# HWESASLLR
# HWESASXX*
# N,N,N-trimethyl-5-aminovalerate
# N,N,N-trimethyl-alanylproline betaine (TMAP)
# N-acetyl-4-chlorophenylalanine
# N-acetyl-aspartyl-glutamate (NAAG)
# N-acetylarginine
# N-acetylaspartate (NAA)
# N-acetylglucosamine/N-acetylgalactosamine
# N-alpha-acetylornithine
# N-behenoyl-sphingadienine (d18:2/22:0)*
# N-linoleoyltaurine*
# N-methylhydroxyproline**
# N-methylpipecolate
# N-palmitoyl-heptadecasphingosine (d17:1/16:0)*
# N-palmitoyl-sphingadienine (d18:2/16:0)*
# N-palmitoyl-sphinganine (d18:0/16:0)
# N-palmitoyl-sphingosine (d18:1/16:0)
# N-palmitoylserine
# N-stearoyl-sphingadienine (d18:2/18:0)*
# N-stearoyl-sphinganine (d18:0/18:0)*
# N-stearoyl-sphingosine (d18:1/18:0)*
# N-stearoylserine*
# N1-Methyl-2-pyridone-5-carboxamide
# N1-methyladenosine
# N2,N5-diacetylornithine
# N2-acetyl,N6-methyllysine
# N2-methylguanosine
# N4-acetylcytidine
# N6,N6,N6-trimethyllysine
# N6,N6-dimethyllysine
# N6-acetyllysine
# N6-carboxymethyllysine
# N6-methyllysine
# N6-succinyladenosine
# S-adenosylhomocysteine (SAH)
# acetylcarnitine (C2)
# aconitate [cis or trans]
# adenosine 3',5'-cyclic monophosphate (cAMP)
# adenosine 5'-diphosphate (ADP)
# adenosine 5'-diphosphoribose (ADP-ribose)
# adenosine 5'-monophosphate (AMP)
# adipoylcarnitine (C6-DC)
# adrenate (22:4n6)
# alpha-CEHC glucuronide*
# alpha-CMBHC glucuronide
# andro steroid monosulfate C19H28O6S (1)*
# androstenediol (3alpha, 17alpha) monosulfate (2)
# androstenediol (3alpha, 17alpha) monosulfate (3)
# androstenediol (3beta,17beta) disulfate (1)
# androstenediol (3beta,17beta) disulfate (2)
# androstenediol (3beta,17beta) monosulfate (1)
# androstenediol (3beta,17beta) monosulfate (2)
# arabitol/xylitol
# arabonate/xylonate
# arachidate (20:0)
# arachidonate (20:4n6)
# arachidonoylcarnitine (C20:4)
# arachidoylcarnitine (C20)*
# azelate (C9-DC)
# behenoyl dihydrosphingomyelin (d18:0/22:0)*
# behenoylcarnitine (C22)*
# beta-hydroxyisovaleroylcarnitine
# bilirubin (E,E)*
# bilirubin (E,Z or Z,E)*
# bilirubin (Z,Z)
# branched chain 14:0 dicarboxylic acid**
# branched-chain, straight-chain, or cyclopropyl 10:1 fatty acid (1)*
# branched-chain, straight-chain, or cyclopropyl 12:1 fatty acid*
# butyrate/isobutyrate (4:0)
# butyrylcarnitine (C4)
# caprate (10:0)
# caproate (6:0)
# caprylate (8:0)
# carboxyethyl-GABA
# carotene diol (1)
# carotene diol (2)
# carotene diol (3)
# ceramide (d16:1/24:1, d18:1/22:1)*
# ceramide (d18:1/14:0, d16:1/16:0)*
# ceramide (d18:1/20:0, d16:1/22:0, d20:1/18:0)*
# ceramide (d18:2/24:1, d18:1/24:2)*
# cerotoylcarnitine (C26)*
# cis-4-decenoate (10:1n6)*
# cis-4-decenoylcarnitine (C10:1)
# cortolone glucuronide (1)
# cysteine s-sulfate
# cysteinylglycine disulfide*
# decadienedioic acid (C10:2-DC)**
# decanoylcarnitine (C10)
# dehydroepiandrosterone sulfate (DHEA-S)
# delta-CEHC
# deoxycholic acid (12 or 24)-sulfate*
# deoxycholic acid 3-sulfate
# deoxycholic acid glucuronide
# diacylglycerol (12:0/18:1, 14:0/16:1, 16:0/14:1) [1]*
# diacylglycerol (12:0/18:1, 14:0/16:1, 16:0/14:1) [2]*
# diacylglycerol (14:0/18:1, 16:0/16:1) [1]*
# diacylglycerol (14:0/18:1, 16:0/16:1) [2]*
# diacylglycerol (16:1/18:2 [2], 16:0/18:3 [1])*
# dihomo-linolenate (20:3n3 or n6)
# dihomo-linolenoyl-choline
# dihomo-linolenoylcarnitine (C20:3n3 or 6)*
# dihomo-linoleoylcarnitine (C20:2)*
# dihydrocaffeate sulfate (2)
# dimethylarginine (SDMA + ADMA)
# docosadienoate (22:2n6)
# docosadioate (C22-DC)
# docosahexaenoate (DHA; 22:6n3)
# docosahexaenoylcarnitine (C22:6)*
# docosahexaenoylcholine
# docosapentaenoate (n3 DPA; 22:5n3)
# docosapentaenoate (n6 DPA; 22:5n6)
# docosapentaenoylcarnitine (C22:5n3)*
# dodecadienoate (12:2)*
# dodecanedioate (C12-DC)
# dodecenedioate (C12:1-DC)*
# eicosanedioate (C20-DC)
# eicosapentaenoate (EPA; 20:5n3)
# eicosapentaenoylcholine
# eicosenoate (20:1)
# eicosenoylcarnitine (C20:1)*
# erucate (22:1n9)
# ethyl alpha-glucopyranoside
# ethyl beta-glucopyranoside
# ferulylglycine (1)
# ferulylglycine (2)
# flavin adenine dinucleotide (FAD)
# gamma-glutamyl-alpha-lysine
# gamma-glutamylcitrulline*
# gamma-glutamylisoleucine*
# gamma-glutamylmethionine
# gamma-tocopherol/beta-tocopherol
# glucuronide of C10H18O2 (1)*
# glucuronide of C10H18O2 (4)*
# glucuronide of C10H18O2 (7)*
# glucuronide of C10H18O2 (8)*
# glucuronide of C19H28O4 (1)*
# glucuronide of C19H28O4 (2)*
# glucuronide of piperine metabolite C17H21NO3 (3)*
# glucuronide of piperine metabolite C17H21NO3 (4)*
# glucuronide of piperine metabolite C17H21NO3 (5)*
# glutamine conjugate of C6H10O2 (1)*
# glutamine conjugate of C6H10O2 (2)*
# glutamine conjugate of C7H12O2*
# glutarate (C5-DC)
# glutarylcarnitine (C5-DC)
# glycerophosphorylcholine (GPC)
# glycine conjugate of C10H12O2*
# glycine conjugate of C10H14O2 (1)*
# glyco-beta-muricholate**
# glycochenodeoxycholate 3-sulfate
# glycodeoxycholate 3-sulfate
# glycosyl ceramide (d16:1/24:1, d18:1/22:1)*
# glycosyl ceramide (d18:1/20:0, d16:1/22:0)*
# glycosyl ceramide (d18:2/24:1, d18:1/24:2)*
# glycosyl-N-(2-hydroxynervonoyl)-sphingosine (d18:1/24:1(2OH))*
# glycosyl-N-behenoyl-sphingadienine (d18:2/22:0)*
# glycosyl-N-palmitoyl-sphingosine (d18:1/16:0)
# glycosyl-N-stearoyl-sphingosine (d18:1/18:0)
# heneicosapentaenoate (21:5n3)
# heptenedioate (C7:1-DC)*
# hexadecadienoate (16:2n6)
# hexadecanedioate (C16-DC)
# hexadecasphingosine (d16:1)*
# hexadecenedioate (C16:1-DC)*
# hexanoylcarnitine (C6)
# hexanoylglutamine
# histidine betaine (hercynine)*
# homovanillate (HVA)
# hydroxy-CMPF*
# hydroxy-N6,N6,N6-trimethyllysine*
# hydroxypalmitoyl sphingomyelin (d18:1/16:0(OH))**
# iminodiacetate (IDA)
# indoleacetoylcarnitine*
# inosine 5'-monophosphate (IMP)
# isobutyrylcarnitine (C4)
# isovalerate (i5:0)
# isovalerylcarnitine (C5)
# lactosyl-N-behenoyl-sphingosine (d18:1/22:0)*
# lactosyl-N-nervonoyl-sphingosine (d18:1/24:1)*
# lactosyl-N-palmitoyl-sphingosine (d18:1/16:0)
# laurate (12:0)
# laurylcarnitine (C12)
# levulinate (4-oxovalerate)
# lignoceroyl sphingomyelin (d18:1/24:0)
# lignoceroylcarnitine (C24)*
# linoleate (18:2n6)
# linolenate [alpha or gamma; (18:3n3 or 6)]
# linolenoylcarnitine (C18:3)*
# linoleoyl-arachidonoyl-glycerol (18:2/20:4) [1]*
# linoleoyl-arachidonoyl-glycerol (18:2/20:4) [2]*
# linoleoyl-docosahexaenoyl-glycerol (18:2/22:6) [1]*
# linoleoyl-docosahexaenoyl-glycerol (18:2/22:6) [2]*
# linoleoyl-linolenoyl-glycerol (18:2/18:3) [2]*
# linoleoyl-linoleoyl-glycerol (18:2/18:2) [1]*
# linoleoylcarnitine (C18:2)*
# linoleoylcholine*
# mannitol/sorbitol
# margarate (17:0)
# margaroylcarnitine (C17)*
# metabolonic lactone sulfate
# methyl glucopyranoside (alpha + beta)
# methyl indole-3-acetate
# methylmalonate (MMA)
# methylnaphthyl sulfate (1)*
# methylnaphthyl sulfate (2)*
# myristate (14:0)
# myristoleate (14:1n5)
# myristoleoylcarnitine (C14:1)*
# myristoyl dihydrosphingomyelin (d18:0/14:0)*
# myristoyl-linoleoyl-glycerol (14:0/18:2) [1]*
# myristoyl-linoleoyl-glycerol (14:0/18:2) [2]*
# myristoylcarnitine (C14)
# naringenin 7-glucuronide
# nervonoylcarnitine (C24:1)*
# nicotinate ribonucleoside
# nisinate (24:6n3)
# nonadecanoate (19:0)
# nonanoylcarnitine (C9)
# octadecadienedioate (C18:2-DC)*
# octadecanedioate (C18-DC)
# octadecanedioylcarnitine (C18-DC)*
# octadecenedioate (C18:1-DC)
# octadecenedioylcarnitine (C18:1-DC)*
# octanoylcarnitine (C8)
# oleate/vaccenate (18:1)
# oleoyl-arachidonoyl-glycerol (18:1/20:4) [1]*
# oleoyl-arachidonoyl-glycerol (18:1/20:4) [2]*
# oleoyl-linoleoyl-glycerol (18:1/18:2) [1]
# oleoyl-linoleoyl-glycerol (18:1/18:2) [2]
# oleoyl-oleoyl-glycerol (18:1/18:1)  [1]*
# oleoyl-oleoyl-glycerol (18:1/18:1) [2]*
# oleoylcarnitine (C18:1)
# oxalate (ethanedioate)
# palmitate (16:0)
# palmitoleate (16:1n7)
# palmitoleoyl-linoleoyl-glycerol (16:1/18:2) [1]*
# palmitoleoyl-oleoyl-glycerol (16:1/18:1) [1]*
# palmitoleoyl-oleoyl-glycerol (16:1/18:1) [2]*
# palmitoleoylcarnitine (C16:1)*
# palmitoloelycholine
# palmitoyl-linoleoyl-glycerol (16:0/18:2) [1]*
# palmitoyl-linoleoyl-glycerol (16:0/18:2) [2]*
# palmitoyl-oleoyl-glycerol (16:0/18:1) [1]*
# palmitoyl-oleoyl-glycerol (16:0/18:1) [2]*
# palmitoyl-sphingosine-phosphoethanolamine (d18:1/16:0)
# palmitoylcarnitine (C16)
# pentadecanoate (15:0)
# pentose acid*
# perfluorooctanesulfonate (PFOS)
# perfluorooctanoate (PFOA)
# phenol glucuronide
# phenylacetylcarnitine
# phenylacetylglutamate
# phenyllactate (PLA)
# phosphatidylcholine (14:0/14:0, 16:0/12:0)
# phosphatidylcholine (15:0/18:1, 17:0/16:1, 16:0/17:1)*
# phosphatidylcholine (16:0/22:5n3, 18:1/20:4)*
# phosphatidylcholine (18:0/20:2, 20:0/18:2)*
# phosphatidylcholine (18:0/20:5, 16:0/22:5n6)*
# phosphatidylcholine (O-18:1/20:4, O-16:0/22:5n3)*
# pimeloylcarnitine/3-methyladipoylcarnitine (C7-DC)
# pregnanolone/allopregnanolone sulfate
# pregnenediol disulfate (C21H34O8S2)*
# pregnenediol sulfate (C21H34O5S)*
# pregnenetriol disulfate*
# pregnenetriol sulfate*
# propionylcarnitine (C3)
# retinol (Vitamin A)
# ribulonate/xylulonate/lyxonate*
# sebacate (C10-DC)
# sphinganine-1-phosphate
# sphingomyelin (d17:1/14:0, d16:1/15:0)*
# sphingomyelin (d17:1/16:0, d18:1/15:0, d16:1/17:0)*
# sphingomyelin (d17:2/16:0, d18:2/15:0)*
# sphingomyelin (d18:0/18:0, d19:0/17:0)*
# sphingomyelin (d18:0/20:0, d16:0/22:0)*
# sphingomyelin (d18:1/14:0, d16:1/16:0)*
# sphingomyelin (d18:1/17:0, d17:1/18:0, d19:1/16:0)
# sphingomyelin (d18:1/18:1, d18:2/18:0)
# sphingomyelin (d18:1/19:0, d19:1/18:0)*
# sphingomyelin (d18:1/20:0, d16:1/22:0)*
# sphingomyelin (d18:1/20:1, d18:2/20:0)*
# sphingomyelin (d18:1/20:2, d18:2/20:1, d16:1/22:2)*
# sphingomyelin (d18:1/21:0, d17:1/22:0, d16:1/23:0)*
# sphingomyelin (d18:1/22:1, d18:2/22:0, d16:1/24:1)*
# sphingomyelin (d18:1/22:2, d18:2/22:1, d16:1/24:2)*
# sphingomyelin (d18:1/24:1, d18:2/24:0)*
# sphingomyelin (d18:1/25:0, d19:0/24:1, d20:1/23:0, d19:1/24:0)*
# sphingomyelin (d18:2/14:0, d18:1/14:1)*
# sphingomyelin (d18:2/16:0, d18:1/16:1)*
# sphingomyelin (d18:2/18:1)*
# sphingomyelin (d18:2/21:0, d16:2/23:0)*
# sphingomyelin (d18:2/23:0, d18:1/23:1, d17:1/24:1)*
# sphingomyelin (d18:2/23:1)*
# sphingomyelin (d18:2/24:1, d18:1/24:2)*
# sphingomyelin (d18:2/24:2)*
# stearate (18:0)
# stearoyl sphingomyelin (d18:1/18:0)
# stearoyl-arachidonoyl-glycerol (18:0/20:4) [1]*
# stearoylcarnitine (C18)
# stearoylcholine*
# suberate (C8-DC)
# suberoylcarnitine (C8-DC)
# succinylcarnitine (C4-DC)
# sulfate of piperine metabolite C16H19NO3 (2)*
# sulfate of piperine metabolite C16H19NO3 (3)*
# sulfate of piperine metabolite C18H21NO3 (1)*
# sulfate of piperine metabolite C18H21NO3 (3)*
# tartronate (hydroxymalonate)
# taurodeoxycholic acid 3-sulfate
# tetradecadienedioate (C14:2-DC)*
# tetradecadienoate (14:2)*
# tetradecanedioate (C14-DC)
# tigloylglycine
# tiglylcarnitine (C5:1-DC)
# trans-4-hydroxyproline
# tricosanoyl sphingomyelin (d18:1/23:0)*
# tridecenedioate (C13:1-DC)*
# trigonelline (N'-methylnicotinate)
# undecenoylcarnitine (C11:1)
# valerate (5:0)
# valylphenylalanine
# vanillic acid glycine
# vanillylmandelate (VMA)
# ximenoylcarnitine (C26:1)*

# %%
queries = []
for (prefix, identifier, name), genes in grounded_df[["grounding", "nearest_gene_ids"]].values:
    norm_prefix, norm_id = bioregistry.normalize_parsed_curie(prefix, identifier)
    for gene in genes:
        queries.append((
            "hgnc", gene, hgnc_client.get_hgnc_name(gene),
            norm_prefix, norm_id, name,
        ))
columns = [
    "gene_prefix",
    "gene_identifier",
    "gene_name",
    "phenotype_prefix",
    "phenotype_identifier",
    "phenotype_name",
]
queries_df = pd.DataFrame(queries, columns=columns).sort_values(columns)
queries_df.to_csv("pheweb_metsim_tests.tsv", sep="\t", index=False)
queries_df.head()
# Out:
#     gene_prefix gene_identifier gene_name phenotype_prefix  \
# 633        hgnc           10348    RPL37A            chebi
# 350        hgnc            1048     BHMT2            chebi
# 39         hgnc            1048     BHMT2             mesh
# 100        hgnc           10487   S100A10            chebi
# 141        hgnc           10487   S100A10            chebi
#
#     phenotype_identifier      phenotype_name
# 633                27592             ectoine
# 350                90344     N-methylproline
# 39               C025138     dimethylglycine
# 100               132979  3-hydroxydecanoate
# 141               133511  3-hydroxyoctanoate
